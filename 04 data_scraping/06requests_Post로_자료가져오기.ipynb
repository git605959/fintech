# %%
import requests
import pandas as pd
import time
import os
from bs4 import BeautifulSoup as bs

# %%
url="https://kind.krx.co.kr/corpgeneral/corpList.do?method=loadInitPage"

# %%
r=requests.get(url)
print(r.status_code)
soup = bs(r.content, 'lxml')
soup
# 기업 정보는 실시간 반영되는 형태라 html로 저장되어있지 않아서 위 코드로는 확인 불가
# Out:
# 200
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="kr" http-equiv="content-language"/>
# <meta content="text/css" http-equiv="content-style-type"/>
# <meta content="no-cache" http-equiv="pragma"/>
# <meta content="no-cache" http-equiv="cache-control"/>
# <meta content="no" http-equiv="imagetoolbar"/>
# <meta content="대한민국 대표 기업공시채널 KIND(c)2014" name="copyright"/>
# <meta content="대한민국 대표 기업공시채널 KIND" name="description"/>
# <meta content="대한민국 대표 기업공시채널 KIND" name="keywords"/>
# <title>대한민국 대표 기업공시채널 KIND</title>
# <link href="../images/kind.ico" rel="shortcut icon"/>
# <link href="../js/jquery/themes-base/jquery-ui.min.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="../css/default_new.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="../css/common.css?version=20240927" media="all" rel="stylesheet" type="text/css"/>
# <link href="../css/style.css?version=20240524" media="all" rel="stylesheet" type="text/css"/>
# <link href="../esg/notoSans.css?20240524" media="all" rel="stylesheet" type="text/css"/>
# <!--[if lt IE 9]>
# <script type="text/javascript" src="../js/html5shiv.js"></script>
# <![endif]-->
# <script src="../js/dtree.js" type="text/javascript"></script>
# <script src="../js/trans.js" type="text/javascript"></script>
# <script src="../js/jquery/jquery.js" type="text/javascript"></script>
# <script src="../js/jquery/jquery-ui.min.js" type="text/javascript"></script>
# <script src="../js/jquery/jquery.placeholder.js" type="text/javascript"></script>
# <script src="../js/common.js?version=20240927" type="text/javascript"></script>
# <script src="../js/common-ajax.js" type="text/javascript"></script>
# <script src="../js/JCommon.js?version=20240809" type="text/javascript"></script>
# <script src="../js/common-sort.js" type="text/javascript"></script>
# </head>
# <body>
# <!-- 화면 확대/축소 안내 START-->
# <section class="notice popup modal type-00 hide">
# <div class="container">
# <div class="wrapper">
# <hgroup class="handle"><h2>화면 확대/축소 안내</h2></hgroup>
# <a class="btn-pop-close btn_close" href="#">닫기</a>
# <section class="body">
# <ul class="msg type-99 fc01">
# <li>※ IE8 이하의 웹브라우저에서는 다음과 같은 방법으로 화면의 확대/축소 기능을 이용하실 수 있습니다.</li>
# </ul>
# <img alt="화면확대 화면축소" src="../images/common/notice.png"/>
# </section>
# </div>
# <img alt="배경이미지" class="tl" src="../images/common/pop-type-00-tl.png"/>
# <img alt="배경이미지" class="bl" src="../images/common/pop-type-00-bl.png"/>
# <img alt="배경이미지" class="tr" src="../images/common/pop-type-00-tr.png"/>
# <img alt="배경이미지" class="br" src="../images/common/pop-type-00-br.png"/>
# <div class="tm"></div>
# <div class="lm"></div>
# <div class="bm"></div>
# <div class="rm"></div>
# </div>
# </section>
# <!-- HEADER 영역 START -->
# <header class="container">
# <div class="container_line">
# <div class="wrapper-super">
# <hgroup>
# <h1 class="logo"><a href="/main.do?method=loadInitPage&amp;scrnmode=1" title="대한민국 대표 기업공시채널 KIND"><img alt="대한민국 대표 기업공시채널 KIND" src="../images/main/logo.gif"/></a></h1>
# </hgroup>
# <ul class="util">
# <li class="first"><a href="/common/JLDDST35000.html" onclick="winCommPopOpen('1'); return false;" title="KIND 소개 새창"><img alt="KIND 소개" src="../images/common/util_intro.gif"/></a></li>
# <li>
# <a href="https://engkind.krx.co.kr/" target="_blank" title="KIND 영문사이트 바로가기"><img alt="ENGLISH KIND" src="../images/common/util_eng.gif"/></a>
# </li>
# <li class="btn-group">
# <img alt="화면크기" class="ttl" src="../images/common/ttl_screen.gif"/>
# <a class="plus zoom_btn-in" href="#"><span>확대</span></a>
# <a class="reset zoom_btn-reset" href="#"><span>원래대로</span></a>
# <a class="minus zoom_btn-out" href="#"><span>축소</span></a>
# </li>
# </ul>
# <div class="clear"></div>
# <form id="AKCFrm" name="AKCFrm">
# <input id="method" name="method" type="hidden" value="disclosureSimpleSearchMain"/>
# <input id="searchCodeType" name="searchCodeType" type="hidden" value=""/>
# <input id="repIsuSrtCd" name="repIsuSrtCd" type="hidden" value=""/>
# <input id="isurCd" name="isurCd" type="hidden" value=""/>
# <input id="AKCKwdCode" name="AKCKwdCode" type="hidden" value=""/>
# <section class="search auto_complete top-akc-sub">
# <div class="autoKey">
# <input autocomplete="off" class="search-txt dval" id="AKCKwdTop" name="searchCorpName" onblur="chkValidChar_top(this); fnMainCorpType();" placeholder="회사명 또는 종목코드를 입력해 주세요." type="text"/>
# <div class="tselect">
# <img alt="자동완성 열기" class="autoc_open" id="AKCArrowTop" src="../images/common/icn_autoc_open.gif"/>
# <div class="AKCDivTop" id="AKCDivTop" style="display:none;">
# <iframe frameborder="0" id="AKCIfrmTop" name="AKCIfrmTop" scrolling="no" src="../common/akc_top.html?version=20220624" title="자동완성"></iframe>
# </div>
# </div>
# </div>
# <input alt="검색" class="submit" onclick="fnTopAKCKwdSearch(); return false;" src="../images/common/btn_search.gif" type="image"/>
# <div class="clear"></div>
# </section>
# </form>
# <a class="btn sitemap open" href="#"><img alt="전체메뉴보기" src="../images/common/btn_sitemap.gif"/></a>
# </div>
# </div>
# <div class="sitemap-wrapper">
# <!-- TOP MENU START -->
# <section class="sitemap">
# <article class="mymenu">
# <h3><img alt="나만의 메뉴" src="../images/common/ttl_sitemap_my.png"/></h3>
# <div class="list">
# <ul id="myMenuTop">
# <li class="active"><a href="/disclosure/todaydisclosure.do?method=searchTodayDisclosureMain">오늘의공시</a></li>
# <li><a href="/disclosure/searchdisclosurebycorp.do?method=searchDisclosureByCorpMain">회사별검색</a></li>
# <li><a href="/disclosure/searchtotalinfo.do?method=searchTotalInfoMain">통합검색</a></li>
# <li><a href="/disclosure/details.do?method=searchDetailsMain">상세검색</a></li>
# <li><a href="/corpdetail/totalinfo.do?method=loadInitPage">종합정보</a></li>
# </ul>
# </div>
# <a class="btn_sitemap-set" href="#"><img alt="설정" src="../images/common/btn_sitemap_set.png"/></a>
# </article>
# <section class="list-wrapper links">
# <article class="list">
# <h3>공시</h3>
# <ul>
# <li><a class="first" href="/disclosure/todaydisclosure.do?method=searchTodayDisclosureMain">오늘의공시</a></li>
# <li><a class="first" href="/disclosure/searchdisclosurebycorp.do?method=searchDisclosureByCorpMain">회사별검색</a></li>
# <li><a class="first" href="/disclosure/details.do?method=searchDetailsMain">상세검색</a></li>
# <li><a class="first" href="#" onclick="krxPaPago_open(); return false;">KRX-Papago번역기</a></li>
# <li><a class="first" href="/disclosure/searchtotalinfo.do?method=searchTotalInfoMain">통합검색</a></li>
# <li><a class="first" href="/disclosure/searchbondcorpdisclosure.do?method=searchBondCorpDisclosureMain">채권공시</a></li>
# <li><a class="more" href="#">ETF/ELW/ETN<span><img alt="메뉴 더보기" src="../images/common/bg_gnb_gmn2.gif"/></span></a></li>
# <div class="gnb1-wrapper" id="sub">
# <nav id="gnb1"><dl>
# <dd>
# <div class="lnb">
# <div class="wrapper">
# <a class="lmn" href="/disclosure/disclosurebystocktype.do?method=searchDisclosureByStockTypeEtf">ETF</a>
# <a class="lmn" href="/disclosure/disclosurebystocktype.do?method=searchDisclosureByStockTypeElw">ELW</a>
# <a class="lmn" href="/disclosure/disclosurebystocktype.do?method=searchDisclosureByStockTypeEtn">ETN</a>
# <img class="arrow" src="../images/common/lnb_arrow_sub.png"/>
# <img class="tl" src="../images/common/lnb_tl.png"/>
# <img class="tr" src="../images/common/lnb_tr.png"/>
# <img class="bl" src="../images/common/lnb_bl.png"/>
# <img class="br" src="../images/common/lnb_br.png"/>
# </div>
# </div>
# </dd>
# </dl></nav>
# </div>
# <li><a class="more" href="#">펀드공시<span><img alt="메뉴 더보기" src="../images/common/bg_gnb_gmn2.gif"/></span></a></li>
# <div class="gnb1-wrapper" id="sub">
# <nav id="gnb1"><dl>
# <dd>
# <div class="lnb">
# <div class="wrapper">
# <a class="lmn" href="/disclosure/disclosurebystocktype.do?method=searchDisclosureByStockTypeRestinvstcom">부동산투자회사</a>
# <a class="lmn" href="/disclosure/disclosurebystocktype.do?method=searchDisclosureByStockTypeShipinvstcom">선박투자회사</a>
# <a class="lmn" href="/disclosure/disclosurebystocktype.do?method=searchDisclosureByStockTypeInvstcom">투자회사</a>
# <a class="lmn" href="/disclosure/disclosurebystocktype.do?method=searchDisclosureByStockTypeBenfcert">수익증권</a>
# <img class="arrow" src="../images/common/lnb_arrow_sub.png"/>
# <img class="tl" src="../images/common/lnb_tl.png"/>
# <img class="tr" src="../images/common/lnb_tr.png"/>
# <img class="bl" src="../images/common/lnb_bl.png"/>
# <img class="br" src="../images/common/lnb_br.png"/>
# </div>
# </div>
# </dd>
# </dl></nav>
# </div>
# <li><a class="first" href="/disclosure/misccorpdiscls.do?method=searchMiscCorpDisclsMain">기타법인공시</a></li>
# <li><a class="more" href="#">의결권행사공시<span><img alt="메뉴 더보기" src="../images/common/bg_gnb_gmn2.gif"/></span></a></li>
# <div class="gnb1-wrapper" id="sub">
# <nav id="gnb1"><dl>
# <dd>
# <div class="lnb">
# <div class="wrapper">
# <a class="lmn" href="/disclosure/disclosurebyvote.do?method=searchDisclosurebyVoteMain">의결권행사공시</a>
# <a class="lmn" href="https://dis.kofia.or.kr/websquare/index.jsp?w2xPath=/wq/compann/DISFndVoteRightView.xml&amp;divisionId=MDIS02003010000000&amp;serviceId=SDIS02003010000#!" target="_blank">운용사 펀드의결권행사공시</a>
# <a class="lmn" href="https://dis.kofia.or.kr/websquare/index.jsp?w2xPath=/wq/compann/DISFndVoteRightViewDet.xml&amp;divisionId=MDIS02003011000000&amp;serviceId=SDIS02003011000" target="_blank">펀드별 의결권행사공시</a>
# <img class="arrow" src="../images/common/lnb_arrow_sub.png"/>
# <img class="tl" src="../images/common/lnb_tl.png"/>
# <img class="tr" src="../images/common/lnb_tr.png"/>
# <img class="bl" src="../images/common/lnb_bl.png"/>
# <img class="br" src="../images/common/lnb_br.png"/>
# </div>
# </div>
# </dd>
# </dl></nav>
# </div>
# <li><a class="first" href="/corpdetail/chart.do?method=loadInitPage">공시차트</a></li>
# <li><a class="first" href="/disclosure/searchErrorTradeRelief.do?method=searchErrorTradeReliefMain">착오매매구제신청</a></li>
# <!-- 신종증권 메뉴 제외 -->
# <!--<li><a href="#" class="more">신종증권<span><img src="../images/common/bg_gnb_gmn2.gif" alt="메뉴 더보기"/></span></a></li>
# 						<DIV id="sub" class="gnb1-wrapper">
# 							<nav id="gnb1">
# 							<DL>
# 							<DD>
# 							<DIV class="lnb">
# 								<DIV class="wrapper">
# 									<A class="lmn" href="/digital/digitalList.do?method=digitalList">비금전신탁수익증권</A>
# 									<A class="lmn" href="/digital/digitalInvstList.do?method=digitalInvstList">투자계약증권</A>
# 									<IMG class="arrow" src="../images/common/lnb_arrow_sub.png" />
# 									<IMG class="tl" src="../images/common/lnb_tl.png" />
# 									<IMG class="tr" src="../images/common/lnb_tr.png" />
# 									<IMG class="bl" src="../images/common/lnb_bl.png" />
# 									<IMG class="br" src="../images/common/lnb_br.png" />
# 								</DIV>
# 							</DIV>
# 							</DD>
# 							</DL>
# 							</nav>
# 						</DIV>
# 						-->
# </ul>
# </article>
# <article class="list">
# <h3>상장법인상세정보</h3>
# <ul>
# <li><a class="first" href="/corpdetail/totalinfo.do?method=loadInitPage">종합정보</a></li>
# <li><a class="first" href="/corpgeneral/listedIssueStatus.do?method=loadInitPage">상장종목현황</a></li>
# <li><a class="first" href="/corpgeneral/corpList.do?method=loadInitPage">상장법인목록</a></li>
# <li><a class="first" href="/corpgeneral/stockissuelist.do?method=loadInitPage">주식발행내역</a></li>
# <li><a class="more" href="#">기업지배구조<span><img alt="메뉴 더보기" src="../images/common/bg_gnb_gmn2.gif"/></span></a></li>
# <div class="gnb1-wrapper" id="sub">
# <nav id="gnb1"><dl>
# <dd>
# <div class="lnb">
# <div class="wrapper">
# <a class="lmn" href="/corpgeneral/companyGovernance.do?method=loadInitPage">기업지배구조 보고서</a>
# <a class="lmn" href="http://www.cgs.or.kr/business/esg_tab04.jsp" target="_blank">ESG등급</a>
# <img class="arrow" src="../images/common/lnb_arrow_sub.png"/>
# <img class="tl" src="../images/common/lnb_tl.png"/>
# <img class="tr" src="../images/common/lnb_tr.png"/>
# <img class="bl" src="../images/common/lnb_bl.png"/>
# <img class="br" src="../images/common/lnb_br.png"/>
# </div>
# </div>
# </dd>
# </dl></nav>
# </div>
# <li><a class="first" href="/corpgeneral/treasurystk.do?method=loadInitPage">자사주취득/처분</a></li>
# <li><a class="more" href="#">IR일정/IR자료실<span><img alt="메뉴 더보기" src="../images/common/bg_gnb_gmn2.gif"/></span></a></li>
# <div class="gnb1-wrapper" id="sub">
# <nav id="gnb1"><dl>
# <dd>
# <div class="lnb">
# <div class="wrapper">
# <a class="lmn" href="/corpgeneral/irschedule.do?method=searchIRScheduleMain&amp;gubun=iRSchedule">IR일정</a>
# <a class="lmn" href="/corpgeneral/irschedule.do?method=searchIRScheduleMain&amp;gubun=iRMaterials">IR자료실</a>
# <a class="lmn" href="https://www.youtube.com/playlist?list=PLAgvDyD2zN6ry9AVlh2emmvoJy4K39KT7" target="_blank">영상자료</a>
# <a class="lmn" href="/corpgeneral/irschedule.do?method=searchIRScheduleMain&amp;gubun=iRScheduleCalendar">IR일정 달력</a>
# <img class="arrow" src="../images/common/lnb_arrow_sub.png"/>
# <img class="tl" src="../images/common/lnb_tl.png"/>
# <img class="tr" src="../images/common/lnb_tr.png"/>
# <img class="bl" src="../images/common/lnb_bl.png"/>
# <img class="br" src="../images/common/lnb_br.png"/>
# </div>
# </div>
# </dd>
# </dl></nav>
# </div>
# <li><a class="more" href="#">기업분석보고서<span><img alt="메뉴 더보기" src="../images/common/bg_gnb_gmn2.gif"/></span></a></li>
# <div class="gnb1-wrapper" id="sub">
# <nav id="gnb1"><dl>
# <dd>
# <div class="lnb">
# <div class="wrapper">
# <a class="lmn" href="/corpgeneral/companyAnalysisReport.do?method=listingForeignCompanyMain&amp;searchGubun=companyAnalysisReport">기업분석리포트</a>
# <a class="lmn" href="/corpgeneral/newListingForeignCompany.do?method=listingForeignCompanyMain&amp;searchGubun=newListingForeignCompany">신규상장기업분석보고서</a>
# <a class="lmn" href="/corpgeneral/growthReport.do?method=listingForeignCompanyMain&amp;searchGubun=growthReport">사업모델 평가보고서 및 기업 계속성 보고서</a>
# <img class="arrow" src="../images/common/lnb_arrow_sub.png"/>
# <img class="tl" src="../images/common/lnb_tl.png"/>
# <img class="tr" src="../images/common/lnb_tr.png"/>
# <img class="bl" src="../images/common/lnb_bl.png"/>
# <img class="br" src="../images/common/lnb_br.png"/>
# </div>
# </div>
# </dd>
# </dl></nav>
# </div>
# <li><a class="first" href="/corpgeneral/corpGroup.do?method=loadInitPage">기업집단</a></li>
# <li><a class="more" href="#">배당정보<span><img alt="메뉴 더보기" src="../images/common/bg_gnb_gmn2.gif"/></span></a></li>
# <div class="gnb1-wrapper" id="sub">
# <nav id="gnb1"><dl>
# <dd>
# <div class="lnb">
# <div class="wrapper">
# <a class="lmn" href="/disclosureinfo/dividendinfo.do?method=searchDividendInfoMain">배당정보</a>
# <a class="lmn" href="http://data.krx.co.kr/contents/MDC/MDI/mdiLoader/index.cmd?menuId=MDC0201010107" target="_blank">업종배당수익율</a>
# <img class="arrow" src="../images/common/lnb_arrow_sub.png"/>
# <img class="tl" src="../images/common/lnb_tl.png"/>
# <img class="tr" src="../images/common/lnb_tr.png"/>
# <img class="bl" src="../images/common/lnb_bl.png"/>
# <img class="br" src="../images/common/lnb_br.png"/>
# </div>
# </div>
# </dd>
# </dl></nav>
# </div>
# <li><a class="first" href="/compfinance/financialinfo.do?method=loadInitPage&amp;searchgubun=corporation">회사재무비교</a></li>
# <li><a class="first" href="/corpgeneral/excntDisclsCompany.do?method=loadInitPage">공시우수법인</a></li>
# <li><a class="first" href="/corpdetail/ventureFundInvest.do?method=corpListMain">벤처펀드투자기업(코)</a></li>
# <!-- 신종증권 메뉴 제외 -->
# <!--<li><a href="/digital/digitalCorpList.do?method=digitalCorpList" class="first">상장종목(신종증권)</a></li>-->
# </ul>
# </article>
# <article class="list">
# <h3>기업 밸류업 정보</h3>
# <ul>
# <li><a class="first" href="/valueup/intro.do?method=valueupIntroMain">기업 밸류업 소개</a></li>
# <li><a class="first" href="/valueup/notice.do?method=valueupNoticeMain">공지사항</a></li>
# <li><a class="first" href="/valueup/disclsstat.do?method=valueupDisclsStatMain">공시현황</a></li>
# <li><a class="more" href="#">투자지표<span><img alt="메뉴 더보기" src="../images/common/bg_gnb_gmn2.gif"/></span></a></li>
# <div class="gnb1-wrapper" id="sub">
# <nav id="gnb1"><dl>
# <dd>
# <div class="lnb">
# <div class="wrapper">
# <a class="lmn" href="/valueup/invstindicsectors.do?method=valueupInvstIndicRankIndMain">업종별 투자지표 순위</a>
# <a class="lmn" href="/valueup/invstindicstocks.do?method=valueupInvstIndicRankIsuMain">종목별 투자지표 추이</a>
# <img class="arrow" src="../images/common/lnb_arrow_sub.png"/>
# <img class="tl" src="../images/common/lnb_tl.png"/>
# <img class="tr" src="../images/common/lnb_tr.png"/>
# <img class="bl" src="../images/common/lnb_bl.png"/>
# <img class="br" src="../images/common/lnb_br.png"/>
# </div>
# </div>
# </dd>
# </dl></nav>
# </div>
# <li><a class="first" href="/valueup/idx.do?method=valueupIdxMain">인덱스</a></li>
# <li><a class="first" href="/valueup/excntcorp.do?method=valueupExcntCorpMain">기업 밸류업 우수법인</a></li>
# <li><a class="first" href="/valueup/resoroom.do?method=valueupResoroomMain">자료실</a></li>
# </ul>
# </article>
# <article class="list weight">
# <h3>투자유의사항</h3>
# <ul>
# <li><a class="first" href="/investwarn/adminissue.do?method=searchAdminIssueList">관리종목</a></li>
# <li><a class="first" href="/investwarn/hwangiissue.do?method=searchHwangiIssueMain">투자주의환기종목(코)</a></li>
# <li><a class="first" href="/investwarn/tradinghaltissue.do?method=searchTradingHaltIssueMain">매매거래정지종목</a></li>
# <li><a class="first" href="/investwarn/undisclosure.do?method=searchUnfaithfulDisclosureCorpList">불성실공시법인</a></li>
# <li><a class="first" href="/investwarn/investattentwarnrisky.do?method=investattentwarnriskyMain">투자주의/경고/위험종목</a></li>
# <li><a class="first" href="/corpgeneral/delistRealInvstg.do?method=searchDelistRealInvstgMain">실질심사법인</a></li>
# <li><a class="first" href="/investwarn/investattentEmbezzlement.do?method=searchInvestAttentEmbezzlementMain">횡령 등</a></li>
# <li><a class="first" href="/investwarn/investattentLargeShareChange.do?method=searchInvestAttentLargeShareChangeMain">최대주주변경2회이상</a></li>
# <li><a class="more" href="#">기타사항<span><img alt="메뉴 더보기" src="../images/common/bg_gnb_gmn2.gif"/></span></a></li>
# <div class="gnb1-wrapper" id="sub">
# <nav id="gnb1"><dl>
# <dd>
# <div class="lnb">
# <div class="wrapper">
# <a class="lmn" href="/investwarn/investattentEtcMarket.do?method=searchInvestAttentEtcMarketMain">기타 시장안내</a>
# <a class="lmn" href="/investwarn/prtdepoStat.do?method=searchPrtdepoStatMain">의무보유현황(유가)</a>
# <a class="lmn" href="/investwarn/penalty.do?method=searchPenaltyImprovementList">벌점및개선계획서 현황</a>
# <a class="lmn" href="/investwarn/delcompany.do?method=searchDelCompanyMain">상장폐지현황</a>
# <a class="lmn" href="/investwarn/delListDelibRec.do?method=searchDelListDelibRecMain">상장폐지최종심의의사록</a>
# <a class="lmn" href="/investwarn/investwarnGuide.do?method=searchInvestGuideMain">투자유의안내</a>
# <a class="lmn" href="/disclosureinfo/nfaithdisclsdecl.do?method=insertNfaithdisclsDeclMain">불성실공시 신고포상</a>
# <img class="arrow" src="../images/common/lnb_arrow_sub.png"/>
# <img class="tl" src="../images/common/lnb_tl.png"/>
# <img class="tr" src="../images/common/lnb_tr.png"/>
# <img class="bl" src="../images/common/lnb_bl.png"/>
# <img class="br" src="../images/common/lnb_br.png"/>
# </div>
# </div>
# </dd>
# </dl></nav>
# </div>
# </ul>
# </article>
# <article class="list">
# <h3>IPO현황</h3>
# <ul>
# <li><a class="first" href="/listinvstg/listinvstgcom.do?method=searchListInvstgCorpMain">예비심사기업</a></li>
# <li><a class="first" href="/listinvstg/listapplcom.do?method=searchListApplCorpMain">코넥스 상장신청기업</a></li>
# <li><a class="more" href="#">공모기업<span><img alt="메뉴 더보기" src="../images/common/bg_gnb_gmn2.gif"/></span></a></li>
# <div class="gnb1-wrapper" id="sub">
# <nav id="gnb1"><dl>
# <dd>
# <div class="lnb">
# <div class="wrapper">
# <a class="lmn" href="/listinvstg/pubofrprogcom.do?method=searchPubofrProgComMain">공모기업현황</a>
# <a class="lmn" href="/listinvstg/pubofrschdl.do?method=searchPubofrScholMain">공모일정</a>
# <img class="arrow" src="../images/common/lnb_arrow_sub.png"/>
# <img class="tl" src="../images/common/lnb_tl.png"/>
# <img class="tr" src="../images/common/lnb_tr.png"/>
# <img class="bl" src="../images/common/lnb_bl.png"/>
# <img class="br" src="../images/common/lnb_br.png"/>
# </div>
# </div>
# </dd>
# </dl></nav>
# </div>
# <li><a class="more" href="#">신규상장기업<span><img alt="메뉴 더보기" src="../images/common/bg_gnb_gmn2.gif"/></span></a></li>
# <div class="gnb1-wrapper" id="sub">
# <nav id="gnb1"><dl>
# <dd>
# <div class="lnb">
# <div class="wrapper">
# <a class="lmn" href="/listinvstg/listingcompany.do?method=searchListingTypeMain">신규상장기업현황</a>
# <a class="lmn" href="/listinvstg/mergeListingCompany.do?method=searchMergeListingCompMain">합병상장기업현황</a>
# <a class="lmn" href="/listinvstg/genfinance.do?method=searchGenFinanaceMain">재무현황</a>
# <a class="lmn" href="/listinvstg/pubprcCmpStkprcByIssue.do?method=pubprcCmpStkprcByIssueMain">공모가대비주가정보</a>
# <img class="arrow" src="../images/common/lnb_arrow_sub.png"/>
# <img class="tl" src="../images/common/lnb_tl.png"/>
# <img class="tr" src="../images/common/lnb_tr.png"/>
# <img class="bl" src="../images/common/lnb_bl.png"/>
# <img class="br" src="../images/common/lnb_br.png"/>
# </div>
# </div>
# </dd>
# </dl></nav>
# </div>
# <li><a class="more" href="#">신규상장통계<span><img alt="메뉴 더보기" src="../images/common/bg_gnb_gmn2.gif"/></span></a></li>
# <div class="gnb1-wrapper" id="sub">
# <nav id="gnb1"><dl>
# <dd>
# <div class="lnb">
# <div class="wrapper">
# <a class="lmn" href="/listinvstg/listtypestat.do?method=searchListTypeStatusMain">상장통계</a>
# <a class="lmn" href="/listinvstg/puboframt.do?method=searchPubofrAmtMain">공모통계</a>
# <a class="lmn" href="/listinvstg/ipoprfm.do?method=searchIpoPrfmMain">상장주선인 IPO실적</a>
# <a class="lmn" href="/listinvstg/advseripoprfm.do?method=searchAdvserIpoPrfmMain">지정자문인 상장실적</a>
# <img class="arrow" src="../images/common/lnb_arrow_sub.png"/>
# <img class="tl" src="../images/common/lnb_tl.png"/>
# <img class="tr" src="../images/common/lnb_tr.png"/>
# <img class="bl" src="../images/common/lnb_bl.png"/>
# <img class="br" src="../images/common/lnb_br.png"/>
# </div>
# </div>
# </dd>
# </dl></nav>
# </div>
# <li><a class="first" href="/listinvstg/listinvstginfo.do?method=searchListInvstgInfoMain">상장심사가이드</a></li>
# </ul>
# <h3>정보실</h3>
# <ul>
# <li><a class="first" href="/disclosureinfo/notice.do?method=searchNoticeMain">공지사항</a></li>
# <!-- li><a href="/news/searchnews.do?method=searchNewsMain" class="first">증시뉴스</a></li -->
# <li><a class="first" href="/disclosureinfo/explanationsystem.do?method=searchSysInfo">제도해설</a></li>
# <li><a class="first" href="/disclosureinfo/searchmaterials.do?method=searchMaterialsMain">자료실</a></li>
# </ul>
# </article>
# </section>
# <section class="list-wrapper config">
# <article class="list">
# <h3>공시</h3>
# <ul>
# <li><input id="chkEdit01" name="checkboxMenu" type="checkbox" value="ULDDST00000"/> <label for="chkEdit01">오늘의공시</label></li>
# <li><input id="chkEdit02" name="checkboxMenu" type="checkbox" value="ULDDST00100"/> <label for="chkEdit02">회사별검색</label></li>
# <li><input id="chkEdit03" name="checkboxMenu" type="checkbox" value="ULDDST00300"/> <label for="chkEdit03">상세검색</label></li>
# <li><input id="chkEdit04" name="checkboxMenu" type="checkbox" value="ULDDST00200"/> <label for="chkEdit04">통합검색</label></li>
# <li><input id="chkEdit05" name="checkboxMenu" type="checkbox" value="ULDDST00700"/> <label for="chkEdit05">채권공시</label></li>
# <li><input id="chkEdit06" name="checkboxMenu" type="checkbox" value="ULDDST00400"/> <label for="chkEdit06">ETF ELW ETN</label></li>
# <li><input id="chkEdit07" name="checkboxMenu" type="checkbox" value="JLDDST00403"/> <label for="chkEdit07">펀드공시</label></li>
# <li><input id="chkEdit08" name="checkboxMenu" type="checkbox" value="ULDDST01300"/> <label for="chkEdit08">기타법인공시</label></li>
# <li><input id="chkEdit010" name="checkboxMenu" type="checkbox" value="ULDDST01500"/> <label for="chkEdit010">의결권행사공시</label></li>
# <li><input id="chkEdit09" name="checkboxMenu" type="checkbox" value="ULDDST10400"/> <label for="chkEdit09">공시차트</label></li>
# <li><input id="chkEdit40" name="checkboxMenu" type="checkbox" value="ULDDST01600"/><label for="chkEdit40">착오매매구제신청</label></li>
# <!-- 신종증권 메뉴 제외 -->
# <!--<li><input type="checkbox" id="chkEdit50" name="checkboxMenu" value="ULDDST20000" /><label for="chkEdit50">신종증권</label></li>-->
# </ul>
# </article>
# <article class="list">
# <h3>상장법인상세정보</h3>
# <ul>
# <li><input id="chkEdit10" name="checkboxMenu" type="checkbox" value="ULDDST10000"/> <label for="chkEdit10">종합정보</label></li>
# <li><input id="chkEdit11" name="checkboxMenu" type="checkbox" value="ULDDST05000"/> <label for="chkEdit11">상장종목현황</label></li>
# <li><input id="chkEdit12" name="checkboxMenu" type="checkbox" value="ULDDST05100"/> <label for="chkEdit12">상장법인목록</label></li>
# <li><input id="chkEdit13" name="checkboxMenu" type="checkbox" value="ULDDST06000"/> <label for="chkEdit13">주식발행내역</label></li>
# <li><input id="chkEdit41" name="checkboxMenu" type="checkbox" value="ULDDST38150"/> <label for="chkEdit41">기업지배구조</label></li>
# <li><input id="chkEdit14" name="checkboxMenu" type="checkbox" value="ULDDST05300"/> <label for="chkEdit14">자사주취득처분</label></li>
# <li><input id="chkEdit15" name="checkboxMenu" type="checkbox" value="ULDDST05600"/> <label for="chkEdit15">IR일정IR자료실</label></li>
# <li><input id="chkEdit16" name="checkboxMenu" type="checkbox" value="ULDDST38010"/> <label for="chkEdit16">기업분석보고서</label></li>
# <li><input id="chkEdit17" name="checkboxMenu" type="checkbox" value="ULDDST05800"/> <label for="chkEdit17">기업진단</label></li>
# <li><input id="chkEdit18" name="checkboxMenu" type="checkbox" value="ULDDST36400"/> <label for="chkEdit18">배당정보</label></li>
# <li><input id="chkEdit19" name="checkboxMenu" type="checkbox" value="ULDDST15400"/> <label for="chkEdit19">회사재무비교</label></li>
# <li><input id="chkEdit39" name="checkboxMenu" type="checkbox" value="JLDDST38140"/> <label for="chkEdit39">공시우수법인</label></li>
# <li><input id="chkEdit42" name="checkboxMenu" type="checkbox" value="JLDDST11000"/> <label for="chkEdit42">벤처펀드투자대상기업(코)</label></li>
# <!-- 신종증권 메뉴 제외 -->
# <!--<li><input type="checkbox" id="chkEdit43" name="checkboxMenu" value="JLDDST30200" /> <label for="chkEdit43">상장종목(신종증권)</label></li>-->
# </ul>
# </article>
# <article class="list">
# <h3>기업 밸류업 정보</h3>
# <ul>
# <li><input id="chkEdit44" name="checkboxMenu" type="checkbox" value="ULDDST80100"/> <label for="chkEdit44">기업 밸류업 소개</label></li>
# <li><input id="chkEdit45" name="checkboxMenu" type="checkbox" value="ULDDST80200"/> <label for="chkEdit45">공지사항</label></li>
# <li><input id="chkEdit46" name="checkboxMenu" type="checkbox" value="ULDDST80300"/> <label for="chkEdit46">공시현황</label></li>
# <li><input id="chkEdit47" name="checkboxMenu" type="checkbox" value="ULDDST80400"/> <label for="chkEdit47">투자지표</label></li>
# <li><input id="chkEdit48" name="checkboxMenu" type="checkbox" value="ULDDST80500"/> <label for="chkEdit48">인덱스</label></li>
# <li><input id="chkEdit49" name="checkboxMenu" type="checkbox" value="ULDDST80600"/> <label for="chkEdit49">기업 밸류업 우수법인</label></li>
# <li><input id="chkEdit50" name="checkboxMenu" type="checkbox" value="ULDDST80700"/> <label for="chkEdit50">자료실</label></li>
# </ul>
# </article>
# <article class="list">
# <h3>투자유의사항</h3>
# <ul>
# <li><input id="chkEdit25" name="checkboxMenu" type="checkbox" value="ULDDST30000"/> <label for="chkEdit25">관리종목</label></li>
# <li><input id="chkEdit26" name="checkboxMenu" type="checkbox" value="ULDDST30900"/> <label for="chkEdit26">투자주의환기종목(코)</label></li>
# <li><input id="chkEdit27" name="checkboxMenu" type="checkbox" value="ULDDST30400"/> <label for="chkEdit27">매매거래정지종목</label></li>
# <li><input id="chkEdit28" name="checkboxMenu" type="checkbox" value="ULDDST30100"/> <label for="chkEdit28">불성실공시법인</label></li>
# <li><input id="chkEdit29" name="checkboxMenu" type="checkbox" value="ULDDST30500"/> <label for="chkEdit29">투자주의경고위험</label></li>
# <li><input id="chkEdit30" name="checkboxMenu" type="checkbox" value="ULDDST05900"/> <label for="chkEdit30">실질심사법인</label></li>
# <li><input id="chkEdit31" name="checkboxMenu" type="checkbox" value="ULDDST30301"/> <label for="chkEdit31">횡령 등</label></li>
# <li><input id="chkEdit32" name="checkboxMenu" type="checkbox" value="ULDDST30302"/> <label for="chkEdit32">최대주주변경2회이상</label></li>
# <li><input id="chkEdit33" name="checkboxMenu" type="checkbox" value="ULDDST30301"/> <label for="chkEdit33">기타사항</label></li>
# </ul>
# </article>
# <article class="list">
# <h3>IPO현황</h3>
# <ul>
# <li><input id="chkEdit20" name="checkboxMenu" type="checkbox" value="ULDDST71000"/> <label for="chkEdit20">예비심사기업</label></li>
# <li><input id="chkEdit38" name="checkboxMenu" type="checkbox" value="ULDDST71100"/> <label for="chkEdit38">코넥스 상장신청기업</label></li>
# <li><input id="chkEdit21" name="checkboxMenu" type="checkbox" value="ULDDST72000"/> <label for="chkEdit21">공모기업</label></li>
# <li><input id="chkEdit22" name="checkboxMenu" type="checkbox" value="ULDDST70000"/> <label for="chkEdit22">신규상장기업</label></li>
# <li><input id="chkEdit23" name="checkboxMenu" type="checkbox" value="ULDDST73000"/> <label for="chkEdit23">신규상장통계</label></li>
# <li><input id="chkEdit24" name="checkboxMenu" type="checkbox" value="ULDDST75000"/> <label for="chkEdit24">상장심사가이드</label></li>
# </ul>
# <h3>정보실</h3>
# <ul>
# <li><input id="chkEdit34" name="checkboxMenu" type="checkbox" value="ULDDST35100"/> <label for="chkEdit34">공지사항</label></li>
# <!-- li><input type="checkbox" id="chkEdit35" name="checkboxMenu" value="ULDDST25000" /> <label for="chkEdit35">증시뉴스</label></li -->
# <li><input id="chkEdit36" name="checkboxMenu" type="checkbox" value="ULDDST35400"/> <label for="chkEdit36">제도해설</label></li>
# <li><input id="chkEdit37" name="checkboxMenu" type="checkbox" value="ULDDST35700"/> <label for="chkEdit37">자료실</label></li>
# </ul>
# </article>
# </section>
# <div class="clear"></div>
# <div class="wrapper-close">
# <a class="btn_sitemap-close" href="#"><img alt="전체메뉴닫기" src="../images/common/btn_sitemap_close.gif"/></a>
# </div>
# </section>
# <script type="text/javascript">
# $(document).ready(function(){
# 	fnInMyMenu();
# 	sitemap_init();
# });
# var cnt=0;
# function sitemap_init()
# {
# 	if($('section.sitemap').length<1) return;
# 	/*$('a.btn.sitemap.open').bind("click",function(e){
# 		e.preventDefault();
# 		$(this).addClass('hide');
# 		setTimeout(function(){
# 			$('section.sitemap').slideToggle(400);
# 		},200);
# 	});*/
#
# 	$('a.btn.sitemap.open').bind("click focus",function(e){
# 		e.preventDefault();
# 		if(cnt==0){
# 			$(this).addClass('hide');
# 			cnt=1;
# 			setTimeout(function(){
# 				$('section.sitemap').slideToggle(400);
# 			},200);
# 		}else if(cnt==1){
# 			setTimeout(function(){
# 				$('section.sitemap').slideToggle(400);
# 			},200);
# 			setTimeout(function(){
# 				$('a.btn.sitemap.open').removeClass('hide');
# 			},400);
#
# 			cnt=0;
# 		}
# 	});
# 	$('a.btn_sitemap-close').bind("click",function(e){
# 		e.preventDefault();
# 		setTimeout(function(){
# 			$('section.sitemap').slideToggle(400,function(){
# 				cnt=0;
# 				$('a.btn.sitemap.open').removeClass('hide');
# 			});
# 		},100);
# 	});
#
# 	$('section.sitemap a.first').bind("mouseover focus",function(){
# 		$('section.sitemap article').removeClass("active");
# 		$(this).parent().addClass("active");
# 		$(this).parent().parent().parent().addClass("active");
# 	});
# 	$('section.sitemap a.first').bind("mouseout focusout",function(){
# 		$(this).parent().removeClass("active");
# 	});
#
# 	$('section.sitemap span , section.sitemap input[type=checkbox]').bind("mouseover focus",function(){
# 		$('section.sitemap article').removeClass("active");
# 		$(this).parent().parent().addClass("active");
# 		$(this).parent().parent().parent().parent().addClass("active");
# 	});
# 	$('section.sitemap span , section.sitemap input[type=checkbox]').bind("mouseout focusout",function(){
# 		$(this).parent().parent().removeClass("active");
# 	});
#
# 	$('section.sitemap article').bind("mouseleave focusout",function(){
# 		$(this).removeClass("active");
# 	});
# 	$('section.sitemap a.btn_sitemap-set').click(function(e){
# 		e.preventDefault();
# 		if(!$('section.sitemap').hasClass("chkon"))
# 		{
# 			$('section.sitemap section.list-wrapper.links').hide();
# 			$('section.sitemap section.list-wrapper.config').show();
# 			$('section.sitemap').addClass("chkon");
# 			$(this).children("img").attr("src",$(this).children("img").attr("src").replace("_set","_active"));
# 			$(this).children("img").attr("alt","확인");
# 		}
# 		else
# 		{
# 			fnSetCookieMyMenu();
# 			$('section.sitemap section.list-wrapper.links').show();
# 			$('section.sitemap section.list-wrapper.config').hide();
# 			$('section.sitemap').removeClass("chkon");
# 			$(this).children("img").attr("src",$(this).children("img").attr("src").replace("_active","_set"));
# 			$(this).children("img").attr("alt","설정");
# 		}
# 	});
#
# 	try
# 	{
# 		if($.browser.msie && $.browser.version == "7.0") {
# 			$('div.gnb1-wrapper').css("top"	, -3);
# 		}
#
# 		var btnMore = $('div.gnb1-wrapper'); //submenu
# 		var imgArrow = $('#sub nav#gnb1 div.lnb div.wrapper img.arrow'); //화살표
# 		$('section.sitemap a.first').bind("mouseover focus",function(){
# 			fnSubClose(btnMore, -1); //모든 submenu 닫기
# 		});
#
# 		$('section.sitemap article li a.more').each(function(i) {
# 			$(this).bind("mouseover focus",function(){
# 				$(this).parent().addClass("active");
# 				$(this).parent().parent().parent().addClass("active");
# 				$(this).children("span").children("img").attr("src","../images/common/bg_gnb_gmn2_active.gif");
#
# 				fnSubClose(btnMore, i) //모든 submenu 닫기
#
# 				var left1	= $(this).parent().offset().left;
# 				var left2	= $(this).children("span").children("img").offset().left;
# 				var leftVal = left2 - left1 - 2;
# 				if(i == 7){
# 					leftVal = leftVal - 6;
# 				}
# 				imgArrow.eq(i).css("left", leftVal);
# 				btnMore.eq(i).show();
# 			});
#
# 			btnMore.eq(i).bind("mouseleave",function(){
# 				btnMore.eq(i).hide();
# 			});
#
# 			$(this).bind("mouseout focusout",function(){
# 				$(this).parent().removeClass("active");
# 				$(this).children("span").children("img").attr("src","../images/common/bg_gnb_gmn2.gif");
# 			});
# 		});
#
# 	}catch(e){console.error(e.message);}
#
# }
#
# function fnInMyMenu(){
# 	var cookies = GetCookie('krxMenu');
# 	var cookieValue = "";
# 	if(cookies == null ){
# 		cookieValue = cookieValue + "ULDDST00000,오늘의공시/";
# 		cookieValue = cookieValue + "ULDDST00100,회사별검색/";
# 		cookieValue = cookieValue + "ULDDST00300,상세검색/";
# 		cookieValue = cookieValue + "ULDDST00200,통합검색/";
# 		cookieValue = cookieValue + "ULDDST71000,예비심사기업/";
# 		SetCookie('krxMenu',cookieValue ,'7');
# 	} else {
#
# 	}
#
# 	fnUpdateInMyMenu();
# }
#
# function fnSetCookieMyMenu(){
# 	var cookieValue = "";
# 	$('input:checkbox[name="checkboxMenu"]:checked').each(function(){
# 		var menuName = $("label[for="+this.id+"]").text().replace("/","");
# 		cookieValue += $(this).val()+","+menuName+"/";
# 	});
# 	SetCookie('krxMenu',cookieValue ,'7');
# 	fnUpdateInMyMenu();
# }
#
# function fnUpdateInMyMenu(){
# 	var cookies = GetCookie('krxMenu');
# 	if(cookies != null ){
# 		$("#myMenuTop").empty();
# 		var items = cookies.split("/");
# 		for(var i in items){
# 			var item = items[i].split(",");
# 			var menuId	 = item[0];
# 			var menuName = item[1];
# 			if(undefined != menuName){
# 				var url = fnGetInMyMenuUrl(menuId);
# 				$("#myMenuTop").append("<li><a href='"+url+"'>"+menuName+"</a></li>");
# 			}
#
# 			$('input:checkbox[name="checkboxMenu"]').each(function(){
# 				if($(this).val() == menuId)
# 					this.checked = true;
# 			});
# 		}
# 	}
# }
#
# function fnGetInMyMenuUrl(menuId){
#
# 	var url = {
# 			"ULDDST00000":"/disclosure/todaydisclosure.do?method=searchTodayDisclosureMain",						/*오늘의공시*/
# 			"ULDDST00100":"/disclosure/searchdisclosurebycorp.do?method=searchDisclosureByCorpMain",				/*회사별검색*/
# 			"ULDDST00300":"/disclosure/details.do?method=searchDetailsMain",										/*상세검색*/
# 			"ULDDST00200":"/disclosure/searchtotalinfo.do?method=searchTotalInfoMain",								/*통합검색*/
# 			"ULDDST00700":"/disclosure/searchbondcorpdisclosure.do?method=searchBondCorpDisclosureMain",			/*채권공시*/
# 			"ULDDST00400":"/disclosure/disclosurebystocktype.do?method=searchDisclosureByStockTypeEtf",				/*ETF/ELW/ETN*/
# 			"JLDDST00403":"/disclosure/disclosurebystocktype.do?method=searchDisclosureByStockTypeRestinvstcom",	/*펀드공시*/
# 			"ULDDST01300":"/disclosure/misccorpdiscls.do?method=searchMiscCorpDisclsMain",							/*기타법인공시*/
# 			"ULDDST01500":"/disclosure/disclosurebyvote.do?method=searchDisclosurebyVoteMain",						/*의결권공시*/
# 			"ULDDST10400":"/corpdetail/chart.do?method=loadInitPage",												/*공시차트*/
# 			"ULDDST01600":"/disclosure/searchErrorTradeRelief.do?method=searchErrorTradeReliefMain",				/*착오매매구제신청*/
# 			"ULDDST10000":"/corpdetail/totalinfo.do?method=loadInitPage",	/*종합정보*/
# 			"ULDDST05000":"/corpgeneral/listedIssueStatus.do?method=loadInitPage",	/*상장종목현황*/
# 			"ULDDST05100":"/corpgeneral/corpList.do?method=loadInitPage",	/*상장법인목록*/
# 			"ULDDST38150":"/corpgeneral/companyGovernance.do?method=loadInitPage", /*기업지배구조*/
# 			//"ULDDST20000":"/digital/digitalList.do?method=digitalList",				/* 신종증권 메뉴 제외  */
# 			"ULDDST06000":"/corpgeneral/stockissuelist.do?method=loadInitPage",	/*주식발행내역*/
# 			"ULDDST05300":"/corpgeneral/treasurystk.do?method=loadInitPage",	/*자사추취득처분*/
# 			"ULDDST05600":"/corpgeneral/irschedule.do?method=searchIRScheduleMain&gubun=iRScheduleCalendar",	/*IR일정IR자료실*/
# 			"ULDDST38010":"/corpgeneral/companyAnalysisReport.do?method=listingForeignCompanyMain&searchGubun=companyAnalysisReport",	/*기업분석보고서*/
# 			"ULDDST05800":"/corpgeneral/corpGroup.do?method=loadInitPage",	/*기업진단*/
# 			"ULDDST36400":"/disclosureinfo/dividendinfo.do?method=searchDividendInfoMain",	/*배당정보*/
# 			"ULDDST15400":"/compfinance/financialinfo.do?method=loadInitPage&searchgubun=corporation",	/*회사재무비교*/
# 			"JLDDST38140":"/corpgeneral/excntDisclsCompany.do?method=loadInitPage",	/*공시우수법인*/
# 			"JLDDST11000":"/corpdetail/ventureFundInvest.do?method=corpListMain",	/*벤처펀드투자기업(코)*/
# 			//"JLDDST30200":"/digital/digitalCorpList.do?method=digitalCorpList",	/*신종증권 상장종목(신종증권) - 신종증권 메뉴 제외*/
#
# 			"ULDDST80100":"/valueup/intro.do?method=valueupIntroMain",	/*기업밸류업소개*/
# 			"ULDDST80200":"/valueup/notice.do?method=valueupNoticeMain",	/*공지사항*/
# 			"ULDDST80300":"/valueup/disclsstat.do?method=valueupDisclsStatMain",	/*공시현황*/
# 			"ULDDST80400":"/valueup/invstindicsectors.do?method=valueupInvstIndicRankIndMain",	/*투자지표*/
# 			"ULDDST80500":"/valueup/idx.do?method=valueupIdxMain",	/*인덱스*/
# 			"ULDDST80600":"/valueup/excntcorp.do?method=valueupExcntCorpMain",	/*기업 밸류업 우수법인*/
# 			"ULDDST80700":"/valueup/resoroom.do?method=valueupResoroomMain",	/*자료실*/
#
# 			"ULDDST30000":"/investwarn/adminissue.do?method=searchAdminIssueList",	/*관리종목*/
# 			"ULDDST30900":"/investwarn/hwangiissue.do?method=searchHwangiIssueMain",	/*투자주의환기종목(코)*/
# 			"ULDDST30400":"/investwarn/tradinghaltissue.do?method=searchTradingHaltIssueMain",	/*매매거래정지종목*/
# 			"ULDDST30100":"/investwarn/undisclosure.do?method=searchUnfaithfulDisclosureCorpList",	/*불성실공시법인*/
# 			"ULDDST30500":"/investwarn/investattentwarnrisky.do?method=investattentwarnriskyMain",	/*투자주의-경고-위험종목*/
# 			"ULDDST05900":"/corpgeneral/delistRealInvstg.do?method=searchDelistRealInvstgMain",	/*실질심사법인*/
# 			"ULDDST30301":"/investwarn/investattentEmbezzlement.do?method=searchInvestAttentEmbezzlementMain",	/*횡령 등*/
# 			"ULDDST30302":"/investwarn/investattentLargeShareChange.do?method=searchInvestAttentLargeShareChangeMain",	/*최대주주변경2회이상*/
# 			"ULDDST30301":"/investwarn/investattentEtcMarket.do?method=searchInvestAttentEtcMarketMain",	/*기타사항*/
#
# 			"ULDDST71000":"/listinvstg/listinvstgcom.do?method=searchListInvstgCorpMain",		/*예비심사기업*/
# 			"ULDDST71100":"/listinvstg/listapplcom.do?method=searchListApplCorpMain",			/*코넥스상장신청기업*/
# 			"ULDDST72000":"/listinvstg/pubofrprogcom.do?method=searchPubofrProgComMain",		/*공모기업*/
# 			"ULDDST70000":"/listinvstg/listingcompany.do?method=searchListingTypeMain",			/*신규상장기업*/
# 			"ULDDST73000":"/listinvstg/listtypestat.do?method=searchListTypeStatusMain",		/*신규상장통계*/
# 			"ULDDST75000":"/listinvstg/listinvstginfo.do?method=searchListInvstgInfoMain",		/*상장심사가이드*/
#
# 			"ULDDST35100":"/disclosureinfo/notice.do?method=searchNoticeMain",	/*공지사항*/
# 			//"ULDDST25000":"/news/searchnews.do?method=searchNewsMain", /*증시뉴스*/
# 			"ULDDST35400":"/disclosureinfo/explanationsystem.do?method=searchSysInfo",	/*제도해설*/
# 			"ULDDST35700":"/disclosureinfo/searchmaterials.do?method=searchMaterialsMain"	/*자료실*/
#
# 	}
#
# 	return url[menuId];
# }
#
# function fnSubClose(array, i)
# {
# 	for(var a=0;a<array.length;a++){
# 		if(a != i){ array.eq(a).hide(); }
# 	}
# }
#
# </script>
# <!-- TOP MENU END -->
# </div>
# <div class="gnb-wrapper">
# <nav id="gnb">
# <dl>
# <dt><a href="/">홈</a></dt>
# <!-- Lv1 -->
# <dd>
# <a class="gmn" href="#">상장법인상세정보</a>
# <div class="lnb">
# <div class="wrapper">
# <a class="lmn" href="/disclosure/todaydisclosure.do?method=searchTodayDisclosureMain">공시</a>
# <a class="lmn active" href="/corpdetail/totalinfo.do?method=loadInitPage">상장법인상세정보</a>
# <a class="lmn" href="/valueup/intro.do?method=valueupIntroMain">기업 밸류업 정보</a>
# <a class="lmn" href="/investwarn/adminissue.do?method=searchAdminIssueList">투자유의사항</a>
# <a class="lmn" href="/listinvstg/listinvstgcom.do?method=searchListInvstgCorpMain">IPO현황</a>
# <a class="lmn" href="/disclosureinfo/notice.do?method=searchNoticeMain">정보실</a>
# <img class="arrow" src="../images/common/lnb_arrow.png"/>
# <img class="tl" src="../images/common/lnb_tl.png"/>
# <img class="tr" src="../images/common/lnb_tr.png"/>
# <img class="bl" src="../images/common/lnb_bl.png"/>
# <img class="br" src="../images/common/lnb_br.png"/>
# </div>
# </div>
# </dd>
# <!-- Lv2 -->
# <dd>
# <a class="gmn" href="#">상장법인목록</a>
# <div class="lnb">
# <div class="wrapper">
# <a class="lmn" href="/corpdetail/totalinfo.do?method=loadInitPage">종합정보</a>
# <a class="lmn" href="/corpgeneral/listedIssueStatus.do?method=loadInitPage">상장종목현황</a>
# <a class="lmn active" href="/corpgeneral/corpList.do?method=loadInitPage">상장법인목록</a>
# <a class="lmn" href="/corpgeneral/stockissuelist.do?method=loadInitPage">주식발행내역</a>
# <a class="lmn" href="/corpgeneral/companyGovernance.do?method=loadInitPage">기업지배구조</a>
# <a class="lmn" href="/corpgeneral/treasurystk.do?method=loadInitPage">자사주취득/처분</a>
# <a class="lmn" href="/corpgeneral/irschedule.do?method=searchIRScheduleMain&amp;gubun=iRScheduleCalendar">IR일정/IR자료실</a>
# <a class="lmn" href="/corpgeneral/companyAnalysisReport.do?method=listingForeignCompanyMain&amp;searchGubun=companyAnalysisReport">기업분석보고서</a>
# <a class="lmn" href="/corpgeneral/corpGroup.do?method=loadInitPage">기업집단</a>
# <a class="lmn" href="/disclosureinfo/dividendinfo.do?method=searchDividendInfoMain">배당정보</a>
# <a class="lmn" href="/compfinance/financialinfo.do?method=loadInitPage&amp;searchgubun=corporation">회사재무비교</a>
# <a class="lmn" href="/corpgeneral/excntDisclsCompany.do?method=loadInitPage">공시우수법인</a>
# <a class="lmn" href="/corpdetail/ventureFundInvest.do?method=corpListMain">벤처펀드투자기업(코)</a>
# <img class="arrow" src="../images/common/lnb_arrow.png"/>
# <img class="tl" src="../images/common/lnb_tl.png"/>
# <img class="tr" src="../images/common/lnb_tr.png"/>
# <img class="bl" src="../images/common/lnb_bl.png"/>
# <img class="br" src="../images/common/lnb_br.png"/>
# </div>
# </div>
# </dd>
# <!-- Lv3 -->
# <!-- Lv4 -->
# </dl>
# </nav>
# </div>
# <nav class="aside">
# <dl>
# <dt><a href="#"><span>마이페이지</span></a></dt>
# <dd class="mymenu first">
# <a class="bmn" href="#"><span>나만의 메뉴</span></a>
# <div class="list">
# <a class="btn-prev" href="#"><span>이전</span></a>
# <div class="inner">
# <ul class="slider" id="myMenu">
# <li></li>
# </ul>
# </div>
# <a class="btn-next" href="#"><span>다음</span></a>
# </div>
# </dd>
# <dd class="cache_company">
# <a class="bmn" href="#"><span>내가 본 회사</span></a>
# <div class="list">
# <a class="btn-prev" href="#"><span>이전</span></a>
# <div class="inner">
# <ul class="slider" id="myMenuCorp">
# <li></li>
# </ul>
# </div>
# <a class="btn-next" href="#"><span>다음</span></a>
# </div>
# </dd>
# <dd class="cache_disclosure">
# <a class="bmn" href="#"><span>내가 본 공시</span></a>
# <div class="list">
# <a class="btn-prev" href="#"><span>이전</span></a>
# <div class="inner">
# <ul class="slider" id="myMenuDisclosure">
# <li><a href="#"></a></li>
# </ul>
# </div>
# <a class="btn-next" href="#"><span>다음</span></a>
# </div>
# </dd>
# <dd class="link_top">
# <a class="bmn top" href="#"><span>위로</span></a>
# </dd>
# </dl>
# </nav>
# <script type="text/javascript">
# $(document).ready(function(){
# 	fnMyPage();
# 	fnMyCrop();
# 	fnMyDisclosure();
# });
#
# function fnMyPage(){
# 	var cookies = GetCookie('krxMenu');
# 	if(cookies != null ){
# 		$("#myMenu").empty();
# 		var items = cookies.split("/");
# 		for(var i in items){
# 			var item = items[i].split(",");
# 			var menuId	 = item[0];
# 			var menuName = item[1];
# 			if(undefined != menuName){
# 				var url = fnGetInMyMenuUrl(menuId);
# 				$("#myMenu").append("<li><a href='"+url+"' title='"+menuName+"'>"+menuName+"</a></li>");
# 			}
# 		}
# 	}
# }
#
# function fnMyCrop(){
# 	var cookieName	= "krxComp";
# 	var cookies		= GetCookie(cookieName);
# 	if(cookies != null ){
# 		$("#myMenuCorp").empty();
# 		var items = cookies.split("/");
# 		for(var i in items){
# 			var item = items[i].split(",");
# 			var repIsuSrtCd	= item[1];
# 			var corpName	= item[2];
# 			var isurcd		= item[3];
# 			if(undefined != corpName || undefined != isurcd){
# 				var url = "/disclosureSimpleSearch.do?method=disclosureSimpleSearchMain&repIsuSrtCd="+repIsuSrtCd+"&isurCd="+isurcd+"&searchCorpName="+corpName;
# 				$("#myMenuCorp").append("<li><a href=\""+url+"\" title=\""+corpName+" 검색\">"+corpName+"</a></li>");
# 			}
# 		}
# 	}
# }
#
# function fnMyDisclosure(){
# 	var cookies = GetCookie('krxDisc');
# 	if(cookies != null ){
# 		$("#myMenuDisclosure").empty();
# 		var items = cookies.split("/");
# 		for(var i in items){
# 			var item = items[i].split(",");
# 			var acptNo	= item[1];
# 			var title	= item[0];
# 			if("" != title && undefined != acptNo){
# 				$("#myMenuDisclosure").append("<li class='ellipsis'><a href=\"#\" onclick=\"openDisclsViewer('"+acptNo+"','');\">"+title+"</a></li>");
# 			}
# 		}
# 	}
# }
#
# function fnGuidePop(){
# 	window.open("../common/guide.html","KIND소개","top=100,left=100,width=870,height=700,scrollbars=yes,toolbar=no,resizable=yes");
# }
#
# </script>
# </header>
# <!-- HEADER 영역 END -->
# <section class="wrapper-contents">
# <!-- 본문영역 START -->
# <section class="contents">
# <hgroup class="title type-00">
# <h1 id="titleValue">상장법인목록</h1>
# </hgroup>
# <form id="searchForm" method="post" name="searchForm" onsubmit="return false;">
# <input id="method" name="method" type="hidden" value=""/>
# <input id="pageIndex" name="pageIndex" type="hidden" value="1"/>
# <input id="currentPageSize" name="currentPageSize" type="hidden" value="15"/>
# <input id="comAbbrv" name="comAbbrv" type="hidden" value=""/>
# <input id="beginIndex" name="beginIndex" type="hidden" value=""/>
# <input id="orderMode" name="orderMode" type="hidden" value=""/>
# <input id="orderStat" name="orderStat" type="hidden" value=""/>
# <input id="isurCd" name="isurCd" type="hidden" value=""/><!-- 발행기관코드 -->
# <input id="repIsuSrtCd" name="repIsuSrtCd" type="hidden" value=""/><!-- 대표종목단축코드 -->
# <input id="searchCodeType" name="searchCodeType" type="hidden" value=""/> <!--number:종목코드 char:종목명-->
# <section class="search-group type-00">
# <div class="wrapper">
# <div class="form-search type-00 type-multi">
# <table summary="시장구분,회사명,업종,결산월,검색유형,지역">
# <caption>조회</caption>
# <colgroup>
# <col width="80"/>
# <col width="44%"/>
# <col width="70"/>
# <col width="*"/>
# </colgroup>
# <tbody>
# <tr class="first">
# <th scope="row"><label for="rAll">시장구분</label></th>
# <td>
# <input checked="checked" class="rad-00" id="rAll" name="marketType" title="전체" type="radio" value=""/> <label for="rAll">전체</label>
# <input class="rad-00" id="rWertpapier" name="marketType" title="유가증권" type="radio" value="stockMkt"/> <label for="rWertpapier">유가증권</label>
# <input class="rad-00" id="rKosdaq" name="marketType" title="코스닥" type="radio" value="kosdaqMkt"/> <label for="rKosdaq">코스닥</label>
# <input class="rad-00" id="rKonex" name="marketType" title="코넥스" type="radio" value="konexMkt"/> <label for="rKonex">코넥스</label>
# </td>
# <th scope="row"><label for="select_2_0">검색유형</label></th>
# <td>
# <select class="middle" id="searchType" name="searchType" style="width:235px;">
# <option selected="selected" value="13">상장법인</option>
# <option value="01">관리종목</option>
# <option value="05">불성실공시법인</option>
# <option value="07">자산2조법인</option>
# <option value="99">외국법인</option>
# <option value="191">코스닥 글로벌 세그먼트</option>
# <option value="QGG03P">(코스닥) 우량기업부</option>
# <option value="QGG04P">(코스닥) 벤처기업부</option>
# <option value="QGG05P">(코스닥) 중견기업부</option>
# <option value="QGG06P">(코스닥) 기술성장기업부</option>
# <option value="18">코리아밸류업</option> <!-- 코리아밸류업지수 추가 2024.11.28 -->
# <option value="06">KOSPI200</option>
# <option value="16">KOSDAQ150</option>
# <option value="17">KRX300</option>
# <option value="15">KTOP30</option>
# </select>
# </td>
# </tr>
# <tr>
# <th scope="row"><label for="select_1_0">업종</label></th>
# <td>
# <select class="middle" id="industry" name="industry" style="width:290px;">
# <option value="">전체</option>
# <option value="01">농업, 임업 및 어업</option>
# <option value="02">광업</option>
# <option value="03">제조업</option>
# <option value="0310"> - 식료품 제조업</option>
# <option value="0311"> - 음료 제조업</option>
# <option value="0312"> - 담배 제조업</option>
# ...
# <li><a class="ord-07" href="#" id="btnType" onclick="fnBtnType('H', '7'); return false;" title="ㅇ"><span>ㅇ</span></a></li>
# <li><a class="ord-08" href="#" id="btnType" onclick="fnBtnType('I', '8'); return false;" title="ㅈ"><span>ㅈ</span></a></li>
# <li><a class="ord-09" href="#" id="btnType" onclick="fnBtnType('J', '9'); return false;" title="ㅊ"><span>ㅊ</span></a></li>
# <li><a class="ord-10" href="#" id="btnType" onclick="fnBtnType('K', '10'); return false;" title="ㅋ"><span>ㅋ</span></a></li>
# <li><a class="ord-11" href="#" id="btnType" onclick="fnBtnType('L', '11'); return false;" title="ㅌ"><span>ㅌ</span></a></li>
# <li><a class="ord-12" href="#" id="btnType" onclick="fnBtnType('M', '12'); return false;" title="ㅍ"><span>ㅍ</span></a></li>
# <li><a class="ord-13" href="#" id="btnType" onclick="fnBtnType('N', '13'); return false;" title="ㅎ"><span>ㅎ</span></a></li>
# <li><a class="ord-14" href="#" id="btnType" onclick="fnBtnType('AZ', '14'); return false;" title="A-Z"><span>A-Z</span></a></li>
# <li><a class="ord-15" href="#" id="btnType" onclick="fnBtnType('ETC', '15'); return false;" title="기타"><span>기타</span></a></li>
# </ul>
# </div>
# <div class="clear"></div>
# <div class="btn-group type-bt">
# <a class="btn-sprite type-00 vmiddle search-btn" href="#" onclick="fnSearchWithoutIndex(); return false;" title="검색"><span>검색</span></a>
# <a class="btn-sprite type-00 vmiddle xls-btn" href="#" onclick="fnDownload(); return false;" title="EXCEL"><span>EXCEL</span></a>
# </div>
# </div>
# </section>
# </form>
# <article class="pcontents" id="main-contents">
# </article>
# <script type="text/JavaScript">
# document.onkeypress = function(e){
# 	var result = "";
# 	if(typeof(e)!='undefined'){
# 		result = e.which;
# 	}else{
# 		result = event.keyCode;
# 	}
# 	keyEvent(result);
# }
#
# function keyEvent(e){
# 	if(document.all){//IE
# 		if(window.event.keyCode==13){
# 			fnSearchWithoutIndex();
# 		}
# 	}else{
# 		if(e==13){
# 			fnSearchWithoutIndex();
# 		}
# 	}
# }
#
#
# $(document).ready(function(){
# 	fnInit();
# });
#
#
# function fnInit(){
# 	fnOrder("3", "D");
# }
# /*
# *
# *법인명, 종목코드, 일자, 적용구분의 order by 조건
# */
# function fnOrder(mode, stat){
# 	$("#searchForm > #orderMode").val(mode);
# 	$("#searchForm > #orderStat").val(stat);
# 	$("#searchForm > #pageIndex").val("1");
#
# 	fnSearch();
# }
#
# function fnSearch1() {
# 	$("#searchForm > #pageIndex").val("1");
# 	$("#searchForm > #currentPageSize").val($(document).find("select[id=currentPageSize]").val());
# 	fnSearch();
# }
#
# function fnSearchWithoutIndex(){
# 	$("#searchForm > #beginIndex").val("");
# 	fnClearBtnType();
# 	fnInit();
# }
#
# function fnClearBtnType(){
# 	$(document).find("a[id=btnType]").each(function(){
# 		if($(this).hasClass("active")) {
# 			$(this).removeClass("active");
# 		}
# 	});
# }
#
# function fnSetCorpName(str){
# 	$("#searchForm > #comAbbrv").val(encodeURI(str));
# }
#
# function fnClearCorpName(){
# 	$("#searchForm > #comAbbrv").val("");
# 	$("#searchForm").find("input:text[name=comAbbrvTmp]").val("");
# }
#
# function fnSearch(){
#     fnSetCorpName($("#searchForm").find("input:text[name=comAbbrvTmp]").val());
#
#     if($(document).find("select[id=currentPageSize]").val() != undefined) {
#     	$("#searchForm > #currentPageSize").val($(document).find("select[id=currentPageSize]").val());
#     }
# 	$("#searchForm > #method").val("searchCorpList");
# 	$("#searchForm").ajaxSubmit({
# 		  ajaxUrl : '/corpgeneral/corpList.do'
# 		, ajaxCallBack: fnSearchCallBack
# 	});
# }
#
# function fnSearchCallBack(data){
# 	$("#main-contents").empty().append(data);
# 	$("tr:odd").addClass("active");
#
# 	fnLegendTooltip();
# }
#
# function fnDownload(){
# 	$("#searchForm").attr('onsubmit', '');
# 	$("#searchForm > #currentPageSize").val("3000");
# 	$("#searchForm > #pageIndex").val("1");
# 	$("#searchForm > #method").val("download");
# 	$("#searchForm").attr('action', '/corpgeneral/corpList.do').submit();
# 	$("#searchForm").attr('onsubmit', 'return false;');
# }
#
# /** 법인명찾기 팝업의 자바스크립트에서 호출하는 Callback 함수 */
# function setCorpInfo(isurCd, kisComCd, repIsuSrtCd, comNm, comAbbrv, isurSymbl, fssUnqNo){
#
#     var  str = "";
#             str += "isurCd : " + isurCd + "\n";
#             str += "kisComCd : " + kisComCd + "\n";
#             str += "repIsuSrtCd : " + repIsuSrtCd + "\n";
#             str += "comNm : " + comNm + "\n";
#             str += "comAbbrv : " + comAbbrv + "\n";
#             str += "isurSymbl : " + isurSymbl + "\n";
#             str += "fssUnqNo : " + fssUnqNo + "\n";
#     //alert(str);
#
#     $("#searchForm").find("input:text[name=comAbbrvTmp]").val(comAbbrv);	//법인명
#     $("#searchForm > #repIsuSrtCd").val("A"+repIsuSrtCd);					//법인코드
#     $("#searchForm > #searchCodeType").val("char");							//법인코드
# }
#
# function fnBtnType(type, idx){
#
# 	fnClearBtnType();
# 	fnClearCorpName();
#
# 	$("#searchForm > #pageIndex").val("1");
# 	$("#searchForm > #isurCd").val("");
# 	$("#searchForm > #repIsuSrtCd").val("");
# 	$("#searchForm > #beginIndex").val(type);
#
# 	$(document).find("a[id=btnType]").each(function(index){
# 		if(idx == index) {
# 			if(!$(this).hasClass("active")) {
# 				$(this).addClass("active");
# 			}
# 		}
# 	});
#
# 	fnInit();
# }
#
# </script>
# </section>
# <!-- 본문영역 END -->
# <!-- 오른쪽 메뉴 START -->
# <aside class="contents">
# <h3><span class="">상장법인상세정보</span></h3>
# <ul>
# <li><a class="" href="/corpdetail/totalinfo.do?method=loadInitPage">종합정보</a><div class="dash"></div></li>
# <li><a class="" href="/corpgeneral/listedIssueStatus.do?method=loadInitPage">상장종목현황</a><div class="dash"></div></li>
# <li><a class="active" href="/corpgeneral/corpList.do?method=loadInitPage">상장법인목록</a><div class="dash"></div></li>
# <li><a class="" href="/corpgeneral/stockissuelist.do?method=loadInitPage">주식발행내역</a><div class="dash"></div></li>
# <li><a class="" href="/corpgeneral/companyGovernance.do?method=loadInitPage">기업지배구조</a><div class="dash"></div></li>
# <li><a class="" href="/corpgeneral/treasurystk.do?method=loadInitPage">자사주취득/처분</a><div class="dash"></div></li>
# <li><a class="" href="/corpgeneral/irschedule.do?method=searchIRScheduleMain&amp;gubun=iRScheduleCalendar">IR일정/IR자료실</a><div class="dash"></div></li>
# <li><a class="" href="/corpgeneral/companyAnalysisReport.do?method=listingForeignCompanyMain&amp;searchGubun=companyAnalysisReport">기업분석보고서</a><div class="dash"></div></li>
# <li><a class="" href="/corpgeneral/corpGroup.do?method=loadInitPage">기업집단</a><div class="dash"></div></li>
# <li><a class="" href="/disclosureinfo/dividendinfo.do?method=searchDividendInfoMain">배당정보</a><div class="dash"></div></li>
# <li><a class="" href="/compfinance/financialinfo.do?method=loadInitPage&amp;searchgubun=corporation">회사재무비교</a><div class="dash"></div></li>
# <li><a class="" href="/corpgeneral/excntDisclsCompany.do?method=loadInitPage">공시우수법인</a><div class="dash"></div></li>
# <li><a class="" href="/corpdetail/ventureFundInvest.do?method=corpListMain">벤처펀드투자기업(코)</a><div class="dash"></div></li>
# </ul>
# <form name="menuUrlFrm">
# <input name="menuUrl" type="hidden" value="/corpgeneral/corpList.do?method=loadInitPage"/>
# </form>
# </aside>
# <!-- 오른쪽 메뉴 END -->
# <div class="clear"></div>
# </section>
# <!-- FOOTER 영역 START -->
# <footer class="container">
# <section class="footer_map">
# <div class="wrapper">
# <article class="list first">
# <h3>공시</h3>
# <ul>
# <li><a href="/disclosure/todaydisclosure.do?method=searchTodayDisclosureMain">오늘의공시</a></li>
# <li><a href="/disclosure/searchdisclosurebycorp.do?method=searchDisclosureByCorpMain">회사별검색</a></li>
# <li><a href="/disclosure/details.do?method=searchDetailsMain">상세검색</a></li>
# <li><a href="#" onclick="krxPaPago_open(); return false;">KRX-Papago번역기</a></li>
# <li><a href="/disclosure/searchtotalinfo.do?method=searchTotalInfoMain">통합검색</a></li>
# <li><a href="/disclosure/searchbondcorpdisclosure.do?method=searchBondCorpDisclosureMain">채권공시</a></li>
# <li><a href="/disclosure/disclosurebystocktype.do?method=searchDisclosureByStockTypeEtf">ETF / ELW / ETN</a></li>
# <li><a href="/disclosure/disclosurebystocktype.do?method=searchDisclosureByStockTypeRestinvstcom">펀드공시</a></li>
# <li><a href="/disclosure/misccorpdiscls.do?method=searchMiscCorpDisclsMain">기타법인공시</a></li>
# <li><a href="/disclosure/disclosurebyvote.do?method=searchDisclosurebyVoteMain">의결권행사공시</a></li>
# <li><a href="/corpdetail/chart.do?method=loadInitPage">공시차트</a></li>
# <li><a href="/disclosure/searchErrorTradeRelief.do?method=searchErrorTradeReliefMain">착오매매구제신청</a></li>
# <!-- 신종증권 메뉴 제외 -->
# <!--<li><a href="/digital/digitalList.do?method=digitalList">신종증권</a></li>--><!-- 20231201 신종증권 추가 -->
# </ul>
# </article>
# <article class="list">
# <h3>상장법인상세정보</h3>
# <ul>
# <li><a href="/corpdetail/totalinfo.do?method=loadInitPage">종합정보</a></li>
# <li><a href="/corpgeneral/listedIssueStatus.do?method=loadInitPage">상장종목현황</a></li>
# <li><a href="/corpgeneral/corpList.do?method=loadInitPage">상장법인목록</a></li>
# <li><a href="/corpgeneral/stockissuelist.do?method=loadInitPage">주식발행내역</a></li>
# <li><a href="/corpgeneral/companyGovernance.do?method=loadInitPage">기업지배구조</a></li>
# <li><a href="/corpgeneral/treasurystk.do?method=loadInitPage">자사주취득/처분</a></li>
# <li><a href="/corpgeneral/irschedule.do?method=searchIRScheduleMain&amp;gubun=iRScheduleCalendar">IR일정/IR자료실</a></li>
# <li><a href="/corpgeneral/companyAnalysisReport.do?method=listingForeignCompanyMain&amp;searchGubun=companyAnalysisReport">기업분석보고서</a></li>
# <li><a href="/corpgeneral/corpGroup.do?method=loadInitPage">기업집단</a></li>
# <li><a href="/disclosureinfo/dividendinfo.do?method=searchDividendInfoMain">배당정보</a></li>
# <li><a href="/compfinance/financialinfo.do?method=loadInitPage&amp;searchgubun=corporation">회사재무비교</a></li>
# <li><a href="/corpgeneral/excntDisclsCompany.do?method=loadInitPage">공시우수법인</a></li>
# <li><a href="/corpdetail/ventureFundInvest.do?method=corpListMain">벤처펀드투자대상기업(코)</a></li>
# <!-- 신종증권 메뉴 제외 -->
# <!--<li><a href="/digital/digitalCorpList.do?method=digitalCorpList">상장종목(신종증권)</a></li>--><!-- 20231201 신종증권 추가 -->
# </ul>
# </article>
# <article class="list">
# <h3>기업 밸류업 정보</h3>
# <ul>
# <li><a href="/valueup/intro.do?method=valueupIntroMain">기업 밸류업 소개</a></li>
# <li><a href="/valueup/notice.do?method=valueupNoticeMain">공지사항</a></li>
# <li><a href="/valueup/disclsstat.do?method=valueupDisclsStatMain">공시현황</a></li>
# <li><a href="/valueup/invstindicsectors.do?method=valueupInvstIndicRankIndMain">투자지표</a></li>
# <li><a href="/valueup/idx.do?method=valueupIdxMain">인덱스</a></li>
# <li><a href="/valueup/excntcorp.do?method=valueupExcntCorpMain">기업 밸류업 우수법인</a></li>
# <li><a href="/valueup/resoroom.do?method=valueupResoroomMain">자료실</a></li>
# </ul>
# </article>
# <article class="list">
# <h3>투자유의사항</h3>
# <ul>
# <li><a href="/investwarn/adminissue.do?method=searchAdminIssueList">관리종목</a></li>
# <li><a href="/investwarn/hwangiissue.do?method=searchHwangiIssueMain">투자주의환기종목(코)</a></li>
# <li><a href="/investwarn/tradinghaltissue.do?method=searchTradingHaltIssueMain">매매거래정지종목</a></li>
# <li><a href="/investwarn/undisclosure.do?method=searchUnfaithfulDisclosureCorpList">불성실공시법인</a></li>
# <li><a href="/investwarn/investattentwarnrisky.do?method=investattentwarnriskyMain">투자주의/경고/위험종목</a></li>
# <li><a href="/corpgeneral/delistRealInvstg.do?method=searchDelistRealInvstgMain">실질심사법인</a></li>
# <li><a href="/investwarn/investattentEmbezzlement.do?method=searchInvestAttentEmbezzlementMain">횡령 등</a></li>
# <li><a href="/investwarn/investattentLargeShareChange.do?method=searchInvestAttentLargeShareChangeMain">최대주주변경2회이상</a></li>
# <li><a href="/investwarn/investattentEtcMarket.do?method=searchInvestAttentEtcMarketMain">기타사항</a></li>
# </ul>
# </article>
# <article class="list">
# <h3>IPO현황</h3>
# <ul>
# <li><a href="/listinvstg/listinvstgcom.do?method=searchListInvstgCorpMain">예비심사기업</a></li>
# <li><a href="/listinvstg/listapplcom.do?method=searchListApplCorpMain">코넥스 상장신청기업</a></li>
# <li><a href="/listinvstg/pubofrprogcom.do?method=searchPubofrProgComMain">공모기업</a></li>
# <li><a href="/listinvstg/listingcompany.do?method=searchListingTypeMain">신규상장기업</a></li>
# <li><a href="/listinvstg/listtypestat.do?method=searchListTypeStatusMain">신규상장통계</a></li>
# <li><a href="/listinvstg/listinvstginfo.do?method=searchListInvstgInfoMain">상장심사가이드</a></li>
# </ul>
# <br/>
# <h3>정보실</h3>
# <ul>
# <li><a href="/disclosureinfo/notice.do?method=searchNoticeMain">공지사항</a></li>
# <!--  li><a href="/news/searchnews.do?method=searchNewsMain">증시뉴스</a></li -->
# <li><a href="/disclosureinfo/explanationsystem.do?method=searchSysInfo">제도해설</a></li>
# <li><a href="/disclosureinfo/searchmaterials.do?method=searchMaterialsMain">자료실</a></li>
# </ul>
# </article>
# <div class="clear"></div>
# </div>
# </section>
# <section class="footer">
# <div class="wrapper">
# <h5 class="logo"><img alt="대한민국 대표 기업공시채널 KIND" src="../images/main/logo_bt.gif"/></h5>
# <nav class="util">
# <ul>
# <li class="first"><a href="#" onclick="winCommPopOpen('2'); return false;">운영기관안내</a></li>
# <li><a href="http://info.krx.co.kr/contents/KRX/06/06070600/KRX06070600.jsp" target="_blank" title="이용자유의사항 새창">이용자유의사항</a></li>
# <li><a href="http://info.krx.co.kr/contents/KRX/06/06070200/KRX06070200.jsp" target="_blank" title="법적고지 새창">법적고지</a></li>
# <li><a href="http://info.krx.co.kr/contents/KRX/06/06070100/KRX06070100.jsp" target="_blank" title="개인정보처리방침 새창">개인정보처리방침</a></li>
# <li><a href="#" onclick="winCommPopOpen('5'); return false;">뷰어다운로드</a></li>
# </ul>
# <div class="clear"></div>
# </nav>
# <div class="copyright">
# 		본 사 : (우) 48400 부산광역시 남구 문현금융로 40(문현동)  TEL : 051-662-2000   사업자등록번호 : 602-81-35420 <br/>
# 		서 울 : (우) 07329 서울특별시 영등포구 여의나루로 76(여의도동)  TEL : 1577-0088, 02-3774-9000 / 통신판매업신고 부산동구004호<br/>
# 		Copyright(c) 2014 by KOREA EXCHANGE. All rights reserved.
# 		</div>
# </div>
# </section>
# </footer>
# <!-- FOOTER 영역 START -->
# <!-- 범례 START -->
# <div id="marketSection" style="position:absolute; display:none">
# <section class="icn_tbox" style="width:400px;top:-30px; left:10px">
# <ul>
# <li>
# <img alt="유가증권" class="vmiddle" src="../images/common/icn_t_yu.gif"/> 유가증권
# 			</li>
# <li>
# <img alt="코스닥" class="vmiddle" src="../images/common/icn_t_ko.gif"/> 코스닥
# 			</li>
# <li>
# <img alt="코넥스" class="vmiddle" src="../images/common/icn_t_konex.gif"/> 코넥스
# 			</li>
# <li>
# <img alt="관리종목" class="vmiddle" src="../images/common/icn_t_kwan.gif"/> 관리종목
# 			</li>
# <li>
# <img alt="투자주의환기종목" class="vmiddle" src="../images/common/icn_t_hwan.gif"/> 투자주의환기종목
# 			</li>
# <li>
# <img alt="불성실공시법인" class="vmiddle" src="../images/common/icn_t_bul.gif"/> 불성실공시법인
# 			</li>
# <li>
# <img alt="폐지법인" class="vmiddle" src="../images/common/icn_t_pe.gif"/> 폐지법인
# 			</li>
# <li>
# <img alt="코리아밸류업" class="vmiddle" src="../images/common/icn_t_v100.gif"/> 코리아밸류업
# 			</li>
# <li>
# <img alt="KOSPI200" class="vmiddle" src="../images/common/icn_t_k200.gif"/> KOSPI200
# 			</li>
# <li>
# <img alt="KOSDAQ150" class="vmiddle" src="../images/common/icn_t_q150.gif"/> KOSDAQ150
# 			</li>
# <li>
# <img alt="KRX300" class="vmiddle" src="../images/common/icn_t_x300.gif"/> KRX300
# 			</li>
# <li>
# <img alt="KTOP30" class="vmiddle" src="../images/common/icn_t_ktop.gif"/> KTOP30
# 			</li>
# <li>
# <img alt="정정있음" class="vmiddle" src="../images/common/icn_t_jung.gif"/> 정정있음
# 			</li>
# <li>
# <img alt="투자주의" class="vmiddle" src="../images/common/icn_t_joo.gif"/> 투자주의
# 			</li>
# <li>
# <img alt="투자경고" class="vmiddle" src="../images/common/icn_t_kyung.gif"/> 투자경고
# 			</li>
# <li>
# <img alt="투자위험" class="vmiddle" src="../images/common/icn_t_wii.gif"/> 투자위험
# 			</li>
# </ul>
# <div class="clear"></div>
# <img alt="" class="tl" src="../images/common/icn_tbox_tl.png"/>
# <img alt="" class="bl" src="../images/common/icn_tbox_bl.gif"/>
# <img alt="" class="tr" src="../images/common/icn_tbox_tr.gif"/>
# <img alt="" class="br" src="../images/common/icn_tbox_br.gif"/>
# <div class="tm"></div>
# <div class="lm"></div>
# <div class="bm"></div>
# <div class="rm"></div>
# </section>
# </div>
# <!-- 범례 END -->
# <div class="loading" id="dialog-loading" style="display: none;" title="자료를 조회 중입니다.">
# <span>
# <img src="/images/loader/ajax-loader01.gif"/>
# </span>
# </div>
# <div id="dialog-message" style="display: none;"></div>
# <div id="dialog-alert" style="display: none;">
# <div id="img"></div>
# <div class="ui-message" id="msg"></div>
# </div>
# <script type="text/javascript">
# 	$(document).ready(function(){
# 		$('input').placeholder();
# 	});
#
# </script>
# </body>
# </html>

# %%
soup.select_one("#companysum").text  #태그 자체가 없음
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 soup.select_one("#companysum").text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
#페이지 payload에서 페이지 변환 가능 확인
https://kind.krx.co.kr/corpgeneral/corpList.do?

method=searchCorpList&pageIndex=1&currentPageSize=100&comAbbrv=&beginIndex=&orderMode=3&orderStat=D&isurCd=&repIsuSrtCd=&searchCodeType=&marketType=&searchType=13&industry=&fiscalYearEnd=all&comAbbrvTmp=&location=all

#pageIndex만 바꾸면 페이지 이동

# %%
url2='https://kind.krx.co.kr/corpgeneral/corpList.do'

# %%
url2='https://kind.krx.co.kr/corpgeneral/corpList.do'
payload = dict(method='searchCorpList', pageIndex=1, currentPageSize=100, orderMode=3, orderStat='D', searchType=13, fiscalYearEnd='all', location='all')

# %%
r=requests.post(url2,data=payload)
print(r.status_code)
soup = bs(r.content, 'lxml')
soup
# Out:
# 200
# <html><body><section class="scrarea type-00">
# <table class="list type-00 tmt30" summary="회사명, 업종, 주요제품, 상장일, 결산월, 대표자명, 홈페이지, 지역">
# <caption>목록</caption>
# <colgroup>
# <col width="*"/>
# <col width="15%"/>
# <col width="20%"/>
# <col width="11%"/>
# <col width="8%"/>
# <col width="10%"/>
# <col width="8%"/>
# <col width="12%"/>
# </colgroup>
# <thead>
# <tr class="first" id="title-contents">
# </tr>
# </thead>
# <tbody>
# <tr class="first">
# <td class="first" title="한국피아이엠(주)"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('44890'); return false;" title="한국피아이엠"> 한국피아이엠</a> </td>
# <td class="textOverflow" title="자동차 신품 부품 제조업">자동차 신품 부품 제조업</td>
# <td class="textOverflow" title="내연기관 부품(터보차저, DCT변속기), IT 부품(스마트워치/스마트링), 자율주행 부품(카메라 모듈 케이스)">내연기관 부품(터보차저, DCT변속기), IT 부품(스마트워치/스마트링), 자율주행 부품(카메라 모듈 케이스)</td>
# <td class="txc">2025-04-04</td>
# <td class="txc">12월</td>
# <td class="txc" title="송준호">송준호</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.pimkorea.com" target="_blank" title="http://www.pimkorea.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">대구광역시</td>
# </tr>
# <tr>
# <td class="first" title="(주)에이유브랜즈"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('48107'); return false;" title="에이유브랜즈"> 에이유브랜즈</a> </td>
# <td class="textOverflow" title="섬유, 의복, 신발 및 가죽제품 소매업">섬유, 의복, 신발 및 가죽제품 소매업</td>
# <td class="textOverflow" title="레인부츠, 스니커즈, 겨울화, 패션잡화 등">레인부츠, 스니커즈, 겨울화, 패션잡화 등</td>
# <td class="txc">2025-04-03</td>
# <td class="txc">12월</td>
# <td class="txc" title="김지훈">김지훈</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://aubrandz.irpage.co.kr" target="_blank" title="http://aubrandz.irpage.co.kr"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="우양에이치씨(주)"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('10197'); return false;" title="우양에이치씨"> 우양에이치씨</a> </td>
# <td class="textOverflow" title="구조용 금속제품, 탱크 및 증기발생기 제조업">구조용 금속제품, 탱크 및 증기발생기 제조업</td>
# <td class="textOverflow" title="화공 플랜트, 에너지 플랜트">화공 플랜트, 에너지 플랜트</td>
# <td class="txc">2025-03-28</td>
# <td class="txc">12월</td>
# <td class="txc" title="김진태">김진태</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.wooyang.co.kr" target="_blank" title="http://www.wooyang.co.kr"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">경기도</td>
# </tr>
# <tr>
# <td class="first" title="(주)더즌"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('46286'); return false;" title="더즌"> 더즌</a> </td>
# <td class="textOverflow" title="전기 통신업">전기 통신업</td>
# <td class="textOverflow" title="디지털뱅킹 솔루션(B2B 금융 서비스)">디지털뱅킹 솔루션(B2B 금융 서비스)</td>
# <td class="txc">2025-03-24</td>
# <td class="txc">12월</td>
# <td class="txc" title
주식회사"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('47583'); return false;" title="오름테라퓨틱"> 오름테라퓨틱</a> </td>
# <td class="textOverflow" title="기초 의약물질 제조업">기초 의약물질 제조업</td>
# <td class="textOverflow" title="항체약물접합체(ADC) 단백질 분해제(TPD) 연구 개발">항체약물접합체(ADC) 단백질 분해제(TPD) 연구 개발</td>
# <td class="txc">2025-02-14</td>
# <td class="txc">12월</td>
# <td class="txc" title="이승주">이승주</td>
# <td class="txc">
# </td>
# <td class="txc">대전광역시</td>
# </tr>
# <tr>
# <td class="first" title="(주)동방메디컬"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('24055'); return false;" title="동방메디컬"> 동방메디컬</a> </td>
# <td class="textOverflow" title="의료용 기기 제조업">의료용 기기 제조업</td>
# <td class="textOverflow" title="필러, 한방침">필러, 한방침</td>
# <td class="txc">2025-02-13</td>
# <td class="txc">12월</td>
# <td class="txc" title="김근식">김근식</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.dongbangmedical.co.kr/" target="_blank" title="http://www.dongbangmedical.co.kr/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">충청남도</td>
# </tr>
# <tr>
# <td class="first" title="(주)아이에스티이"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('21271'); return false;" title="아이에스티이"> 아이에스티이</a> </td>
# <td class="textOverflow" title="반도체 제조업">반도체 제조업</td>
# <td class="textOverflow" title="반도체 제조용 장비">반도체 제조용 장비</td>
# <td class="txc">2025-02-12</td>
# <td class="txc">12월</td>
# <td class="txc" title="조창현">조창현</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://iste.co.kr/" target="_blank" title="http://iste.co.kr/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">경기도</td>
# </tr>
# <tr>
# <td class="first" title="(주)엘지씨엔에스"><img alt="유가증권" class="vmiddle legend" src="/images/common/icn_t_yu.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('06440'); return false;" title="LG씨엔에스"> LG씨엔에스</a> </td>
# <td class="textOverflow" title="컴퓨터 프로그래밍, 시스템 통합 및 관리업">컴퓨터 프로그래밍, 시스템 통합 및 관리업</td>
# <td class="textOverflow" title="컨설팅, 시스템 구축/운영, 토탈 아웃소싱 및 AI, 클라우드·스마트팩토리 등 IT신기술 기반의 DX사업">컨설팅, 시스템 구축/운영, 토탈 아웃소싱 및 AI, 클라우드·스마트팩토리 등 IT신기술 기반의 DX사업</td>
# <td class="txc">2025-02-05</td>
# <td class="txc">12월</td>
# <td class="txc" title="현신균">현신균</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.lgcns.com" target="_blank" title="http://www.lgcns.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="(주)아이지넷"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('46298'); return false;" title="아이지넷"> 아이지넷</a> </td>
# <td class="textOverflow" title="기타 정보 서비스업">기타 정보 서비스업</td>
# <td class="textOverflow" title="보험 서비스 어플리케이션, 기업용 보험 솔루션">보험 서비스 어플리케이션, 기업용 보험 솔루션</td>
# <td class="txc">2025-02-04</td>
# <td class="txc">12월</td>
# <td class="txc" title="김창균, 김지태">김창균..</td>
# <td class="txc">
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="(주)피아이이"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('45245'); return false;" title="피아이이"> 피아이이</a> </td>
# <td class="textOverflow" title="특수 목적용 기계 제조업">특수 목적용 기계 제조업</td>
# <td class="textOverflow" title="AI 비전 솔루션 및 스마트팩토리 솔루션">AI 비전 솔루션 및 스마트팩토리 솔루션</td>
# <td class="txc">2025-02-04</td>
# <td class="txc">12월</td>
# <td class="txc" title="최정일, 김현준">최정일..</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://piegroup.co.kr" target="_blank" title="http://piegroup.co.kr"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">경기도</td>
# </tr>
# <tr>
# <td class="first" title="(주)삼양엔씨켐"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('48263'); return false;" title="삼양엔씨켐"> 삼양엔씨켐</a> </td>
# <td class="textOverflow" title="기타 화학제품 제조업">기타 화학제품 제조업</td>
# <td class="textOverflow" title="반도체 포토레지스트용 기초화합물(KrF PR용 소재, ArF PR용 소재, Wet Chemical)">반도체 포토레지스트용 기초화합물(KrF PR용 소재, ArF PR용 소재, Wet Chemical)</td>
# <td class="txc">2025-02-03</td>
# <td class="txc">12월</td>
# <td class="txc" title="정회식">정회식</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www
20</td>
# <td class="txc">12월</td>
# <td class="txc" title="임병완">임병완</td>
# <td class="txc">
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="(주)위츠"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('45910'); return false;" title="위츠"> 위츠</a> </td>
# <td class="textOverflow" title="전자부품 제조업">전자부품 제조업</td>
# <td class="textOverflow" title="무선충전소재, 부품 제조">무선충전소재, 부품 제조</td>
# <td class="txc">2024-11-20</td>
# <td class="txc">12월</td>
# <td class="txc" title="김응태">김응태</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.ewits.co.kr/kr/" target="_blank" title="http://www.ewits.co.kr/kr/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">경기도</td>
# </tr>
# <tr>
# <td class="first" title="(주)유디엠텍"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('38968'); return false;" title="유디엠텍"> 유디엠텍</a> </td>
# <td class="textOverflow" title="소프트웨어 개발 및 공급업">소프트웨어 개발 및 공급업</td>
# <td class="textOverflow" title="PLC eXpert, OPTRA Black-box, OPTRA Tracker">PLC eXpert, OPTRA Black-box, OPTRA Tracker</td>
# <td class="txc">2024-11-20</td>
# <td class="txc">12월</td>
# <td class="txc" title="왕지남">왕지남</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.udmtek.com" target="_blank" title="http://www.udmtek.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">경기도</td>
# </tr>
# <tr>
# <td class="first" title="알에프시스템즈(주)"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('47461'); return false;" title="RF시스템즈"> RF시스템즈</a> </td>
# <td class="textOverflow" title="기타 금속 가공제품 제조업">기타 금속 가공제품 제조업</td>
# <td class="textOverflow" title="방산제품(레이더시스템, 안테나시스템, 환경제어시스템 등)">방산제품(레이더시스템, 안테나시스템, 환경제어시스템 등)</td>
# <td class="txc">2024-11-19</td>
# <td class="txc">12월</td>
# <td class="txc" title="한기우">한기우</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.rf-systems.co.kr/" target="_blank" title="http://www.rf-systems.co.kr/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">경기도</td>
# </tr>
# <tr>
# <td class="first" title="(주)사이냅소프트"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('46641'); return false;" title="사이냅소프트"> 사이냅소프트</a> </td>
# <td class="textOverflow" title="소프트웨어 개발 및 공급업">소프트웨어 개발 및 공급업</td>
# <td class="textOverflow" title="웹 기반 문서뷰어, 문서필터, 웹 에디터 등">웹 기반 문서뷰어, 문서필터, 웹 에디터 등</td>
# <td class="txc">2024-11-19</td>
# <td class="txc">12월</td>
# <td class="txc" title="전경헌">전경헌</td>
# <td class="txc">
# <a class="btn ico homepage" href="http:///www.synapsoft.co.kr" target="_blank" title="http:///www.synapsoft.co.kr"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="하나34호기업인수목적 주식회사"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('48413'); return false;" title="하나34호스팩"> 하나34호스팩</a> </td>
# <td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# <td class="textOverflow" title="기업인수목적">기업인수목적</td>
# <td class="txc">2024-11-19</td>
# <td class="txc">12월</td>
# <td class="txc" title="송하용">송하용</td>
# <td class="txc">
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="주식회사 에스켐"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('47566'); return false;" title="에스켐"> 에스켐</a> </td>
# <td class="textOverflow" title="기타 화학제품 제조업">기타 화학제품 제조업</td>
# <td class="textOverflow" title="OLED 유기화합물 등">OLED 유기화합물 등</td>
# <td class="txc">2024-11-18</td>
# <td class="txc">12월</td>
# <td class="txc" title="염호영">염호영</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.s-chem.co.kr" target="_blank" title="http://www.s-chem.co.kr"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">충청북도</td>
# </tr>
# <tr>
# <td class="first" title="(주)엠오티"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('41339'); return false;" title="엠오티"> 엠오티</a> </td>
# <td class="textOverflow" title="특수 목적용 기계 제조업">특수 목적용 기계 제조업</td>
# <td class="textOverflow" title="이차전지 제조 자동화 설비">이차전지 제조 자동화 설비</td>
# <td class="txc">2024-11-18</td>
# <td class="txc">12월</td>
# <td class="txc" title="마점래">마점래</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.motfa.com" target="_blank" title="http://www.motfa.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">경상남도</td>
# </tr>
# <tr>
# <td class="first" title="신한제15호기업인수목적 주식회사"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('48783'); return false;" title="신한제15호스팩"> 신한제15호스팩</a> </td>
# <td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# <td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# <td class="txc">2024-11-15</td>
# <td class="txc">12월</td>
# <td class="txc" title="연오흠">연오흠</td>
# <td class="txc">
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="(주)쓰리빌리언"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('39480'); return false;" title="쓰리빌리언"> 쓰리빌리언</a> </td>
# <td class="textOverflow" title="의료용 기기 제조업">의료용 기기 제조업</td>
# <td class="textOverflow" title="유전체 분석 기반 희귀 유전질환 진단 검사 서비스">유전체 분석 기반 희귀 유전질환 진단 검사 서비스</td>
# <td class="txc">2024-11-14</td>
# <td class="txc">12월</td>
# <td class="txc" title="금창원">금창원</td>
# <td class="txc">
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="(주)닷밀"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('
com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="(주)탑런토탈솔루션"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('33668'); return false;" title="탑런토탈솔루션"> 탑런토탈솔루션</a> </td>
# <td class="textOverflow" title="전자부품 제조업">전자부품 제조업</td>
# <td class="textOverflow" title="전장디스플레이 및 pOLED 부품">전장디스플레이 및 pOLED 부품</td>
# <td class="txc">2024-11-01</td>
# <td class="txc">12월</td>
# <td class="txc" title="각 자 대표이사 박영근, 손종술">각 자..</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://toprun.co.kr/" target="_blank" title="http://toprun.co.kr/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">경상북도</td>
# </tr>
# <tr>
# <td class="first" title="(주)성우"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('45865'); return false;" title="성우"> 성우</a> </td>
# <td class="textOverflow" title="일차전지 및 이차전지 제조업">일차전지 및 이차전지 제조업</td>
# <td class="textOverflow" title="이차전지 부품(2170 Topcap Ass'y, S4623 등), 자동차 전장부품(Motor Housing, EV Relay 등)">이차전지 부품(2170 Topcap Ass'y, S4623 등), 자동차 전장부품(Motor Housing, EV Relay 등)</td>
# <td class="txc">2024-10-31</td>
# <td class="txc">12월</td>
# <td class="txc" title="박종헌">박종헌</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.e-sungwoo.co.kr" target="_blank" title="http://www.e-sungwoo.co.kr"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">경상북도</td>
# </tr>
# <tr>
# <td class="first" title="유진기업인수목적11호 주식회사"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('48806'); return false;" title="유진스팩11호"> 유진스팩11호</a> </td>
# <td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# <td class="textOverflow" title="기업인수합병">기업인수합병</td>
# <td class="txc">2024-10-31</td>
# <td class="txc">12월</td>
# <td class="txc" title="박홍식">박홍식</td>
# <td class="txc">
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="(주)타조엔터테인먼트"><img alt="코넥스" class="vmiddle legend" src="/images/common/icn_t_konex.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('47671'); return false;" title="타조엔터테인먼트"> 타조엔터테인먼트</a> </td>
# <td class="textOverflow" title="창작 및 예술관련 서비스업">창작 및 예술관련 서비스업</td>
# <td class="textOverflow" title="공연기획, 방송·공연">공연기획, 방송·공연</td>
# <td class="txc">2024-10-30</td>
# <td class="txc">12월</td>
# <td class="txc" title="이성호">이성호</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://tajoyent.com/" target="_blank" title="http://tajoyent.com/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="주식회사 클로봇"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('46610'); return false;" title="클로봇"> 클로봇</a> </td>
# <td class="textOverflow" title="소프트웨어 개발 및 공급업">소프트웨어 개발 및 공급업</td>
# <td class="textOverflow" title="로봇 소프트웨어(카멜레온, 크롬스)">로봇 소프트웨어(카멜레온, 크롬스)</td>
# <td class="txc">2024-10-28</td>
# <td class="txc">12월</td>
# <td class="txc" title="각자 대표이사 김창구, 김경필">각자 ..</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://clobot.co.kr" target="_blank" title="http://clobot.co.kr"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">경기도</td>
# </tr>
# <tr>
# ...
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="(주)한켐"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('45737'); return false;" title="한켐"> 한켐</a> </td>
# <td class="textOverflow" title="기초 화학물질 제조업">기초 화학물질 제조업</td>
# <td class="textOverflow" title="OLED 발광층 소재 등">OLED 발광층 소재 등</td>
# <td class="txc">2024-10-22</td>
# <td class="txc">12월</td>
# <td class="txc" title="이상조">이상조</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.hanchem.net" target="_blank" title="http://www.hanchem.net"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">대전광역시</td>
# </tr>
# <tr>
# <td class="first" title="루미르 주식회사"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('47417'); return false;" title="루미르"> 루미르</a> </td>
# <td class="textOverflow" title="항공기,우주선 및 부품 제조업">항공기,우주선 및 부품 제조업</td>
# <td class="textOverflow" title="인공위성 시스템 및 전장품, 위성 영상 및 정보">인공위성 시스템 및 전장품, 위성 영상 및 정보</td>
# <td class="txc">2024-10-21</td>
# <td class="txc">12월</td>
# <td class="txc" title="남명용">남명용</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.lumir.space" target="_blank" title="http://www.lumir.space"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">경기도</td>
# </tr>
# <tr>
# <td class="first" title="와이제이링크(주)"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('20964'); return false;" title="와이제이링크"> 와이제이링크</a> </td>
# <td class="textOverflow" title="특수 목적용 기계 제조업">특수 목적용 기계 제조업</td>
주)"><img alt="유가증권" class="vmiddle legend" src="/images/common/icn_t_yu.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('07990'); return false;" title="전진건설로봇"> 전진건설로봇</a> </td>
# <td class="textOverflow" title="특수 목적용 기계 제조업">특수 목적용 기계 제조업</td>
# <td class="textOverflow" title="콘크리트 펌프카">콘크리트 펌프카</td>
# <td class="txc">2024-08-19</td>
# <td class="txc">12월</td>
# <td class="txc" title="고현국">고현국</td>
# <td class="txc">
# </td>
# <td class="txc">충청북도</td>
# </tr>
# <tr>
# <td class="first" title="(주)유라클"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('08834'); return false;" title="유라클"> 유라클</a> </td>
# <td class="textOverflow" title="소프트웨어 개발 및 공급업">소프트웨어 개발 및 공급업</td>
# <td class="textOverflow" title="모바일 앱 개발 플랫폼">모바일 앱 개발 플랫폼</td>
# <td class="txc">2024-08-16</td>
# <td class="txc">12월</td>
# <td class="txc" title="조준희">조준희</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.uracle.co.kr/" target="_blank" title="http://www.uracle.co.kr/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="교보16호기업인수목적 주식회사"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('48252'); return false;" title="교보16호스팩"> 교보16호스팩</a> </td>
# <td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# <td class="textOverflow" title="기업인수합병">기업인수합병</td>
# <td class="txc">2024-08-13</td>
# <td class="txc">12월</td>
# <td class="txc" title="정시화">정시화</td>
# <td class="txc">
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# </tbody>
# </table>
# </section>
# <!-- 페이징 START -->
# <section class="paging-group">
# <div class="paging type-00"><a class="pprev" href="#prevPage10" onclick="return false;"><span>이전10개 페이지</span></a><a class="prev" href="#prevPage" onclick="return false;"><span>이전 페이지</span></a>
# <a class="active" href="#page_link_1" onclick="return false;">1</a><a href="#page_link_2" onclick="fnPageGo('2');return false;">2</a><a href="#page_link_3" onclick="fnPageGo('3');return false;">3</a><a href="#page_link_4" onclick="fnPageGo('4');return false;">4</a><a href="#page_link_5" onclick="fnPageGo('5');return false;">5</a><a href="#page_link_6" onclick="fnPageGo('6');return false;">6</a><a href="#page_link_7" onclick="fnPageGo('7');return false;">7</a><a href="#page_link_8" onclick="fnPageGo('8');return false;">8</a><a href="#page_link_9" onclick="fnPageGo('9');return false;">9</a><a href="#page_link_10" onclick="fnPageGo('10');return false;">10</a>
# <a class="next" href="#nextPage" onclick="fnPageGo('2');return false;"><span>다음 페이지</span></a><a class="nnext" href="#nextPage10" onclick="fnPageGo('11');return false;"><span>다음10개 페이지</span></a></div><div class="info type-00">
# 전체 <em>2,761</em>건 : <strong>1</strong>/28
# <select id="currentPageSize" name="currentPageSize">
# <option value="15">15건</option>
# <option value="30">30건</option>
# <option value="50">50건</option>
# <option selected="selected" value="100">100건</option>
# </select>  <a class="btn-sprite btn-go vmiddle" href="#" onclick="fnSearch1();return false;" title="GO"><span>GO</span></a>
# </div>
# </section>
# <!-- 페이징 END -->
# <script type="text/JavaScript">
# $(document).ready(function(){
# 	fn_InitTitle("회사명,업종,주요제품,상장일,결산월,대표자명,홈페이지,지역", "true,false,false,true,false,false,false,false");
# });
# </script></body></html>

# %%
for a in soup.select('td'):
    print(a.get('title', a.text.strip()))

    if a.find('a'):
        if not a.find('a').get('href') == '#companysum':
            print(a.find('a').get('href'))
# Out:
# 한국피아이엠(주)
# 자동차 신품 부품 제조업
# 내연기관 부품(터보차저, DCT변속기), IT 부품(스마트워치/스마트링), 자율주행 부품(카메라 모듈 케이스)
# 2025-04-04
# 12월
# 송준호
# 홈페이지 보기
# http://www.pimkorea.com
# 대구광역시
# (주)에이유브랜즈
# 섬유, 의복, 신발 및 가죽제품 소매업
# 레인부츠, 스니커즈, 겨울화, 패션잡화 등
# 2025-04-03
# 12월
# 김지훈
# 홈페이지 보기
# http://aubrandz.irpage.co.kr
# 서울특별시
# 우양에이치씨(주)
# 구조용 금속제품, 탱크 및 증기발생기 제조업
# 화공 플랜트, 에너지 플랜트
# 2025-03-28
# 12월
# 김진태
# 홈페이지 보기
# http://www.wooyang.co.kr
# 경기도
# (주)더즌
# 전기 통신업
# 디지털뱅킹 솔루션(B2B 금융 서비스)
# 2025-03-24
# 12월
# 조철한
# 홈페이지 보기
# http://www.dozn.co.kr/
# 서울특별시
# (주)심플랫폼
# 소프트웨어 개발 및 공급업
# NUBISON AIoT(산업용 데이터 수집과 산업용 AI서비스 운영)
# 2025-03-21
# 12월
# 임대근, 강태신
# 홈페이지 보기
# http://simplatform.com/
# 서울특별시
# 주식회사 티엑스알로보틱스
# 일반 목적용 기계 제조업
# 물류자동화, 로봇자동화, AMR/AGV
# 2025-03-20
# 12월
# 엄인섭
# 홈페이지 보기
# http://www.txr.kr
# 경기도
# (주)한텍
# 일반 목적용 기계 제조업
# 열교환기 등 화공기기, 저장용 탱크
# 2025-03-20
# 12월
# 김강식
# 홈페이지 보기
# http://hantechltd.com
# 울산광역시
# 한화플러스제5호기업인수목적(주)
# 금융 지원 서비스업
# -
# 2025-03-20
# 12월
# 김광후
#
# 서울특별시
# (주)씨케이솔루션
# 건축기술, 엔지니어링 및 관련 기술 서비스업
# 드라이룸/클린룸 등 건물용 기계, 장비 설치 공사업
# 2025-03-17
# 12월
# 김유곤, 안근표 (공동 대표이사)
# 홈페이지 보기
# http://www.cksolution.co.kr/
# 경기도
# 서울보증보험(주)
# 보험업
# 보증보험, 신용보험 등
# 2025-03-14
# 12월
# 이명순
# 홈페이지 보기
# http://www.sgic.co.kr
# 서울특별시
# (주)에스엠씨지
# 유리 및 유리제품 제조업
# 화장품 유리용기
# 2025-03-07
# 12월
# 최승호
# 홈페이지 보기
# http://www.somangglass.co.kr
# 경기도
# 엠디바이스 주식회사
# 전자부품 제조업
# 반도체기억장치
# 2025-03-07
# 12월
# 조호경
#
# 경기도
# 대진첨단소재(주)
# 플라스틱제품 제조업
# 이차전지 공정용 대전방지트레이, 대전방지코팅액, 이차전지용 PET이형필름
# 2025-03-06
# 12월
# 유성준, 장현주
# 홈페이지 보기
# http://daejin2019.com
# 서울특별시
# (주)에르코스 농업회사법인
# 도시락 및 식사용 조리식품 제조업
# 영유아식, 고령친화식품, 식물기반 대체식품
# 2025-02-28
# 12월
# 김슬기
# 홈페이지 보기
# http://www.ercohs.com
# 대전광역시
# (주)엘케이켐
# 기타 화학제품 제조업
# 반도체 소재(CP, PCP, DIS) 등
# 2025-02-25
# 12월
# 이창엽
# 홈페이지 보기
# http://lkchem.co.kr
# 충청남도
# (주)위너스
# 기타 전기장비 제조업
# 배선기구(스위치, 콘센트, 멀티탭), 전기차 충전기(급속, 완속)
# 2025-02-24
# 12월
# 김창성
# 홈페이지 보기
# http://www.wns21.co.kr/
#
# 모티브링크(주)
# 전자부품 제조업
# EV용 Main Transformer, EV용 Line Filter
# 2025-02-20
# 12월
# 김기한
# 홈페이지 보기
# http://evpart.co.kr
# 경기도
# 동국생명과학(주)
# 의약품 제조업
# 조영제 완제 및 원료, 의료기기 유통
# 2025-02-17
# 12월
# 박재원
# 홈페이지 보기
# http://dkls.co.kr
# 서울특별시
# 오름테라퓨틱 주식회사
# 기초 의약물질 제조업
# 항체약물접합체(ADC) 단백질 분해제(TPD) 연구 개발
# 2025-02-14
# 12월
# 이승주
#
# 대전광역시
# (주)동방메디컬
# 의료용 기기 제조업
# 필러, 한방침
# 2025-02-13
# 12월
# 김근식
# 홈페이지 보기
# http://www.dongbangmedical.co.kr/
# 충청남도
# (주)아이에스티이
# 반도체 제조업
# 반도체 제조용 장비
# 2025-02-12
# 12월
# 조창현
# 홈페이지 보기
# http://iste.co.kr/
# 경기도
# (주)엘지씨엔에스
# 컴퓨터 프로그래밍, 시스템 통합 및 관리업
# 컨설팅, 시스템 구축/운영, 토탈 아웃소싱 및 AI, 클라우드·스마트팩토리 등 IT신기술 기반의 DX사업
# 2025-02-05
# 12월
# 현신균
# 홈페이지 보기
# http://www.lgcns.com
# 서울특별시
# (주)아이지넷
# 기타 정보 서비스업
# 보험 서비스 어플리케이션, 기업용 보험 솔루션
# 2025-02-04
# 12월
# 김창균, 김지태
#
# 서울특별시
# (주)피아이이
# 특수 목적용 기계 제조업
# AI 비전 솔루션 및 스마트팩토리 솔루션
# 2025-02-04
# 12월
# 최정일, 김현준
# 홈페이지 보기
# http://piegroup.co.kr
# 경기도
# (주)삼양엔씨켐
# 기타 화학제품 제조업
# 반도체 포토레지스트용 기초화합물(KrF PR용 소재, ArF PR용 소재, Wet Chemical)
# 2025-02-03
# 12월
# 정회식
# 홈페이지 보기
# http://www.samyangncchem.com
# 경기도
# (주)데이원컴퍼니
# 기타 교육기관
# 성인대상 교육서비스
# 2025-01-24
# 12월
# 이강민
# 홈페이지 보기
# http://day1company.co.kr/
# 서울특별시
# (주)아스테라시스
# 의료용 기기 제조업
# 피부 미용의료기기 제조, 판매
# 2025-01-24
# 12월
# 서은택
# 홈페이지 보기
# http://asterasys.com
# 서울특별시
# (주)와이즈넛
# 소프트웨어 개발 및 공급업
# 검색엔진, 챗봇, 클라우드서비스
# 2025-01-24
# 12월
# 강용성
# 홈페이지 보기
# http://www.wisenut.com/
# 경기도
# (주)미트박스글로벌
# 기타 정보 서비스업
# 축산물 도소매 판매 및 중개
# 2025-01-23
# 12월
# 김기봉
# 홈페이지 보기
# http://www.meatbox.co.kr
# 서울특별시
# 유안타제17호기업인수목적 주식회사
# 금융 지원 서비스업
# 금융 지원 서비스업
# 2025-01-23
# 12월
# 윤원도
#
# 서울특별시
# 주식회사 블랙야크아이앤씨
# 신발 및 신발 부분품 제조업
# 산업용 안전화, 안전복 및 안전용품
# 2025-01-21
# 12월
# 김태효
# 홈페이지 보기
# http://www.blackyakinc.com
# 서울특별시
# 오션스바이오 주식회사
# 의료용 기기 제조업
# 전자약
# 2025-01-14
# 12월
# 이현웅
#
# 경상남도
# 엠에프씨(주)
# 기초 의약물질 제조업
# 원료의약품(API) 및 핵심소재
# 2024-12-26
# 12월
# 황성관, 서기형(각자 대표이사)
# 홈페이지 보기
# http://www.mfcglobal.co.kr
# 경기도
# 주식회사 파인메딕스
# 의료용 기기 제조업
# 인젝터, 스네어, 나이프, 포셉 등 내시경용 시술기구
# 2024-12-26
# 12월
# 전성우, 김성철
#
# 대구광역시
# 쓰리에이로직스(주)
# 반도체 제조업
# NFC/IoT SoC 및 모듈
# 2024-12-24
# 12월
# 박광범, 이평한
# 홈페이지 보기
# http://www.3alogics.com/
# 경기도
# (주)지에스피앤엘
# 기타 금융업
# 지주회사
# 2024-12-23
# 12월
# 김원식
# 홈페이지 보기
# http://www.gspnl.com
# 서울특별시
# 신한제14호기업인수목적 주식회사
# 금융 지원 서비스업
# 금융 지원 서비스업
# 2024-12-23
# 12월
# 정우주
#
# 서울특별시
# (주)유비씨
# 소프트웨어 개발 및 공급업
# 디지털트윈 구현 플랫폼(Flexing CPS, Flexing DT 등)
# 2024-12-23
# 12월
# 조규종
# 홈페이지 보기
# http://uvc.co.kr
# 경기도
# (주)창대정밀
# 특수 목적용 기계 제조업
# 정밀금형 및 사출품
# 2024-12-23
# 12월
# 박제현, 박순민
# 홈페이지 보기
# http://www.i-changdae.com/
# 경기도
# (주)듀켐바이오
# 의약품 제조업
# 방사성의약품
# 2024-12-20
# 12월
# 김상우
# 홈페이지 보기
# http://www.duchembio.com
# 서울특별시
# 키움제10호기업인수목적 주식회사
# 금융 지원 서비스업
# 기업 인수합병
# 2024-12-20
# 12월
# 김대식
#
# 서울특별시
# (주)에스지헬스케어
# 의료용 기기 제조업
# 의료용 영상진단기기
# 2024-12-19
# 12월
# 김정수
# 홈페이지 보기
# http://sghealthcare.com/
# 경기도
# 온코닉테라퓨틱스(주)
# 자연과학 및 공학 연구개발업
# 자큐보정(Zastaprazan, 소화기질환 신약), Nesuparib(표적항암제 신약)
# 2024-12-19
# 12월
# 김존
# 홈페이지 보기
# http://onconic.co.kr
# 서울특별시
# 주식회사 온코크로스
# 자연과학 및 공학 연구개발업
# AI플랫폼 기반 신약개발 용역서비스
# 2024-12-18
# 12월
# 김이랑, 강지훈 (각자대표)
# 홈페이지 보기
# http://www.oncocross.com/
# 서울특별시
# (주)벡트
# 영상 및 음향기기 제조업
# 프로젝터, 전자칠판, 전자교탁 및 관련 영상 소프트웨어, 콘텐츠 등
# 2024-12-16
# 12월
# 유창수
# 홈페이지 보기
# http://vect.co.kr
# 서울특별시
# 주식회사 엠앤씨솔루션
# 특수 목적용 기계 제조업
# 방위산업용 유압식/전기식 부품 및 시스템
# 2024-12-16
# 12월
# 김병근
# 홈페이지 보기
# http://www.mncsolution.com
# 경상남도
# (주)셀로맥스사이언스
# 기타 식품 제조업
# 건강기능식품
# 2024-12-13
# 12월
# 서정민
# 홈페이지 보기
# http://cellromax.kr/
# 경기도
# 주식회사 에이엠시지
# 의료용 기기 제조업
# 심자계
# 2024-12-13
# 12월
# 서용성
# 홈페이지 보기
# http://www.amcg.kr/
# 서울특별시
# 케이비제31호기업인수목적(주)
# 금융 지원 서비스업
# 기업인수합병
# 2024-12-12
# 12월
# 김형철
#
# 서울특별시
# 키움제11호기업인수목적 주식회사
# 금융 지원 서비스업
# 기업 인수합병
# 2024-12-11
# 12월
# 조선희
#
# 서울특별시
# 케이비발해인프라투융자회사
# 신탁업 및 집합투자업
#
# 2024-11-29
# 12월
# 법인이사 케이비자산운용(주)
#
# 서울특별시
# 디비금융제13호기업인수목적 주식회사
# 기타 금융업
# 기업인수 및 합병
# 2024-11-28
# 12월
# 양준석
#
# 서울특별시
# 교보17호기업인수목적 주식회사
# 금융 지원 서비스업
# 기업인수합병
# 2024-11-21
# 12월
# 장정훈
#
# 서울특별시
# 대신밸런스제19호기업인수목적(주)
# 금융 지원 서비스업
# 기업 인수 및 합병
# 2024-11-20
# 12월
# 임병완
#
# 서울특별시
# (주)위츠
# 전자부품 제조업
# 무선충전소재, 부품 제조
# 2024-11-20
# 12월
# 김응태
# 홈페이지 보기
# http://www.ewits.co.kr/kr/
# 경기도
# (주)유디엠텍
# 소프트웨어 개발 및 공급업
# PLC eXpert, OPTRA Black-box, OPTRA Tracker
# 2024-11-20
# 12월
# 왕지남
# 홈페이지 보기
# http://www.udmtek.com
# 경기도
# 알에프시스템즈(주)
# 기타 금속 가공제품 제조업
# 방산제품(레이더시스템, 안테나시스템, 환경제어시스템 등)
# 2024-11-19
# 12월
# 한기우
# 홈페이지 보기
# http://www.rf-systems.co.kr/
# 경기도
# (주)사이냅소프트
# 소프트웨어 개발 및 공급업
# 웹 기반 문서뷰어, 문서필터, 웹 에디터 등
# 2024-11-19
# 12월
# 전경헌
# 홈페이지 보기
# http:///www.synapsoft.co.kr
# 서울특별시
# 하나34호기업인수목적 주식회사
# 금융 지원 서비스업
# 기업인수목적
# 2024-11-19
# 12월
# 송하용
#
# 서울특별시
# 주식회사 에스켐
# 기타 화학제품 제조업
# OLED 유기화합물 등
# 2024-11-18
# 12월
# 염호영
# 홈페이지 보기
# http://www.s-chem.co.kr
# 충청북도
# (주)엠오티
# 특수 목적용 기계 제조업
# 이차전지 제조 자동화 설비
# 2024-11-18
# 12월
# 마점래
# 홈페이지 보기
# http://www.motfa.com
# 경상남도
# 신한제15호기업인수목적 주식회사
# 금융 지원 서비스업
# 금융 지원 서비스업
# 2024-11-15
# 12월
# 연오흠
#
# 서울특별시
# (주)쓰리빌리언
# 의료용 기기 제조업
# 유전체 분석 기반 희귀 유전질환 진단 검사 서비스
# 2024-11-14
# 12월
# 금창원
#
# 서울특별시
# (주)닷밀
# 영화, 비디오물, 방송프로그램 제작 및 배급업
# 실감미디어 콘텐츠 및 시설 구축, 전시 및 테마파크 운영
# 2024-11-13
# 12월
# 정해운
#
# 서울특별시
# (주)노머스
# 창작 및 예술관련 서비스업
# 공연기획 및 MD, Fromm 플랫폼
# 2024-11-12
# 12월
# 김영준
# 홈페이지 보기
# http://knowmerce.com
# 서울특별시
# ㈜에어레인
# 일반 목적용 기계 제조업
# 기체분리막 모듈 및 시스템
# 2024-11-08
# 12월
# 하성용
# 홈페이지 보기
# http://www.airrane.com
# 충청북도
# (주)토모큐브
# 사진장비 및 광학기기 제조업
# 홀로토모그래피 HT-X1, HT-2H
# 2024-11-07
# 12월
# 박용근
# 홈페이지 보기
# http://www.tomocube.com
# 대전광역시
# 주식회사 더본코리아
# 상품 종합 도매업
# 프랜차이즈
# 2024-11-06
# 12월
# 백종원, 강석원
# 홈페이지 보기
# http://www.theborn.co.kr/
# 서울특별시
# 주식회사 에이치이엠파마
# 자연과학 및 공학 연구개발업
# 맞춤형 헬스케어, LBP 디스커버리 플랫폼
# 2024-11-05
# 12월
# 지요셉
# 홈페이지 보기
# http://www.hempharma.bio
# 경기도
# 주식회사 에이럭스
# 그외 기타 제품 제조업
# 교육용 드론/로봇 및 코딩 콘텐츠
# 2024-11-01
# 12월
# 이치헌
# 홈페이지 보기
# http://www.aluxonline.com
# 서울특별시
# (주)탑런토탈솔루션
# 전자부품 제조업
# 전장디스플레이 및 pOLED 부품
# 2024-11-01
# 12월
# 각 자 대표이사 박영근, 손종술
# 홈페이지 보기
# http://toprun.co.kr/
# 경상북도
# (주)성우
# 일차전지 및 이차전지 제조업
# 이차전지 부품(2170 Topcap Ass'y, S4623 등), 자동차 전장부품(Motor Housing, EV Relay 등)
# 2024-10-31
# 12월
# 박종헌
# 홈페이지 보기
# http://www.e-sungwoo.co.kr
# 경상북도
# 유진기업인수목적11호 주식회사
# 금융 지원 서비스업
# 기업인수합병
# 2024-10-31
# 12월
# 박홍식
#
# 서울특별시
# (주)타조엔터테인먼트
# 창작 및 예술관련 서비스업
# 공연기획, 방송·공연
# 2024-10-30
# 12월
# 이성호
# 홈페이지 보기
# http://tajoyent.com/
# 서울특별시
# 주식회사 클로봇
# 소프트웨어 개발 및 공급업
# 로봇 소프트웨어(카멜레온, 크롬스)
# 2024-10-28
# 12월
# 각자 대표이사 김창구, 김경필
# 홈페이지 보기
# http://clobot.co.kr
# 경기도
# 에이치엔에스하이텍(주)
# 전자부품 제조업
# ACF(이방성전도필름), 수정진동자/수정발진기
# 2024-10-25
# 12월
# 김정희
# 홈페이지 보기
# http://www.hnshightech.com/
# 대전광역시
# (주)웨이비스
# 반도체 제조업
# GaN RF 칩, 패키지 트랜지스터, 모듈 등
# 2024-10-25
# 12월
# 한민석
# 홈페이지 보기
# http://www.wavice.com/
# 경기도
# (주)씨메스
# 특수 목적용 기계 제조업
# AI 기반 로봇 솔루션 및 3D 비전 솔루션
# 2024-10-24
# 12월
# 이성호
# 홈페이지 보기
# http://www.cmesrobotics.ai/
# 서울특별시
# (주)한켐
# 기초 화학물질 제조업
# OLED 발광층 소재 등
# 2024-10-22
# 12월
# 이상조
# 홈페이지 보기
# http://www.hanchem.net
# 대전광역시
# 루미르 주식회사
# 항공기,우주선 및 부품 제조업
# 인공위성 시스템 및 전장품, 위성 영상 및 정보
# 2024-10-21
# 12월
# 남명용
# 홈페이지 보기
# http://www.lumir.space
# 경기도
# 와이제이링크(주)
# 특수 목적용 기계 제조업
# SMT(PCB 표면실장) 이송 및 추적장비 등 스마트 공정장비
# 2024-10-18
# 12월
# 박순일
# 홈페이지 보기
# http://www.yjlink.com
# 대구광역시
# 인스피언(주)
# 소프트웨어 개발 및 공급업
# SAP 보안 솔루션, SAP PO/CPI 컨설팅, EDI SaaS 플랫폼
# 2024-10-18
# 12월
# 최정규
# 홈페이지 보기
# http://www.inspien.co.kr
# 서울특별시
# 주식회사 셀비온
# 의약품 제조업
# 셀비온그린주, 셀비온메브로페닌주, 도페정 등
# 2024-10-16
# 12월
# 김권
# 홈페이지 보기
# http://cellbion.co.kr
# 서울특별시
# 제닉스(주)
# 특수 목적용 기계 제조업
# Stocker, AGV/AMR
# 2024-09-30
# 12월
# 배성관
# 홈페이지 보기
# http://www.zenixkorea.co.kr/
# 충청남도
# (주)차이커뮤니케이션
# 광고업
# 광고대행, 광고물 작성
# 2024-09-27
# 12월
# 최영섭
# 홈페이지 보기
# http://www.artistchai.co.kr
# 서울특별시
# 한화비전(주)
# 기타 금융업
# 비금융지주회사
# 2024-09-27
# 12월
# 안순홍
# 홈페이지 보기
# http://www.hanwhavision.com
# 경기도
# 케이비제30호기업인수목적(주)
# 금융 지원 서비스업
# 기업인수합병
# 2024-09-25
# 12월
# 박홍진
#
# 서울특별시
# (주)아이언디바이스
# 반도체 제조업
# 스마트폰용 오디오 앰프 반도체 Soc
# 2024-09-23
# 12월
# 박기태
# 홈페이지 보기
# http://www.irondevice.com/index.html
# 서울특별시
# 미래에셋비전기업인수목적7호 주식회사
# 금융 지원 서비스업
# 기업인수합병
# 2024-09-11
# 12월
# 송우영
#
# 서울특별시
# (주)아이비젼웍스
# 특수 목적용 기계 제조업
# 이차전지 검사시스템 및 검사시스템 설치셋업용역
# 2024-09-03
# 12월
# 길기재
# 홈페이지 보기
# http://www.ivw.co.kr/kor/main/
# 대전광역시
# (주)아이스크림미디어
# 소프트웨어 개발 및 공급업
# 교육출판, 커머스, 연수
# 2024-08-30
# 12월
# 허주환, 현준우(각자대표)
# 홈페이지 보기
# http://www.i-screammedia.com
# 경기도
# 이엔셀(주)
# 기초 의약물질 제조업
# 첨단바이오의약품 위탁개발생산(CDMO) 서비스 / 차세대 세포,유전자 치료제
# 2024-08-23
# 12월
# 장종욱
# 홈페이지 보기
# http://www.encellinc.com/
# 서울특별시
# (주)엠83
# 영화, 비디오물, 방송프로그램 제작 및 배급업
# VFX
# 2024-08-22
# 12월
# 정성진
# 홈페이지 보기
# http://m83.co.kr
# 서울특별시
# 대신밸런스제18호기업인수목적(주)
# 금융 지원 서비스업
# 금융 지원 서비스업
# 2024-08-22
# 12월
# 문병식
#
# 서울특별시
# (주)티디에스팜
# 의약품 제조업
# 경피약물전달시스템(습포제, 첩부제)
# 2024-08-21
# 12월
# 김철준
# 홈페이지 보기
# http://www.tdspharm.com
# 경기도
# (주)넥스트바이오메디컬
# 의료용 기기 제조업
# 내시경용 지혈재, 혈관색전 미립구
# 2024-08-20
# 12월
# 이돈행
# 홈페이지 보기
# http://www.nextbiomedical.co.kr
# 인천광역시
# (주)케이쓰리아이
# 소프트웨어 개발 및 공급업
# XR 실감형콘텐츠
# 2024-08-20
# 12월
# 이재영
# 홈페이지 보기
# http://www.k3i.co.kr
# 대전광역시
# 전진건설로봇(주)
# 특수 목적용 기계 제조업
# 콘크리트 펌프카
# 2024-08-19
# 12월
# 고현국
#
# 충청북도
# (주)유라클
# 소프트웨어 개발 및 공급업
# 모바일 앱 개발 플랫폼
# 2024-08-16
# 12월
# 조준희
# 홈페이지 보기
# http://www.uracle.co.kr/
# 서울특별시
# 교보16호기업인수목적 주식회사
# 금융 지원 서비스업
# 기업인수합병
# 2024-08-13
# 12월
# 정시화
#
# 서울특별시

# %%
industry=[]
for ind in soup.select('td.textOverflow'):
    industry.append(ind.text)
industry
# Out:
# ['자동차 신품 부품 제조업',
#  '내연기관 부품(터보차저, DCT변속기), IT 부품(스마트워치/스마트링), 자율주행 부품(카메라 모듈 케이스)',
#  '섬유, 의복, 신발 및 가죽제품 소매업',
#  '레인부츠, 스니커즈, 겨울화, 패션잡화 등',
#  '구조용 금속제품, 탱크 및 증기발생기 제조업',
#  '화공 플랜트, 에너지 플랜트',
#  '전기 통신업',
#  '디지털뱅킹 솔루션(B2B 금융 서비스)',
#  '소프트웨어 개발 및 공급업',
#  'NUBISON AIoT(산업용 데이터 수집과 산업용 AI서비스 운영)',
#  '일반 목적용 기계 제조업',
#  '물류자동화, 로봇자동화, AMR/AGV',
#  '일반 목적용 기계 제조업',
#  '열교환기 등 화공기기, 저장용 탱크',
#  '금융 지원 서비스업',
#  '-',
#  '건축기술, 엔지니어링 및 관련 기술 서비스업',
#  '드라이룸/클린룸 등 건물용 기계, 장비 설치 공사업',
#  '보험업',
#  '보증보험, 신용보험 등',
#  '유리 및 유리제품 제조업',
#  '화장품 유리용기',
#  '전자부품 제조업',
#  '반도체기억장치',
#  '플라스틱제품 제조업',
#  '이차전지 공정용 대전방지트레이, 대전방지코팅액, 이차전지용 PET이형필름',
#  '도시락 및 식사용 조리식품 제조업',
#  '영유아식, 고령친화식품, 식물기반 대체식품',
#  '기타 화학제품 제조업',
#  '반도체 소재(CP, PCP, DIS) 등',
#  '기타 전기장비 제조업',
#  '배선기구(스위치, 콘센트, 멀티탭), 전기차 충전기(급속, 완속)',
#  '전자부품 제조업',
#  'EV용 Main Transformer, EV용 Line Filter',
#  '의약품 제조업',
#  '조영제 완제 및 원료, 의료기기 유통',
#  '기초 의약물질 제조업',
#  '항체약물접합체(ADC) 단백질 분해제(TPD) 연구 개발',
#  '의료용 기기 제조업',
#  '필러, 한방침',
#  '반도체 제조업',
#  '반도체 제조용 장비',
#  '컴퓨터 프로그래밍, 시스템 통합 및 관리업',
#  '컨설팅, 시스템 구축/운영, 토탈 아웃소싱 및 AI, 클라우드·스마트팩토리 등 IT신기술 기반의 DX사업',
#  '기타 정보 서비스업',
#  '보험 서비스 어플리케이션, 기업용 보험 솔루션',
#  '특수 목적용 기계 제조업',
#  'AI 비전 솔루션 및 스마트팩토리 솔루션',
#  '기타 화학제품 제조업',
#  '반도체 포토레지스트용 기초화합물(KrF PR용 소재, ArF PR용 소재, Wet Chemical)',
#  '기타 교육기관',
#  '성인대상 교육서비스',
#  '의료용 기기 제조업',
#  '피부 미용의료기기 제조, 판매',
#  '소프트웨어 개발 및 공급업',
#  '검색엔진, 챗봇, 클라우드서비스',
#  '기타 정보 서비스업',
#  '축산물 도소매 판매 및 중개',
#  '금융 지원 서비스업',
#  '금융 지원 서비스업',
#  '신발 및 신발 부분품 제조업',
#  '산업용 안전화, 안전복 및 안전용품',
#  '의료용 기기 제조업',
#  '전자약',
#  '기초 의약물질 제조업',
#  '원료의약품(API) 및 핵심소재',
#  '의료용 기기 제조업',
#  '인젝터, 스네어, 나이프, 포셉 등 내시경용 시술기구',
#  '반도체 제조업',
#  'NFC/IoT SoC 및 모듈',
#  '기타 금융업',
#  '지주회사',
#  '금융 지원 서비스업',
#  '금융 지원 서비스업',
#  '소프트웨어 개발 및 공급업',
#  '디지털트윈 구현 플랫폼(Flexing CPS, Flexing DT 등)',
#  '특수 목적용 기계 제조업',
#  '정밀금형 및 사출품',
#  '의약품 제조업',
#  '방사성의약품',
#  '금융 지원 서비스업',
#  '기업 인수합병',
#  '의료용 기기 제조업',
#  '의료용 영상진단기기',
#  '자연과학 및 공학 연구개발업',
#  '자큐보정(Zastaprazan, 소화기질환 신약), Nesuparib(표적항암제 신약)',
#  '자연과학 및 공학 연구개발업',
#  'AI플랫폼 기반 신약개발 용역서비스',
#  '영상 및 음향기기 제조업',
#  '프로젝터, 전자칠판, 전자교탁 및 관련 영상 소프트웨어, 콘텐츠 등',
#  '특수 목적용 기계 제조업',
#  '방위산업용 유압식/전기식 부품 및 시스템',
#  '기타 식품 제조업',
#  '건강기능식품',
#  '의료용 기기 제조업',
#  '심자계',
#  '금융 지원 서비스업',
#  '기업인수합병',
#  '금융 지원 서비스업',
#  '기업 인수합병',
#  '신탁업 및 집합투자업',
#  '',
#  '기타 금융업',
#  '기업인수 및 합병',
#  '금융 지원 서비스업',
#  '기업인수합병',
#  '금융 지원 서비스업',
#  '기업 인수 및 합병',
#  '전자부품 제조업',
#  '무선충전소재, 부품 제조',
#  '소프트웨어 개발 및 공급업',
#  'PLC eXpert, OPTRA Black-box, OPTRA Tracker',
#  '기타 금속 가공제품 제조업',
#  '방산제품(레이더시스템, 안테나시스템, 환경제어시스템 등)',
#  '소프트웨어 개발 및 공급업',
#  '웹 기반 문서뷰어, 문서필터, 웹 에디터 등',
#  '금융 지원 서비스업',
#  '기업인수목적',
#  '기타 화학제품 제조업',
#  'OLED 유기화합물 등',
#  '특수 목적용 기계 제조업',
#  '이차전지 제조 자동화 설비',
#  '금융 지원 서비스업',
#  '금융 지원 서비스업',
#  '의료용 기기 제조업',
#  '유전체 분석 기반 희귀 유전질환 진단 검사 서비스',
#  '영화, 비디오물, 방송프로그램 제작 및 배급업',
#  '실감미디어 콘텐츠 및 시설 구축, 전시 및 테마파크 운영',
#  '창작 및 예술관련 서비스업',
#  '공연기획 및 MD, Fromm 플랫폼',
#  '일반 목적용 기계 제조업',
#  '기체분리막 모듈 및 시스템',
#  '사진장비 및 광학기기 제조업',
#  '홀로토모그래피 HT-X1, HT-2H',
#  '상품 종합 도매업',
#  '프랜차이즈',
#  '자연과학 및 공학 연구개발업',
#  '맞춤형 헬스케어, LBP 디스커버리 플랫폼',
#  '그외 기타 제품 제조업',
#  '교육용 드론/로봇 및 코딩 콘텐츠',
#  '전자부품 제조업',
#  '전장디스플레이 및 pOLED 부품',
#  '일차전지 및 이차전지 제조업',
#  "이차전지 부품(2170 Topcap Ass'y, S4623 등), 자동차 전장부품(Motor Housing, EV Relay 등)",
#  '금융 지원 서비스업',
#  '기업인수합병',
#  '창작 및 예술관련 서비스업',
#  '공연기획, 방송·공연',
#  '소프트웨어 개발 및 공급업',
#  '로봇 소프트웨어(카멜레온, 크롬스)',
#  '전자부품 제조업',
#  'ACF(이방성전도필름), 수정진동자/수정발진기',
#  '반도체 제조업',
#  'GaN RF 칩, 패키지 트랜지스터, 모듈 등',
#  '특수 목적용 기계 제조업',
#  'AI 기반 로봇 솔루션 및 3D 비전 솔루션',
#  '기초 화학물질 제조업',
#  'OLED 발광층 소재 등',
#  '항공기,우주선 및 부품 제조업',
#  '인공위성 시스템 및 전장품, 위성 영상 및 정보',
#  '특수 목적용 기계 제조업',
#  'SMT(PCB 표면실장) 이송 및 추적장비 등 스마트 공정장비',
#  '소프트웨어 개발 및 공급업',
#  'SAP 보안 솔루션, SAP PO/CPI 컨설팅, EDI SaaS 플랫폼',
#  '의약품 제조업',
#  '셀비온그린주, 셀비온메브로페닌주, 도페정 등',
#  '특수 목적용 기계 제조업',
#  'Stocker, AGV/AMR',
#  '광고업',
#  '광고대행, 광고물 작성',
#  '기타 금융업',
#  '비금융지주회사',
#  '금융 지원 서비스업',
#  '기업인수합병',
#  '반도체 제조업',
#  '스마트폰용 오디오 앰프 반도체 Soc',
#  '금융 지원 서비스업',
#  '기업인수합병',
#  '특수 목적용 기계 제조업',
#  '이차전지 검사시스템 및 검사시스템 설치셋업용역',
#  '소프트웨어 개발 및 공급업',
#  '교육출판, 커머스, 연수',
#  '기초 의약물질 제조업',
#  '첨단바이오의약품 위탁개발생산(CDMO) 서비스 / 차세대 세포,유전자 치료제',
#  '영화, 비디오물, 방송프로그램 제작 및 배급업',
#  'VFX',
#  '금융 지원 서비스업',
#  '금융 지원 서비스업',
#  '의약품 제조업',
#  '경피약물전달시스템(습포제, 첩부제)',
#  '의료용 기기 제조업',
#  '내시경용 지혈재, 혈관색전 미립구',
#  '소프트웨어 개발 및 공급업',
#  'XR 실감형콘텐츠',
#  '특수 목적용 기계 제조업',
#  '콘크리트 펌프카',
#  '소프트웨어 개발 및 공급업',
#  '모바일 앱 개발 플랫폼',
#  '금융 지원 서비스업',
#  '기업인수합병']

# %%
for etc in soup.select('tr.first>td.txc'):
    if etc.find('a'):
        #print("a 태그 포함:", etc.text.strip())
        print(etc.find('a').get('href'))
    else:
        print(etc.text)
# Out:
# 2025-04-04
# 12월
# 송준호
# http://www.pimkorea.com
# 대구광역시

# %%
for etc in soup.select('td'):
    if etc.find('a'):
        print(etc.find('a').get('href'))
# Out:
# #companysum
# http://www.pimkorea.com
# #companysum
# http://aubrandz.irpage.co.kr
# #companysum
# http://www.wooyang.co.kr
# #companysum
# http://www.dozn.co.kr/
# #companysum
# http://simplatform.com/
# #companysum
# http://www.txr.kr
# #companysum
# http://hantechltd.com
# #companysum
# #companysum
# http://www.cksolution.co.kr/
# #companysum
# http://www.sgic.co.kr
# #companysum
# http://www.somangglass.co.kr
# #companysum
# #companysum
# http://daejin2019.com
# #companysum
# http://www.ercohs.com
# #companysum
# http://lkchem.co.kr
# #companysum
# http://www.wns21.co.kr/
# #companysum
# http://evpart.co.kr
# #companysum
# http://dkls.co.kr
# #companysum
# #companysum
# http://www.dongbangmedical.co.kr/
# #companysum
# http://iste.co.kr/
# #companysum
# http://www.lgcns.com
# #companysum
# #companysum
# http://piegroup.co.kr
# #companysum
# http://www.samyangncchem.com
# #companysum
# http://day1company.co.kr/
# #companysum
# http://asterasys.com
# #companysum
# http://www.wisenut.com/
# #companysum
# http://www.meatbox.co.kr
# #companysum
# #companysum
# http://www.blackyakinc.com
# #companysum
# #companysum
# http://www.mfcglobal.co.kr
# #companysum
# #companysum
# http://www.3alogics.com/
# #companysum
# http://www.gspnl.com
# #companysum
# #companysum
# http://uvc.co.kr
# #companysum
# http://www.i-changdae.com/
# #companysum
# http://www.duchembio.com
# #companysum
# #companysum
# http://sghealthcare.com/
# #companysum
# http://onconic.co.kr
# #companysum
# http://www.oncocross.com/
# #companysum
# http://vect.co.kr
# #companysum
# http://www.mncsolution.com
# #companysum
# http://cellromax.kr/
# #companysum
# http://www.amcg.kr/
# #companysum
# #companysum
# #companysum
# #companysum
# #companysum
# #companysum
# #companysum
# http://www.ewits.co.kr/kr/
# #companysum
# http://www.udmtek.com
# #companysum
# http://www.rf-systems.co.kr/
# #companysum
# http:///www.synapsoft.co.kr
# #companysum
# #companysum
# http://www.s-chem.co.kr
# #companysum
# http://www.motfa.com
# #companysum
# #companysum
# #companysum
# #companysum
# http://knowmerce.com
# #companysum
# http://www.airrane.com
# #companysum
# http://www.tomocube.com
# #companysum
# http://www.theborn.co.kr/
# #companysum
# http://www.hempharma.bio
# #companysum
# http://www.aluxonline.com
# #companysum
# http://toprun.co.kr/
# #companysum
# http://www.e-sungwoo.co.kr
# #companysum
# #companysum
# http://tajoyent.com/
# #companysum
# http://clobot.co.kr
# #companysum
# http://www.hnshightech.com/
# #companysum
# http://www.wavice.com/
# #companysum
# http://www.cmesrobotics.ai/
# #companysum
# http://www.hanchem.net
# #companysum
# http://www.lumir.space
# #companysum
# http://www.yjlink.com
# #companysum
# http://www.inspien.co.kr
# #companysum
# http://cellbion.co.kr
# #companysum
# http://www.zenixkorea.co.kr/
# #companysum
# http://www.artistchai.co.kr
# #companysum
# http://www.hanwhavision.com
# #companysum
# #companysum
# http://www.irondevice.com/index.html
# #companysum
# #companysum
# http://www.ivw.co.kr/kor/main/
# #companysum
# http://www.i-screammedia.com
# #companysum
# http://www.encellinc.com/
# #companysum
# http://m83.co.kr
# #companysum
# #companysum
# http://www.tdspharm.com
# #companysum
# http://www.nextbiomedical.co.kr
# #companysum
# http://www.k3i.co.kr
# #companysum
# #companysum
# http://www.uracle.co.kr/
# #companysum

# %% [markdown]
# # 찾을 자료를 1개씩 찾아보기

# %%
soup.select("tbody > tr")[0].select('td:nth-child(1)')
# Out:
# [<td class="first" title="한국피아이엠(주)"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('44890'); return false;" title="한국피아이엠"> 한국피아이엠</a> </td>]

# %%
#주식종목
soup.select("tbody > tr")[0].select_one('td:nth-child(1) > img')['alt']
# Out:
# '코스닥'

# %%
#회사이름
soup.select("tbody > tr")[0].select_one('td:nth-child(1) > a')['title']
# Out:
# '한국피아이엠'

# %%
#종목코드
soup.select("tbody > tr")[0].select_one('td:nth-child(1) > a')['onclick'].split("'")[1]
# Out:
# '44890'

# %%
#업종
soup.select("tbody > tr")[0].select_one('td:nth-child(2)')['title']
# Out:
# '자동차 신품 부품 제조업'

# %%
#주요제품
soup.select("tbody > tr")[0].select_one('td:nth-child(3)')['title']
# Out:
# '내연기관 부품(터보차저, DCT변속기), IT 부품(스마트워치/스마트링), 자율주행 부품(카메라 모듈 케이스)'

# %%
#상장일
soup.select("tbody > tr")[0].select_one('td:nth-child(4)').text
# Out:
# '2025-04-04'

# %%
#결산월
soup.select("tbody > tr")[0].select_one('td:nth-child(5)').text
# Out:
# '12월'

# %%
#대표자명
soup.select("tbody > tr")[0].select_one('td:nth-child(6)')['title']
# Out:
# '송준호'

# %%
#홈페이지(url)
soup.select("tbody > tr")[0].select_one('td:nth-child(7) > a')['href']
# Out:
# 'http://www.pimkorea.com'

# %%
#지역
soup.select("tbody > tr")[0].select_one('td:nth-child(8)').text
# Out:
# '대구광역시'

# %%
#전체페이지
total_page=int(soup.select_one('.info.type-00 > em').text.replace(',','')) // 100 +1
total_page
# Out:
# 28

# %%
# 컬럼명
columns = soup.select_one('table')['summary'].split(", ")
columns.insert(0,'주식종목')
columns.insert(2,'종목코드')

# %%
columns
# Out:
# ['주식종목', '회사명', '종목코드', '업종', '주요제품', '상장일', '결산월', '대표자명', '홈페이지', '지역']

# %% [markdown]
# # 코드 합쳐서 1페이지 정보 모두 추출하기

# %%
for i in range(100):
    tr= soup.select("tbody > tr")[i]
    stock_type= tr.select_one('td:nth-child(1) > img')['alt']
    company_name= tr.select_one('td:nth-child(1) > a')['title']
    stock_code= tr.select_one('td:nth-child(1) > a')['onclick'].split("'")[1]
    business_type=tr.select_one('td:nth-child(2)')['title']
    product=tr.select_one('td:nth-child(3)')['title']
    resi_date=tr.select_one('td:nth-child(4)').text
    settlement=tr.select_one('td:nth-child(5)').text
    ceo=tr.select_one('td:nth-child(6)')['title']
    homepage=tr.select_one('td:nth-child(7) > a')['href'] if tr.select_one('td:nth-child(7) > a') !=None else ""
    region=tr.select_one('td:nth-child(8)').text
    print(stock_type,company_name,stock_code,business_type,product,resi_date,settlement,ceo,homepage,region)
# Out:
# 코스닥 한국피아이엠 44890 자동차 신품 부품 제조업 내연기관 부품(터보차저, DCT변속기), IT 부품(스마트워치/스마트링), 자율주행 부품(카메라 모듈 케이스) 2025-04-04 12월 송준호 http://www.pimkorea.com 대구광역시
# 코스닥 에이유브랜즈 48107 섬유, 의복, 신발 및 가죽제품 소매업 레인부츠, 스니커즈, 겨울화, 패션잡화 등 2025-04-03 12월 김지훈 http://aubrandz.irpage.co.kr 서울특별시
# 코스닥 우양에이치씨 10197 구조용 금속제품, 탱크 및 증기발생기 제조업 화공 플랜트, 에너지 플랜트 2025-03-28 12월 김진태 http://www.wooyang.co.kr 경기도
# 코스닥 더즌 46286 전기 통신업 디지털뱅킹 솔루션(B2B 금융 서비스) 2025-03-24 12월 조철한 http://www.dozn.co.kr/ 서울특별시
# 코스닥 심플랫폼 44453 소프트웨어 개발 및 공급업 NUBISON AIoT(산업용 데이터 수집과 산업용 AI서비스 운영) 2025-03-21 12월 임대근, 강태신 http://simplatform.com/ 서울특별시
# 코스닥 티엑스알로보틱스 48481 일반 목적용 기계 제조업 물류자동화, 로봇자동화, AMR/AGV 2025-03-20 12월 엄인섭 http://www.txr.kr 경기도
# 코스닥 한텍 09807 일반 목적용 기계 제조업 열교환기 등 화공기기, 저장용 탱크 2025-03-20 12월 김강식 http://hantechltd.com 울산광역시
# 코스닥 한화플러스제5호스팩 49839 금융 지원 서비스업 - 2025-03-20 12월 김광후  서울특별시
# 유가증권 씨케이솔루션 48037 건축기술, 엔지니어링 및 관련 기술 서비스업 드라이룸/클린룸 등 건물용 기계, 장비 설치 공사업 2025-03-17 12월 김유곤, 안근표 (공동 대표이사) http://www.cksolution.co.kr/ 경기도
# 유가증권 서울보증보험 03121 보험업 보증보험, 신용보험 등 2025-03-14 12월 이명순 http://www.sgic.co.kr 서울특별시
# 코스닥 에스엠씨지 46087 유리 및 유리제품 제조업 화장품 유리용기 2025-03-07 12월 최승호 http://www.somangglass.co.kr 경기도
# 코스닥 엠디바이스 22659 전자부품 제조업 반도체기억장치 2025-03-07 12월 조호경  경기도
# 코스닥 대진첨단소재 39397 플라스틱제품 제조업 이차전지 공정용 대전방지트레이, 대전방지코팅액, 이차전지용 PET이형필름 2025-03-06 12월 유성준, 장현주 http://daejin2019.com 서울특별시
# 코스닥 에르코스 43557 도시락 및 식사용 조리식품 제조업 영유아식, 고령친화식품, 식물기반 대체식품 2025-02-28 12월 김슬기 http://www.ercohs.com 대전광역시
# 코스닥 아이스크림미디어 46130 소프트웨어 개발 및 공급업 교육출판, 커머스, 연수 2024-08-30 12월 허주환, 현준우(각자대표) http://www.i-screammedia.com 경기도
# 코스닥 이엔셀 45607 기초 의약물질 제조업 첨단바이오의약품 위탁개발생산(CDMO) 서비스 / 차세대 세포,유전자 치료제 2024-08-23 12월 장종욱 http://www.encellinc.com/ 서울특별시
# 코스닥 M83 47608 영화, 비디오물, 방송프로그램 제작 및 배급업 VFX 2024-08-22 12월 정성진 http://m83.co.kr 서울특별시
# 코스닥 대신밸런스제18호스팩 47878 금융 지원 서비스업 금융 지원 서비스업 2024-08-22 12월 문병식  서울특별시
# 코스닥 티디에스팜 46428 의약품 제조업 경피약물전달시스템(습포제, 첩부제) 2024-08-21 12월 김철준 http://www.tdspharm.com 경기도
# 코스닥 넥스트바이오메디컬 38965 의료용 기기 제조업 내시경용 지혈재, 혈관색전 미립구 2024-08-20 12월 이돈행 http://www.nextbiomedical.co.kr 인천광역시
# 코스닥 케이쓰리아이 43119 소프트웨어 개발 및 공급업 XR 실감형콘텐츠 2024-08-20 12월 이재영 http://www.k3i.co.kr 대전광역시
# 유가증권 전진건설로봇 07990 특수 목적용 기계 제조업 콘크리트 펌프카 2024-08-19 12월 고현국  충청북도
# 코스닥 유라클 08834 소프트웨어 개발 및 공급업 모바일 앱 개발 플랫폼 2024-08-16 12월 조준희 http://www.uracle.co.kr/ 서울특별시
# 코스닥 교보16호스팩 48252 금융 지원 서비스업 기업인수합병 2024-08-13 12월 정시화  서울특별시

# %%
page=1
company_infos=[]
while True:
    url2='https://kind.krx.co.kr/corpgeneral/corpList.do'
    payload = dict(method='searchCorpList', pageIndex=page, currentPageSize=100, 
                   orderMode=3, orderStat='D', searchType=13, fiscalYearEnd='all', 
                   location='all')
    r=requests.post(url2,data=payload)
    #print(r.status_code)
    soup = bs(r.content, 'lxml')
    total_page=int(soup.select_one('.info.type-00 > em').text.replace(',','')) // 100 +1
    for idx,tr in enumerate(soup.select("tbody>tr")):
        print(f'{page}/{total_page} 중 {idx+1}/{len(soup.select("tbody>tr"))} 작업중', end="\r")
        #tr= soup.select("tbody > tr")[i]
        stock_type= tr.select_one('td:nth-child(1) > img')['alt']
        company_name= tr.select_one('td:nth-child(1) > a')['title']
        stock_code= tr.select_one('td:nth-child(1) > a')['onclick'].split("'")[1]
        business_type=tr.select_one('td:nth-child(2)')['title']
        product=tr.select_one('td:nth-child(3)')['title']
        resi_date=tr.select_one('td:nth-child(4)').text
        settlement=tr.select_one('td:nth-child(5)').text
        ceo=tr.select_one('td:nth-child(6)')['title']
        homepage=tr.select_one('td:nth-child(7) > a')['href'] if tr.select_one('td:nth-child(7) > a') !=None else ""
        region=tr.select_one('td:nth-child(8)').text
        company_infos.append((stock_type,company_name,stock_code,business_type,product,resi_date,settlement,ceo,homepage,region))
    if page < total_page:
        page+=1
    else:
        break
    
company_infos
# Out:
# 28/28 중 61/61 작업중업중
# [('코스닥',
#   '한국피아이엠',
#   '44890',
#   '자동차 신품 부품 제조업',
#   '내연기관 부품(터보차저, DCT변속기), IT 부품(스마트워치/스마트링), 자율주행 부품(카메라 모듈 케이스)',
#   '2025-04-04',
#   '12월',
#   '송준호',
#   'http://www.pimkorea.com',
#   '대구광역시'),
#  ('코스닥',
#   '에이유브랜즈',
#   '48107',
#   '섬유, 의복, 신발 및 가죽제품 소매업',
#   '레인부츠, 스니커즈, 겨울화, 패션잡화 등',
#   '2025-04-03',
#   '12월',
#   '김지훈',
#   'http://aubrandz.irpage.co.kr',
#   '서울특별시'),
#  ('코스닥',
#   '우양에이치씨',
#   '10197',
#   '구조용 금속제품, 탱크 및 증기발생기 제조업',
#   '화공 플랜트, 에너지 플랜트',
#   '2025-03-28',
#   '12월',
#   '김진태',
#   'http://www.wooyang.co.kr',
#   '경기도'),
#  ('코스닥',
#   '더즌',
#   '46286',
#   '전기 통신업',
#   '디지털뱅킹 솔루션(B2B 금융 서비스)',
#   '2025-03-24',
#   '12월',
#   '조철한',
#   'http://www.dozn.co.kr/',
#   '서울특별시'),
#  ('코스닥',
#   '심플랫폼',
#   '44453',
#   '소프트웨어 개발 및 공급업',
#   'NUBISON AIoT(산업용 데이터 수집과 산업용 AI서비스 운영)',
#   '2025-03-21',
#   '12월',
#   '임대근, 강태신',
#   'http://simplatform.com/',
#   '서울특별시'),
#  ('코스닥',
#   '티엑스알로보틱스',
#   '48481',
#   '일반 목적용 기계 제조업',
#   '물류자동화, 로봇자동화, AMR/AGV',
#   '2025-03-20',
#   '12월',
#   '엄인섭',
#   'http://www.txr.kr',
#   '경기도'),
#  ('코스닥',
#   '한텍',
#   '09807',
#   '일반 목적용 기계 제조업',
#   '열교환기 등 화공기기, 저장용 탱크',
#   '2025-03-20',
#   '12월',
#   '김강식',
#   'http://hantechltd.com',
#   '울산광역시'),
#  ('코스닥',
#   '한화플러스제5호스팩',
#   '49839',
#   '금융 지원 서비스업',
#   '-',
#   '2025-03-20',
#   '12월',
#   '김광후',
#   '',
#   '서울특별시'),
#  ('유가증권',
#   '씨케이솔루션',
#   '48037',
#   '건축기술, 엔지니어링 및 관련 기술 서비스업',
#   '드라이룸/클린룸 등 건물용 기계, 장비 설치 공사업',
#   '2025-03-17',
#   '12월',
#   '김유곤, 안근표 (공동 대표이사)',
#   'http://www.cksolution.co.kr/',
#   '경기도'),
#  ('유가증권',
#   '서울보증보험',
#   '03121',
#   '보험업',
#   '보증보험, 신용보험 등',
#   '2025-03-14',
#   '12월',
#   '이명순',
#   'http://www.sgic.co.kr',
#   '서울특별시'),
#  ('코스닥',
#   '에스엠씨지',
#   '46087',
#   '유리 및 유리제품 제조업',
#   '화장품 유리용기',
#   '2025-03-07',
#   '12월',
#   '최승호',
#   'http://www.somangglass.co.kr',
#   '경기도'),
#  ('코스닥',
#   '엠디바이스',
#   '22659',
#   '전자부품 제조업',
#   '반도체기억장치',
#   '2025-03-07',
#   '12월',
#   '조호경',
#   '',
#   '경기도'),
#  ('코스닥',
#   '대진첨단소재',
#   '39397',
#   '플라스틱제품 제조업',
#   '이차전지 공정용 대전방지트레이, 대전방지코팅액, 이차전지용 PET이형필름',
#   '2025-03-06',
#   '12월',
#   '유성준, 장현주',
#   'http://daejin2019.com',
#   '서울특별시'),
#  ('코스닥',
#   '에르코스',
#   '43557',
#   '도시락 및 식사용 조리식품 제조업',
#   '영유아식, 고령친화식품, 식물기반 대체식품',
#   '2025-02-28',
#   '12월',
#   '김슬기',
#   'http://www.ercohs.com',
#   '대전광역시'),
#  ('코스닥',
#   '엘케이켐',
#   '48950',
#   '기타 화학제품 제조업',
#   '반도체 소재(CP, PCP, DIS) 등',
#   '2025-02-25',
#   '12월',
#   '이창엽',
#   'http://lkchem.co.kr',
#   '충청남도'),
#  ('코스닥',
#   '위너스',
#   '47996',
#   '기타 전기장비 제조업',
#   '배선기구(스위치, 콘센트, 멀티탭), 전기차 충전기(급속, 완속)',
#   '2025-02-24',
#   '12월',
#   '김창성',
#   'http://www.wns21.co.kr/',
#   ''),
#  ('코스닥',
#   '모티브링크',
#   '46348',
#   '전자부품 제조업',
#   'EV용 Main Transformer, EV용 Line Filter',
#   '2025-02-20',
#   '12월',
#   '김기한',
#   'http://evpart.co.kr',
#   '경기도'),
#  ('코스닥',
#   '동국생명과학',
#   '30381',
#   '의약품 제조업',
#   '조영제 완제 및 원료, 의료기기 유통',
#   '2025-02-17',
#   '12월',
#   '박재원',
#   'http://dkls.co.kr',
#   '서울특별시'),
#  ('코스닥',
#   '오름테라퓨틱',
#   '47583',
#   '기초 의약물질 제조업',
#   '항체약물접합체(ADC) 단백질 분해제(TPD) 연구 개발',
#   '2025-02-14',
#   '12월',
#   '이승주',
#   '',
#   '대전광역시'),
#  ('코스닥',
#   '동방메디컬',
#   '24055',
#   '의료용 기기 제조업',
#   '필러, 한방침',
#   '2025-02-13',
#   '12월',
#   '김근식',
#   'http://www.dongbangmedical.co.kr/',
#   '충청남도'),
#  ('코스닥',
#   '아이에스티이',
#   '21271',
#   '반도체 제조업',
#   '반도체 제조용 장비',
#   '2025-02-12',
#   '12월',
#   '조창현',
#   'http://iste.co.kr/',
#   '경기도'),
#  ('유가증권',
#   'LG씨엔에스',
#   '06440',
#   '컴퓨터 프로그래밍, 시스템 통합 및 관리업',
#   '컨설팅, 시스템 구축/운영, 토탈 아웃소싱 및 AI, 클라우드·스마트팩토리 등 IT신기술 기반의 DX사업',
#   '2025-02-05',
#   '12월',
#   '현신균',
#   'http://www.lgcns.com',
#   '서울특별시'),
#  ('코스닥',
#   '아이지넷',
#   '46298',
#   '기타 정보 서비스업',
#   '보험 서비스 어플리케이션, 기업용 보험 솔루션',
#   '2025-02-04',
#   '12월',
#   '김창균, 김지태',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '피아이이',
#   '45245',
#   '특수 목적용 기계 제조업',
#   'AI 비전 솔루션 및 스마트팩토리 솔루션',
#   '2025-02-04',
#   '12월',
#   '최정일, 김현준',
#   'http://piegroup.co.kr',
#   '경기도'),
#  ('코스닥',
#   '삼양엔씨켐',
#   '48263',
#   '기타 화학제품 제조업',
#   '반도체 포토레지스트용 기초화합물(KrF PR용 소재, ArF PR용 소재, Wet Chemical)',
#   '2025-02-03',
#   '12월',
#   '정회식',
#   'http://www.samyangncchem.com',
#   '경기도'),
#  ('코스닥',
#   '데이원컴퍼니',
#   '37316',
#   '기타 교육기관',
#   '성인대상 교육서비스',
#   '2025-01-24',
#   '12월',
#   '이강민',
#   'http://day1company.co.kr/',
#   '서울특별시'),
#  ('코스닥',
#   '아스테라시스',
#   '45095',
#   '의료용 기기 제조업',
#   '피부 미용의료기기 제조, 판매',
#   '2025-01-24',
#   '12월',
#   '서은택',
#   'http://asterasys.com',
#   '서울특별시'),
#  ('코스닥',
#   '와이즈넛',
#   '09625',
#   '소프트웨어 개발 및 공급업',
#   '검색엔진, 챗봇, 클라우드서비스',
#   '2025-01-24',
#   '12월',
#   '강용성',
#   'http://www.wisenut.com/',
#   '경기도'),
#  ('코스닥',
#   '미트박스',
#   '47546',
#   '기타 정보 서비스업',
#   '축산물 도소매 판매 및 중개',
#   '2025-01-23',
#   '12월',
#   '김기봉',
#   'http://www.meatbox.co.kr',
#   '서울특별시'),
#  ('코스닥',
#   '유안타제17호스팩',
#   '49379',
#   '금융 지원 서비스업',
#   '금융 지원 서비스업',
#   '2025-01-23',
#   '12월',
#   '윤원도',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '블랙야크아이앤씨',
#   '47856',
#   '신발 및 신발 부분품 제조업',
#   '산업용 안전화, 안전복 및 안전용품',
#   '2025-01-21',
#   '12월',
#   '김태효',
#   'http://www.blackyakinc.com',
#   '서울특별시'),
#  ('코넥스',
#   '오션스바이오',
#   '33219',
#   '의료용 기기 제조업',
#   '전자약',
#   '2025-01-14',
#   '12월',
#   '이현웅',
#   '',
#   '경상남도'),
#  ('코스닥',
#   '엠에프씨',
#   '43298',
#   '기초 의약물질 제조업',
#   '원료의약품(API) 및 핵심소재',
#   '2024-12-26',
#   '12월',
#   '황성관, 서기형(각자 대표이사)',
#   'http://www.mfcglobal.co.kr',
#   '경기도'),
#  ('코스닥',
#   '파인메딕스',
#   '38757',
#   '의료용 기기 제조업',
#   '인젝터, 스네어, 나이프, 포셉 등 내시경용 시술기구',
#   '2024-12-26',
#   '12월',
#   '전성우, 김성철',
#   '',
#   '대구광역시'),
#  ('코스닥',
#   '쓰리에이로직스',
#   '17790',
#   '반도체 제조업',
#   'NFC/IoT SoC 및 모듈',
#   '2024-12-24',
#   '12월',
#   '박광범, 이평한',
#   'http://www.3alogics.com/',
#   '경기도'),
#  ('유가증권',
#   'GS피앤엘',
#   '49979',
#   '기타 금융업',
#   '지주회사',
#   '2024-12-23',
#   '12월',
#   '김원식',
#   'http://www.gspnl.com',
#   '서울특별시'),
#  ('코스닥',
#   '신한제14호스팩',
#   '48736',
#   '금융 지원 서비스업',
#   '금융 지원 서비스업',
#   '2024-12-23',
#   '12월',
#   '정우주',
#   '',
#   '서울특별시'),
#  ('코넥스',
#   '유비씨',
#   '49581',
#   '소프트웨어 개발 및 공급업',
#   '디지털트윈 구현 플랫폼(Flexing CPS, Flexing DT 등)',
#   '2024-12-23',
#   '12월',
#   '조규종',
#   'http://uvc.co.kr',
#   '경기도'),
#  ('코넥스',
#   '창대정밀',
#   '36803',
#   '특수 목적용 기계 제조업',
#   '정밀금형 및 사출품',
#   '2024-12-23',
#   '12월',
#   '박제현, 박순민',
#   'http://www.i-changdae.com/',
#   '경기도'),
#  ('코스닥',
#   '듀켐바이오',
#   '17675',
#   '의약품 제조업',
#   '방사성의약품',
#   '2024-12-20',
#   '12월',
#   '김상우',
#   'http://www.duchembio.com',
#   '서울특별시'),
#  ('코스닥',
#   '키움제10호스팩',
#   '48772',
#   '금융 지원 서비스업',
#   '기업 인수합병',
#   '2024-12-20',
#   '12월',
#   '김대식',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '에스지헬스케어',
#   '39812',
#   '의료용 기기 제조업',
#   '의료용 영상진단기기',
#   '2024-12-19',
#   '12월',
#   '김정수',
#   'http://sghealthcare.com/',
#   '경기도'),
#  ('코스닥',
#   '온코닉테라퓨틱스',
#   '47606',
#   '자연과학 및 공학 연구개발업',
#   '자큐보정(Zastaprazan, 소화기질환 신약), Nesuparib(표적항암제 신약)',
#   '2024-12-19',
#   '12월',
#   '김존',
#   'http://onconic.co.kr',
#   '서울특별시'),
#  ('코스닥',
#   '온코크로스',
#   '38215',
#   '자연과학 및 공학 연구개발업',
#   'AI플랫폼 기반 신약개발 용역서비스',
#   '2024-12-18',
#   '12월',
#   '김이랑, 강지훈 (각자대표)',
#   'http://www.oncocross.com/',
#   '서울특별시'),
#  ('코스닥',
#   '벡트',
#   '45760',
#   '영상 및 음향기기 제조업',
#   '프로젝터, 전자칠판, 전자교탁 및 관련 영상 소프트웨어, 콘텐츠 등',
#   '2024-12-16',
#   '12월',
#   '유창수',
#   'http://vect.co.kr',
#   '서울특별시'),
#  ('유가증권',
#   '엠앤씨솔루션',
#   '48487',
#   '특수 목적용 기계 제조업',
#   '방위산업용 유압식/전기식 부품 및 시스템',
#   '2024-12-16',
#   '12월',
#   '김병근',
#   'http://www.mncsolution.com',
#   '경상남도'),
#  ('코스닥',
#   '셀로맥스사이언스',
#   '47182',
#   '기타 식품 제조업',
#   '건강기능식품',
#   '2024-12-13',
#   '12월',
#   '서정민',
#   'http://cellromax.kr/',
#   '경기도'),
#  ('코넥스',
#   '에이엠시지',
#   '49590',
#   '의료용 기기 제조업',
#   '심자계',
#   '2024-12-13',
#   '12월',
#   '서용성',
#   'http://www.amcg.kr/',
#   '서울특별시'),
#  ('코스닥',
#   'KB제31호스팩',
#   '49222',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2024-12-12',
#   '12월',
#   '김형철',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '키움제11호스팩',
#   '48948',
#   '금융 지원 서비스업',
#   '기업 인수합병',
#   '2024-12-11',
#   '12월',
#   '조선희',
#   '',
#   '서울특별시'),
#  ('유가증권',
#   'KB발해인프라',
#   '41564',
#   '신탁업 및 집합투자업',
#   '',
#   '2024-11-29',
#   '12월',
#   '법인이사 케이비자산운용(주)',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '디비금융제13호스팩',
#   '48973',
#   '기타 금융업',
#   '기업인수 및 합병',
#   '2024-11-28',
#   '12월',
#   '양준석',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '교보17호스팩',
#   '48921',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2024-11-21',
#   '12월',
#   '장정훈',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '대신밸런스제19호스팩',
#   '48269',
#   '금융 지원 서비스업',
#   '기업 인수 및 합병',
#   '2024-11-20',
#   '12월',
#   '임병완',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '위츠',
#   '45910',
#   '전자부품 제조업',
#   '무선충전소재, 부품 제조',
#   '2024-11-20',
#   '12월',
#   '김응태',
#   'http://www.ewits.co.kr/kr/',
#   '경기도'),
#  ('코스닥',
#   '유디엠텍',
#   '38968',
#   '소프트웨어 개발 및 공급업',
#   'PLC eXpert, OPTRA Black-box, OPTRA Tracker',
#   '2024-11-20',
#   '12월',
#   '왕지남',
#   'http://www.udmtek.com',
#   '경기도'),
#  ('코스닥',
#   'RF시스템즈',
#   '47461',
#   '기타 금속 가공제품 제조업',
#   '방산제품(레이더시스템, 안테나시스템, 환경제어시스템 등)',
#   '2024-11-19',
#   '12월',
#   '한기우',
#   'http://www.rf-systems.co.kr/',
#   '경기도'),
#  ('코스닥',
#   '사이냅소프트',
#   '46641',
#   '소프트웨어 개발 및 공급업',
#   '웹 기반 문서뷰어, 문서필터, 웹 에디터 등',
#   '2024-11-19',
#   '12월',
#   '전경헌',
#   'http:///www.synapsoft.co.kr',
#   '서울특별시'),
#  ('코스닥',
#   '하나34호스팩',
#   '48413',
#   '금융 지원 서비스업',
#   '기업인수목적',
#   '2024-11-19',
#   '12월',
#   '송하용',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '에스켐',
#   '47566',
#   '기타 화학제품 제조업',
#   'OLED 유기화합물 등',
#   '2024-11-18',
#   '12월',
#   '염호영',
#   'http://www.s-chem.co.kr',
#   '충청북도'),
#  ('코스닥',
#   '엠오티',
#   '41339',
#   '특수 목적용 기계 제조업',
#   '이차전지 제조 자동화 설비',
#   '2024-11-18',
#   '12월',
#   '마점래',
#   'http://www.motfa.com',
#   '경상남도'),
#  ('코스닥',
#   '신한제15호스팩',
#   '48783',
#   '금융 지원 서비스업',
#   '금융 지원 서비스업',
#   '2024-11-15',
#   '12월',
#   '연오흠',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '쓰리빌리언',
#   '39480',
#   '의료용 기기 제조업',
#   '유전체 분석 기반 희귀 유전질환 진단 검사 서비스',
#   '2024-11-14',
#   '12월',
#   '금창원',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '닷밀',
#   '46458',
#   '영화, 비디오물, 방송프로그램 제작 및 배급업',
#   '실감미디어 콘텐츠 및 시설 구축, 전시 및 테마파크 운영',
#   '2024-11-13',
#   '12월',
#   '정해운',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '노머스',
#   '47398',
#   '창작 및 예술관련 서비스업',
#   '공연기획 및 MD, Fromm 플랫폼',
#   '2024-11-12',
#   '12월',
#   '김영준',
#   'http://knowmerce.com',
#   '서울특별시'),
#  ('코스닥',
#   '에어레인',
#   '16328',
#   '일반 목적용 기계 제조업',
#   '기체분리막 모듈 및 시스템',
#   '2024-11-08',
#   '12월',
#   '하성용',
#   'http://www.airrane.com',
#   '충청북도'),
#  ('코스닥',
#   '토모큐브',
#   '47596',
#   '사진장비 및 광학기기 제조업',
#   '홀로토모그래피 HT-X1, HT-2H',
#   '2024-11-07',
#   '12월',
#   '박용근',
#   'http://www.tomocube.com',
#   '대전광역시'),
#  ('유가증권',
#   '더본코리아',
#   '47556',
#   '상품 종합 도매업',
#   '프랜차이즈',
#   '2024-11-06',
#   '12월',
#   '백종원, 강석원',
#   'http://www.theborn.co.kr/',
#   '서울특별시'),
#  ('코스닥',
#   '에이치이엠파마',
#   '37627',
#   '자연과학 및 공학 연구개발업',
#   '맞춤형 헬스케어, LBP 디스커버리 플랫폼',
#   '2024-11-05',
#   '12월',
#   '지요셉',
#   'http://www.hempharma.bio',
#   '경기도'),
#  ('코스닥',
#   '에이럭스',
#   '47558',
#   '그외 기타 제품 제조업',
#   '교육용 드론/로봇 및 코딩 콘텐츠',
#   '2024-11-01',
#   '12월',
#   '이치헌',
#   'http://www.aluxonline.com',
#   '서울특별시'),
#  ('코스닥',
#   '탑런토탈솔루션',
#   '33668',
#   '전자부품 제조업',
#   '전장디스플레이 및 pOLED 부품',
#   '2024-11-01',
#   '12월',
#   '각 자 대표이사 박영근, 손종술',
#   'http://toprun.co.kr/',
#   '경상북도'),
#  ('코스닥',
#   '성우',
#   '45865',
#   '일차전지 및 이차전지 제조업',
#   "이차전지 부품(2170 Topcap Ass'y, S4623 등), 자동차 전장부품(Motor Housing, EV Relay 등)",
#   '2024-10-31',
#   '12월',
#   '박종헌',
#   'http://www.e-sungwoo.co.kr',
#   '경상북도'),
#  ('코스닥',
#   '유진스팩11호',
#   '48806',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2024-10-31',
#   '12월',
#   '박홍식',
#   '',
#   '서울특별시'),
#  ('코넥스',
#   '타조엔터테인먼트',
#   '47671',
#   '창작 및 예술관련 서비스업',
#   '공연기획, 방송·공연',
#   '2024-10-30',
#   '12월',
#   '이성호',
#   'http://tajoyent.com/',
#   '서울특별시'),
#  ('코스닥',
#   '클로봇',
#   '46610',
#   '소프트웨어 개발 및 공급업',
#   '로봇 소프트웨어(카멜레온, 크롬스)',
#   '2024-10-28',
#   '12월',
#   '각자 대표이사 김창구, 김경필',
#   'http://clobot.co.kr',
#   '경기도'),
#  ('코스닥',
#   '에이치엔에스하이텍',
#   '04499',
#   '전자부품 제조업',
#   'ACF(이방성전도필름), 수정진동자/수정발진기',
#   '2024-10-25',
#   '12월',
#   '김정희',
#   'http://www.hnshightech.com/',
#   '대전광역시'),
#  ('코스닥',
#   '웨이비스',
#   '28993',
#   '반도체 제조업',
#   'GaN RF 칩, 패키지 트랜지스터, 모듈 등',
#   '2024-10-25',
#   '12월',
#   '한민석',
#   'http://www.wavice.com/',
#   '경기도'),
#  ('코스닥',
#   '씨메스',
#   '47540',
#   '특수 목적용 기계 제조업',
#   'AI 기반 로봇 솔루션 및 3D 비전 솔루션',
#   '2024-10-24',
#   '12월',
#   '이성호',
#   'http://www.cmesrobotics.ai/',
#   '서울특별시'),
#  ('코스닥',
#   '한켐',
#   '45737',
#   '기초 화학물질 제조업',
#   'OLED 발광층 소재 등',
#   '2024-10-22',
#   '12월',
#   '이상조',
#   'http://www.hanchem.net',
#   '대전광역시'),
#  ('코스닥',
#   '루미르',
#   '47417',
#   '항공기,우주선 및 부품 제조업',
#   '인공위성 시스템 및 전장품, 위성 영상 및 정보',
#   '2024-10-21',
#   '12월',
#   '남명용',
#   'http://www.lumir.space',
#   '경기도'),
#  ('코스닥',
#   '와이제이링크',
#   '20964',
#   '특수 목적용 기계 제조업',
#   'SMT(PCB 표면실장) 이송 및 추적장비 등 스마트 공정장비',
#   '2024-10-18',
#   '12월',
#   '박순일',
#   'http://www.yjlink.com',
#   '대구광역시'),
#  ('코스닥',
#   '인스피언',
#   '46548',
#   '소프트웨어 개발 및 공급업',
#   'SAP 보안 솔루션, SAP PO/CPI 컨설팅, EDI SaaS 플랫폼',
#   '2024-10-18',
#   '12월',
#   '최정규',
#   'http://www.inspien.co.kr',
#   '서울특별시'),
#  ('코스닥',
#   '셀비온',
#   '30843',
#   '의약품 제조업',
#   '셀비온그린주, 셀비온메브로페닌주, 도페정 등',
#   '2024-10-16',
#   '12월',
#   '김권',
#   'http://cellbion.co.kr',
#   '서울특별시'),
#  ('코스닥',
#   '제닉스',
#   '38162',
#   '특수 목적용 기계 제조업',
#   'Stocker, AGV/AMR',
#   '2024-09-30',
#   '12월',
#   '배성관',
#   'http://www.zenixkorea.co.kr/',
#   '충청남도'),
#  ('코스닥',
#   '차이커뮤니케이션',
#   '35187',
#   '광고업',
#   '광고대행, 광고물 작성',
#   '2024-09-27',
#   '12월',
#   '최영섭',
#   'http://www.artistchai.co.kr',
#   '서울특별시'),
#  ('유가증권',
#   '한화비전',
#   '48979',
#   '기타 금융업',
#   '비금융지주회사',
#   '2024-09-27',
#   '12월',
#   '안순홍',
#   'http://www.hanwhavision.com',
#   '경기도'),
#  ('코스닥',
#   'KB제30호스팩',
#   '48663',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2024-09-25',
#   '12월',
#   '박홍진',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '아이언디바이스',
#   '46450',
#   '반도체 제조업',
#   '스마트폰용 오디오 앰프 반도체 Soc',
#   '2024-09-23',
#   '12월',
#   '박기태',
#   'http://www.irondevice.com/index.html',
#   '서울특별시'),
#  ('코스닥',
#   '미래에셋비전스팩7호',
#   '48268',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2024-09-11',
#   '12월',
#   '송우영',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '아이비젼웍스',
#   '46975',
#   '특수 목적용 기계 제조업',
#   '이차전지 검사시스템 및 검사시스템 설치셋업용역',
#   '2024-09-03',
#   '12월',
#   '길기재',
#   'http://www.ivw.co.kr/kor/main/',
#   '대전광역시'),
#  ('코스닥',
#   '아이스크림미디어',
#   '46130',
#   '소프트웨어 개발 및 공급업',
#   '교육출판, 커머스, 연수',
#   '2024-08-30',
#   '12월',
#   '허주환, 현준우(각자대표)',
#   'http://www.i-screammedia.com',
#   '경기도'),
#  ('코스닥',
#   '이엔셀',
#   '45607',
#   '기초 의약물질 제조업',
#   '첨단바이오의약품 위탁개발생산(CDMO) 서비스 / 차세대 세포,유전자 치료제',
#   '2024-08-23',
#   '12월',
#   '장종욱',
#   'http://www.encellinc.com/',
#   '서울특별시'),
#  ('코스닥',
#   'M83',
#   '47608',
#   '영화, 비디오물, 방송프로그램 제작 및 배급업',
#   'VFX',
#   '2024-08-22',
#   '12월',
#   '정성진',
#   'http://m83.co.kr',
#   '서울특별시'),
#  ('코스닥',
#   '대신밸런스제18호스팩',
#   '47878',
#   '금융 지원 서비스업',
#   '금융 지원 서비스업',
#   '2024-08-22',
#   '12월',
#   '문병식',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '티디에스팜',
#   '46428',
#   '의약품 제조업',
#   '경피약물전달시스템(습포제, 첩부제)',
#   '2024-08-21',
#   '12월',
#   '김철준',
#   'http://www.tdspharm.com',
#   '경기도'),
#  ('코스닥',
#   '넥스트바이오메디컬',
#   '38965',
#   '의료용 기기 제조업',
#   '내시경용 지혈재, 혈관색전 미립구',
#   '2024-08-20',
#   '12월',
#   '이돈행',
#   'http://www.nextbiomedical.co.kr',
#   '인천광역시'),
#  ('코스닥',
#   '케이쓰리아이',
#   '43119',
#   '소프트웨어 개발 및 공급업',
#   'XR 실감형콘텐츠',
#   '2024-08-20',
#   '12월',
#   '이재영',
#   'http://www.k3i.co.kr',
#   '대전광역시'),
#  ('유가증권',
#   '전진건설로봇',
#   '07990',
#   '특수 목적용 기계 제조업',
#   '콘크리트 펌프카',
#   '2024-08-19',
#   '12월',
#   '고현국',
#   '',
#   '충청북도'),
#  ('코스닥',
#   '유라클',
#   '08834',
#   '소프트웨어 개발 및 공급업',
#   '모바일 앱 개발 플랫폼',
#   '2024-08-16',
#   '12월',
#   '조준희',
#   'http://www.uracle.co.kr/',
#   '서울특별시'),
#  ('코스닥',
#   '교보16호스팩',
#   '48252',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2024-08-13',
#   '12월',
#   '정시화',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '뱅크웨어글로벌',
#   '19948',
#   '소프트웨어 개발 및 공급업',
#   '국내외 은행 및 금융기업 대상 코어뱅킹 소프트웨어',
#   '2024-08-12',
#   '12월',
#   '이경조, 이은중',
#   'http://bankwareglobal.com',
#   '서울특별시'),
#  ('코스닥',
#   '아이빔테크놀로지',
#   '46047',
#   '사진장비 및 광학기기 제조업',
#   '생체현미경, CRO 서비스',
#   '2024-08-06',
#   '12월',
#   '김필한',
#   'http://www.ivimtech.com',
#   '대전광역시'),
#  ('코스닥',
#   '피앤에스미캐닉스',
#   '46094',
#   '의료용 기기 제조업',
#   '보행재활로봇 시스템',
#   '2024-07-31',
#   '12월',
#   '박광훈',
#   'http://walkbot.co.kr',
#   '서울특별시'),
#  ('유가증권',
#   'HS효성',
#   '48757',
#   '기타 금융업',
#   '지주사업',
#   '2024-07-29',
#   '12월',
#   '조현상, 안성훈',
#   'http://www.hshyosung.com',
#   '서울특별시'),
#  ('유가증권',
#   '산일전기',
#   '06204',
#   '전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업',
#   '유입, 몰드, 주상, 건식 변압기 등',
#   '2024-07-29',
#   '12월',
#   '박동석',
#   'http://www.sanil.co.kr',
#   '경기도'),
#  ('코스닥',
#   '엔에이치스팩31호',
#   '48189',
#   '금융 지원 서비스업',
#   '금융지원서비스업',
#   '2024-07-26',
#   '12월',
#   '이시형',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   'SK증권제13호스팩',
#   '47395',
#   '금융 지원 서비스업',
#   '기업인수목적 주식회사',
#   '2024-07-25',
#   '12월',
#   '임율표',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '엑셀세라퓨틱스',
#   '37311',
#   '기초 의약물질 제조업',
#   'CellCor SFD/CD(세포배양배지)',
#   '2024-07-15',
#   '12월',
#   '이의일',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '이베스트스팩6호',
#   '47811',
#   '금융 지원 서비스업',
#   '기업인수목적 주식회사',
#   '2024-07-12',
#   '12월',
#   '박용',
#   '',
#   '서울특별시'),
#  ('유가증권',
#   '시프트업',
#   '46287',
#   '소프트웨어 개발 및 공급업',
#   '게임 소프트웨어',
#   '2024-07-11',
#   '12월',
#   '김형태',
#   'http://shiftup.co.kr',
#   '서울특별시'),
#  ('코스닥',
#   '하스',
#   '45033',
#   '의료용품 및 기타 의약 관련제품 제조업',
#   '리튬디실리케이트 수복소재(Amber block, Amber Ingot 등), 지르코니아 유치관',
#   '2024-07-03',
#   '12월',
#   '김용수',
#   'http://www.hassbio.com',
#   '강원특별자치도'),
#  ('코스닥',
#   '이노스페이스',
#   '46235',
#   '항공기,우주선 및 부품 제조업',
#   '소형발사체, 로켓추진기관, 과학로켓, 시험평가용역',
#   '2024-07-02',
#   '12월',
#   '김수종',
#   'http://www.innospc.com/',
#   '세종특별자치시'),
#  ('유가증권',
#   '신한글로벌액티브리츠',
#   '48185',
#   '신탁업 및 집합투자업',
#   '신탁 및 집합투자',
#   '2024-07-01',
#   '02월',
#   '조준우',
#   'http://shglobalreit.com',
#   '서울특별시'),
#  ('코스닥',
#   '에이치브이엠',
#   '29531',
#   '1차 비철금속 제조업',
#   'Ni계 합금, Fe계 합금, 스퍼터링타겟, Cu계 합금 등',
#   '2024-06-28',
#   '12월',
#   '문승호',
#   'http://hvm.co.kr/',
#   '경기도'),
#  ('코넥스',
#   '팡스카이',
#   '26635',
#   '소프트웨어 개발 및 공급업',
#   '게임 개발 및 리퍼블리싱',
#   '2024-06-28',
#   '12월',
#   '이병진(단독대표이사)',
#   'http://www.panggame.com/',
#   '서울특별시'),
#  ('코스닥',
#   '하이젠알앤엠',
#   '16019',
#   '전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업',
#   '전동기 및 발전기 (범용모터, 서보모터)',
#   '2024-06-27',
#   '12월',
#   '김재학',
#   'http://higenrnm.com',
#   '경상남도'),
#  ('코스닥',
#   '한국제15호스팩',
#   '47988',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2024-06-26',
#   '12월',
#   '유한',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '에스오에스랩',
#   '46408',
#   '측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외',
#   '산업용 및 차량용 라이다(LiDAR)',
#   '2024-06-25',
#   '12월',
#   '정지성',
#   'http://soslab.co',
#   '광주광역시'),
#  ('코스닥',
#   '미래에셋비전스팩6호',
#   '47844',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2024-06-24',
#   '12월',
#   '정명훈',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '에이치엠씨제7호스팩',
#   '47734',
#   '금융 지원 서비스업',
#   '기타금융',
#   '2024-06-24',
#   '12월',
#   '조한종',
#   '',
#   '서울특별시'),
#  ('유가증권',
#   '파라다이스',
#   '03423',
#   '유원지 및 기타 오락관련 서비스업',
#   '카지노, 호텔, 복합리조트',
#   '2024-06-24',
#   '12월',
#   '최종환',
#   'http://www.paradise.co.kr/ko/main',
#   '서울특별시'),
#  ('코스닥',
#   '한중엔시에스',
#   '10764',
#   '전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업',
#   '수냉식 냉각시스템 ESS Parts, 공랭식 ESS Module Parts, EV Module 및 내연기관 Parts',
#   '2024-06-24',
#   '12월',
#   '김환식',
#   'http://www.hjncs.com',
#   '경상북도'),
#  ('코스닥',
#   'KB제29호스팩',
#   '47839',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2024-06-21',
#   '12월',
#   '서영화',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '미래에셋비전스팩5호',
#   '47747',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2024-06-19',
#   '12월',
#   '김대호',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '씨어스테크놀로지',
#   '45887',
#   '의료용 기기 제조업',
#   '심전도검사솔루션 입원환자모니터링솔루션',
#   '2024-06-19',
#   '12월',
#   '이영신',
#   'http://seerstech.com',
#   '경기도'),
#  ('코스닥',
#   '한국제14호스팩',
#   '47753',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2024-06-19',
#   '12월',
#   '변성환',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '디비금융스팩12호',
#   '47776',
#   '기타 금융업',
#   '기업인수 및 합병',
#   '2024-06-18',
#   '12월',
#   '김창희',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '라메디텍',
#   '46251',
#   '의료용 기기 제조업',
#   '초소형 레이저 의료기기  및 미용기기',
#   '2024-06-17',
#   '12월',
#   '최종석',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '그리드위즈',
#   '45345',
#   '그외 기타 전문, 과학 및 기술 서비스업',
#   '수요관리 서비스, 전기차 충전기 모뎀 등',
#   '2024-06-14',
#   '12월',
#   '김구환',
#   'http://www.gridwiz.com',
#   '경기도'),
#  ('코스닥',
#   '다원넥스뷰',
#   '32335',
#   '사진장비 및 광학기기 제조업',
#   'LSMB(Laser Micro Bonding System)',
#   '2024-06-11',
#   '12월',
#   '남기중',
#   'http://www.nexview.co.kr',
#   '경기도'),
#  ('코스닥',
#   '미래에셋비전스팩4호',
#   '47738',
#   '금융 지원 서비스업',
#   '기업인수목적회사(기타금융서비스)',
#   '2024-05-29',
#   '12월',
#   '김정수',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '노브랜드',
#   '14517',
#   '편조의복 제조업',
#   'Knit, Woven 의류',
#   '2024-05-23',
#   '12월',
#   '김기홍',
#   'http://www.nobland.com',
#   '서울특별시'),
#  ('코스닥',
#   'KB제28호스팩',
#   '47647',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2024-05-17',
#   '12월',
#   '고광범',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '아이씨티케이',
#   '45601',
#   '반도체 제조업',
#   'PUF반도체,보안솔루션(보안반도체,정보통신모듈기기,정보통신용반도체) 제조,개발',
#   '2024-05-17',
#   '12월',
#   '이정원',
#   'http://www.ictk.com',
#   '서울특별시'),
#  ('유가증권',
#   'HD현대마린솔루션',
#   '44306',
#   '건축기술, 엔지니어링 및 관련 기술 서비스업',
#   'AM(After Market) 솔루션, 친환경 Retrofit, 디지털 제어',
#   '2024-05-08',
#   '12월',
#   '이기동',
#   'http://www.hd-marinesolution.com/',
#   '경기도'),
#  ('코스닥',
#   'SK증권제12호스팩',
#   '47300',
#   '금융 지원 서비스업',
#   '기업인수목적 주식회사',
#   '2024-05-07',
#   '12월',
#   '이재혁',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '코칩',
#   '12673',
#   '전자부품 제조업',
#   '소형 및 초소형 슈퍼커패시터',
#   '2024-05-07',
#   '12월',
#   '손진형',
#   'http://www.korchip.com',
#   '경기도'),
#  ('코스닥',
#   '민테크',
#   '45220',
#   '측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외',
#   '배터리 진단시스템, 배터리 시스템, 충방전 검사장비',
#   '2024-05-03',
#   '12월',
#   '홍영진',
#   'http://www.g-mintech.co.kr',
#   '대전광역시'),
#  ('코스닥',
#   '카티스',
#   '14043',
#   '컴퓨터 프로그래밍, 시스템 통합 및 관리업',
#   '산업인프라 보안플랫폼',
#   '2024-05-03',
#   '12월',
#   '김승수',
#   'http://CATIS.CO.KR',
#   '경기도'),
#  ('코스닥',
#   '디앤디파마텍',
#   '34785',
#   '자연과학 및 공학 연구개발업',
#   '대사성질환 치료제 등',
#   '2024-05-02',
#   '12월',
#   '이슬기',
#   'http://www.ddpharmatech.com',
#   '경기도'),
#  ('코스닥',
#   '유안타제16호스팩',
#   '47449',
#   '금융 지원 서비스업',
#   '금융 지원 서비스(기업인수목적회사)',
#   '2024-05-02',
#   '12월',
#   '박병권',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '제일엠앤에스',
#   '41254',
#   '특수 목적용 기계 제조업',
#   '2차전지 믹싱시스템',
#   '2024-04-30',
#   '12월',
#   '이영진',
#   'http://www.jeilm.co.kr',
#   '경기도'),
#  ('코스닥',
#   '삐아',
#   '45125',
#   '기타 화학제품 제조업',
#   '색조화장품',
#   '2024-04-25',
#   '12월',
#   '박광춘',
#   'http://www.bbiacosmetic.com/',
#   '인천광역시'),
#  ('코스닥',
#   '하나33호스팩',
#   '47525',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2024-04-24',
#   '12월',
#   '박태한',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '신한제13호스팩',
#   '47493',
#   '금융 지원 서비스업',
#   '기타금융서비스(기업합병)',
#   '2024-04-22',
#   '12월',
#   '배성환',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '신한제12호스팩',
#   '47466',
#   '금융 지원 서비스업',
#   '금융서비스(기업인수목적회사)',
#   '2024-04-15',
#   '12월',
#   '이동호',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '아이엠비디엑스',
#   '46103',
#   '자연과학 및 공학 연구개발업',
#   '알파리퀴드ⓡ 100, 알파리퀴드ⓡ HRR, 알파리퀴드ⓡ 디텍트, 알파리퀴드ⓡ 스크리닝',
#   '2024-04-03',
#   '12월',
#   '김태유',
#   'http://www.imbdx.com/',
#   '서울특별시'),
#  ('유가증권',
#   'SK이터닉스',
#   '47515',
#   '건물 건설업',
#   '부동산 개발',
#   '2024-03-29',
#   '12월',
#   '김해중',
#   'http://www.sketernix.com',
#   '경기도'),
#  ('코스닥',
#   '하나32호스팩',
#   '47524',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2024-03-27',
#   '12월',
#   '박종찬',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '엔젤로보틱스',
#   '45590',
#   '특수 목적용 기계 제조업',
#   '재활 전문 웨어러블 로봇, 근력 보조 무동력 웨어러블 슈트, 일상생활 보조 웨어러블 로봇 등',
#   '2024-03-26',
#   '12월',
#   '조남민 (단독대표)',
#   'http://www.angel-robotics.com/ko/',
#   '서울특별시'),
#  ('코스닥',
#   '제이투케이바이오',
#   '42057',
#   '기타 화학제품 제조업',
#   '화장품 원료(천연소재 바이오소재 등)',
#   '2024-03-25',
#   '12월',
#   '이재섭',
#   'http://www.j2kbio.com',
#   '충청북도'),
#  ('코스닥',
#   '삼현',
#   '43773',
#   '자동차 신품 부품 제조업',
#   '스마트 액추에이터, 스마트 파워유닛',
#   '2024-03-21',
#   '12월',
#   '황성호, 박기원',
#   'http://www.samhyun.co.kr',
#   '경상남도'),
#  ('코스닥',
#   '오상헬스케어',
#   '03622',
#   '의료용품 및 기타 의약 관련제품 제조업',
#   '생화학 측정기 및 센서, 면역진단기기 및 마커, 분자진단기기 및 시약 등',
#   '2024-03-13',
#   '12월',
#   '강철훈, 유병열(각자대표이사)',
#   'http://www.osanghc.com',
#   '경기도'),
#  ('코스닥',
#   '케이엔알시스템',
#   '19943',
#   '측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외',
#   '특수목적 시험장비, 산업용로봇',
#   '2024-03-07',
#   '12월',
#   '김명한',
#   'http://www.knrsys.com',
#   '경기도'),
#  ('코스닥',
#   '비엔케이제2호스팩',
#   '47337',
#   '금융 지원 서비스업',
#   '금융 지원 서비스업',
#   '2024-03-05',
#   '12월',
#   '정민중',
#   'http://bnkspac2.com',
#   '서울특별시'),
#  ('코스닥',
#   '하나31호스팩',
#   '46990',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2024-03-05',
#   '12월',
#   '한규정',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   'SK증권제11호스팩',
#   '47223',
#   '금융 지원 서비스업',
#   '기업인수목적 주식회사',
#   '2024-03-04',
#   '12월',
#   '최상우',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '유안타제15호스팩',
#   '47305',
#   '금융 지원 서비스업',
#   '금융 지원 서비스',
#   '2024-02-29',
#   '12월',
#   '구태훈',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '유진스팩10호',
#   '46876',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2024-02-29',
#   '12월',
#   '김동진',
#   '',
#   '서울특별시'),
#  ('유가증권',
#   '에이피알',
#   '27847',
#   '기타 화학제품 제조업',
#   '화장품, 피부미용기기 등',
#   '2024-02-27',
#   '12월',
#   '김병훈',
#   'http://apr-in.com',
#   '서울특별시'),
#  ('코스닥',
#   '이에이트',
#   '41862',
#   '소프트웨어 개발 및 공급업',
#   'CFD 시뮬레이션 소프트웨어, 디지털트윈 플랫폼',
#   '2024-02-23',
#   '12월',
#   '김진현',
#   'http://e8ight.co.kr/',
#   '서울특별시'),
#  ('코스닥',
#   '코셈',
#   '36035',
#   '측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외',
#   '주사전자현미경(SEM)',
#   '2024-02-23',
#   '12월',
#   '이준희',
#   'http://www.coxem.com',
#   '대전광역시'),
#  ('코스닥',
#   '케이웨더',
#   '06810',
#   '일반 목적용 기계 제조업',
#   '공기개선솔루션, 기상데이터, 공기측정솔루션 등',
#   '2024-02-22',
#   '12월',
#   '김동식',
#   'http://www.kweather.co.kr',
#   '서울특별시'),
#  ('코스닥',
#   '사피엔반도체',
#   '45243',
#   '반도체 제조업',
#   'Micro/Mini-LED Display Driver IC',
#   '2024-02-19',
#   '12월',
#   '이명희',
#   'http://www.sapien-semicon.com',
#   '경기도'),
#  ('코스닥',
#   '에스피소프트',
#   '44367',
#   '컴퓨터 프로그래밍, 시스템 통합 및 관리업',
#   'SPLA 라이센스 총판 사업,CLOUD, gDaaS 등',
#   '2024-02-15',
#   '12월',
#   '이은재',
#   'http://www.spsoft.co.kr',
#   '경기도'),
#  ('코스닥',
#   '스튜디오삼익',
#   '41538',
#   '기타 생활용품 소매업',
#   '침실가구, 거실가구,  옷장/수납, 주방가구 등',
#   '2024-02-06',
#   '12월',
#   '최정석',
#   'http://www.studiosamick.com',
#   '서울특별시'),
#  ('코스닥',
#   '신영스팩10호',
#   '47222',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2024-02-06',
#   '12월',
#   '김용국',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '폰드그룹',
#   '47285',
#   '봉제의복 제조업',
#   '의류(언더웨어, 의복, 잡화, 코스메틱 등)',
#   '2024-02-02',
#   '12월',
#   '임종민 / 김유진',
#   'http://www.pond-group.co.kr',
#   '서울특별시'),
#  ('코스닥',
#   'IBKS제24호스팩',
#   '46948',
#   '금융 지원 서비스업',
#   '금융 지원 서비스업',
#   '2024-02-01',
#   '12월',
#   '김강민',
#   'http://www.ibks.com',
#   '서울특별시'),
#  ('코스닥',
#   '레이저옵텍',
#   '19955',
#   '의료용 기기 제조업',
#   '레이저 기반 피부미용기기 및 질환치료기기',
#   '2024-02-01',
#   '12월',
#   '주홍, 이창진',
#   'http://www.laseroptek.com',
#   '경기도'),
#  ('코스닥',
#   '이닉스',
#   '45240',
#   '자동차 신품 부품 제조업',
#   '2차전지용 배터리셀 패드 등',
#   '2024-02-01',
#   '12월',
#   '강동호.김정득(각자 대표이사)',
#   'http://www.inics.kr',
#   '부산광역시'),
#  ('유가증권',
#   '엘앤에프',
#   '06697',
#   '일차전지 및 이차전지 제조업',
#   '이차전지 양극활물질',
#   '2024-01-29',
#   '12월',
#   '최수안',
#   'http://www.landf.co.kr/',
#   '대구광역시'),
#  ('코스닥',
#   '포스뱅크',
#   '10576',
#   '일반 목적용 기계 제조업',
#   'POS 단말기, KIOSK 단말기',
#   '2024-01-29',
#   '12월',
#   '은동욱',
#   'http://www.posbank.com/',
#   '서울특별시'),
#  ('코스닥',
#   '현대힘스',
#   '46093',
#   '선박 및 보트 건조업',
#   '선박기자재 (선박 블록, 보강재, 도장 등)',
#   '2024-01-26',
#   '12월',
#   '최지용',
#   'http://www.hyms.kr',
#   '울산광역시'),
#  ('코스닥',
#   'HB인베스트먼트',
#   '44029',
#   '기타 금융업',
#   '벤처투자조합 등 조합 결성 및 운영',
#   '2024-01-25',
#   '12월',
#   '황유선',
#   'http://www.hbvc.co.kr',
#   '서울특별시'),
#  ('코스닥',
#   '드림인사이트',
#   '36299',
#   '광고업',
#   '광고대행',
#   '2024-01-25',
#   '12월',
#   '김기철',
#   'http://bydream.co.kr/',
#   '서울특별시'),
#  ('코스닥',
#   '대신밸런스제17호스팩',
#   '47105',
#   '금융 지원 서비스업',
#   '금융 지원 서비스업',
#   '2024-01-24',
#   '12월',
#   '이문수',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '우진엔텍',
#   '45755',
#   '그외 기타 전문, 과학 및 기술 서비스업',
#   '발전소 계측제어설비 정비 서비스',
#   '2024-01-24',
#   '12월',
#   '신상연',
#   'http://www.woojinntec.com/',
#   '경기도'),
#  ('코넥스',
#   '세븐브로이맥주',
#   '26708',
#   '알코올음료 제조업',
#   '맥주 등 주류 및 음료',
#   '2024-01-17',
#   '12월',
#   '김강삼',
#   'http://sevenbrau.com',
#   '전북특별자치도'),
#  ('코스닥',
#   '한빛레이저',
#   '45219',
#   '특수 목적용 기계 제조업',
#   '산업용 레이저 가공장비',
#   '2024-01-04',
#   '12월',
#   '김정묵',
#   'http://www.hblaser.co.kr',
#   '대전광역시'),
#  ('유가증권',
#   '포스코DX',
#   '02210',
#   '건축기술, 엔지니어링 및 관련 기술 서비스업',
#   'EIC 자동화 엔지니어링 및 IT서비스',
#   '2024-01-02',
#   '12월',
#   '심민석',
#   'http://www.poscodx.com/kor/',
#   '경상북도'),
#  ('유가증권',
#   'DS단석',
#   '01786',
#   '기타 화학제품 제조업',
#   '바이오에너지',
#   '2023-12-22',
#   '12월',
#   '한승욱',
#   'http://dsdansuk.com',
#   '경기도'),
#  ('코스닥',
#   'IBKS제23호스팩',
#   '46793',
#   '금융 지원 서비스업',
#   '기업인수 및 합병',
#   '2023-12-22',
#   '12월',
#   '최상규',
#   'http://www.ibks.com',
#   '서울특별시'),
#  ('코스닥',
#   '하나30호스팩',
#   '46988',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2023-12-22',
#   '12월',
#   '전신웅',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '씨싸이트',
#   '10967',
#   '봉제의복 제조업',
#   '니트류 OEM',
#   '2023-12-21',
#   '12월',
#   '김상기',
#   'http://www.c-site.co.kr',
#   '서울특별시'),
#  ('코스닥',
#   '블루엠텍',
#   '43958',
#   '기타 전문 도매업',
#   '의약품 유통업',
#   '2023-12-13',
#   '12월',
#   '김현수',
#   'http://www.bluemtec.com',
#   '경기도'),
#  ('코스닥',
#   'LS머트리얼즈',
#   '41720',
#   '전자부품 제조업',
#   '울트라커패시터(셀 및 모듈)',
#   '2023-12-12',
#   '12월',
#   '홍영호',
#   '',
#   '경기도'),
#  ('코스닥',
#   '케이엔에스',
#   '43247',
#   '특수 목적용 기계 제조업',
#   '이차전지 자동화 설비',
#   '2023-12-06',
#   '12월',
#   '정봉진',
#   'http://knssystem.com',
#   '경기도'),
#  ('코스닥',
#   '교보15호스팩',
#   '46532',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2023-12-05',
#   '12월',
#   '김상도',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '와이바이오로직스',
#   '33884',
#   '자연과학 및 공학 연구개발업',
#   '항체의약품 및 항체후보물질 연구개발',
#   '2023-12-05',
#   '12월',
#   '박영우, 장우익',
#   'http://ybiologics.com',
#   '대전광역시'),
#  ('코스닥',
#   '삼성스팩9호',
#   '46851',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2023-12-04',
#   '12월',
#   '오정헌',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '에이텀',
#   '35569',
#   '전자부품 제조업',
#   '평판형 트랜스',
#   '2023-12-01',
#   '12월',
#   '한택수',
#   'http://www.iatum.com/',
#   '서울특별시'),
#  ('코스닥',
#   '엔에이치스팩30호',
#   '46691',
#   '금융 지원 서비스업',
#   '금융지원서비스업',
#   '2023-12-01',
#   '12월',
#   '조선희',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '에이에스텍',
#   '45386',
#   '기타 화학제품 제조업',
#   '자외선 차단제 유기 원료',
#   '2023-11-28',
#   '12월',
#   '윤종배,이승재',
#   'http://www.asteh.co.kr',
#   '충청남도'),
#  ('코스닥',
#   '그린리소스',
#   '40249',
#   '반도체 제조업',
#   '반도체 및 디스플레이 장비 보호코팅 및 소재',
#   '2023-11-24',
#   '12월',
#   '이종수,이종범(공동대표이사)',
#   'http://www.greenresource.kr',
#   '인천광역시'),
#  ('코스닥',
#   '제이엔비',
#   '45216',
#   '특수 목적용 기계 제조업',
#   '진공 펌프용 유틸리티 장치(Stacker 등), 정밀가공 부품',
#   '2023-11-24',
#   '12월',
#   '이정범',
#   'http://www.jnbeng.com/',
#   '경기도'),
#  ('코스닥',
#   '한선엔지니어링',
#   '45228',
#   '기타 금속 가공제품 제조업',
#   '계장용 피팅 및 밸브, 모듈',
#   '2023-11-24',
#   '12월',
#   '이제훈',
#   'http://www.slok.co.kr',
#   '부산광역시'),
#  ('유가증권',
#   '동인기연',
#   '11138',
#   '가죽, 가방 및 유사제품 제조업',
#   '스포츠용품(등산용가방,골프백),금속압형제품,유아용품 제조,도소매,통신 판매/부동산 임대',
#   '2023-11-21',
#   '12월',
#   '정인수',
#   'http://www.dong-in.com/',
#   '경기도'),
#  ('코스닥',
#   '에코아이',
#   '44828',
#   '기타 전문 서비스업',
#   '탄소배출권 및 탄소배출권 관련 컨설팅',
#   '2023-11-21',
#   '12월',
#   '이수복',
#   'http://www.ecoeye.com',
#   '서울특별시'),
#  ('코스닥',
#   '스톰테크',
#   '35209',
#   '플라스틱제품 제조업',
#   '정수기 피팅, 밸브, 파우셋 등 부품',
#   '2023-11-20',
#   '12월',
#   '강기환, 최준수',
#   'http://www.stormtec.co.kr/',
#   '서울특별시'),
#  ('유가증권',
#   '에코프로머티',
#   '45008',
#   '일차전지 및 이차전지 제조업',
#   '배터리 양극재용 핵심소재 하이니켈 전구체',
#   '2023-11-17',
#   '12월',
#   '김병훈',
#   'http://ecopromaterials.com/',
#   '경상북도'),
#  ('코스닥',
#   '캡스톤파트너스',
#   '45230',
#   '기타 금융업',
#   '벤처투자조합 등 조합 결성 및 운영',
#   '2023-11-15',
#   '12월',
#   '송은강',
#   'http://cspartners.co.kr',
#   '서울특별시'),
#  ('코넥스',
#   '프로젠',
#   '29616',
#   '자연과학 및 공학 연구개발업',
#   '바이오의약품',
#   '2023-11-15',
#   '12월',
#   '김종균',
#   'http://progen.co.kr/',
#   '서울특별시'),
#  ('코스닥',
#   '에스와이스틸텍',
#   '36533',
#   '구조용 금속제품, 탱크 및 증기발생기 제조업',
#   '데크플레이트',
#   '2023-11-13',
#   '12월',
#   '홍성균',
#   'http://systeeltech.com/',
#   '충청북도'),
#  ('코스닥',
#   '에이직랜드',
#   '44509',
#   '반도체 제조업',
#   '비메모리 반도체 설계및 제조, 전자회로 연구, 설계, 레이아웃 등',
#   '2023-11-13',
#   '12월',
#   '이종민',
#   'http://www.asicland.com',
#   '경기도'),
#  ('코스닥',
#   '한국제13호스팩',
#   '46444',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2023-11-13',
#   '12월',
#   '김장하',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '메가터치',
#   '44654',
#   '일차전지 및 이차전지 제조업',
#   '배터리 핀, 반도체 핀',
#   '2023-11-09',
#   '12월',
#   '윤재홍',
#   'http://www.megatouch.co.kr/',
#   '충청남도'),
#  ('코스닥',
#   '비아이매트릭스',
#   '41364',
#   '소프트웨어 개발 및 공급업',
#   '로우코드 기반 코딩 자동화 솔루션 등',
#   '2023-11-09',
#   '12월',
#   '배영근',
#   'http://www.bimatrix.co.kr',
#   '서울특별시'),
#  ('코스닥',
#   '컨텍',
#   '45176',
#   '컴퓨터 프로그래밍, 시스템 통합 및 관리업',
#   '지상국 시스템 엔지니어링 솔루션, 위성영상 생성을 위한 데이터처리 솔루션',
#   '2023-11-09',
#   '12월',
#   '이성희',
#   'http://kr.contec.kr/',
#   '대전광역시'),
#  ('코스닥',
#   '큐로셀',
#   '37232',
#   '자연과학 및 공학 연구개발업',
#   'CAR-T 세포치료제',
#   '2023-11-09',
#   '12월',
#   '김건수',
#   'http://curocellbtx.com',
#   '대전광역시'),
#  ('코스닥',
#   '쏘닉스',
#   '08828',
#   '반도체 제조업',
#   'RF필터 파운드리',
#   '2023-11-07',
#   '12월',
#   '양형국',
#   'http://www.sawnics.com',
#   '경기도'),
#  ('코스닥',
#   'KB제27호스팩',
#   '46468',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2023-11-03',
#   '12월',
#   '이태영',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '세니젠',
#   '18826',
#   '그외 기타 제품 제조업',
#   'Genelix, Genext, Geneka 등',
#   '2023-11-03',
#   '12월',
#   '박정웅',
#   'http://sanigen.kr',
#   '경기도'),
#  ('코스닥',
#   '신시웨이',
#   '29056',
#   '소프트웨어 개발 및 공급업',
#   'DB보안솔루션 등',
#   '2023-11-03',
#   '12월',
#   '정재훈, 유경석 (각자 대표이사)',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '유진테크놀로지',
#   '24060',
#   '기타 금속 가공제품 제조업',
#   '이차전지 정밀금형 외',
#   '2023-11-02',
#   '12월',
#   '여현국, 이미연',
#   'http://www.yujintechnology.com/',
#   '충청북도'),
#  ('코스닥',
#   '유투바이오',
#   '22180',
#   '기타 과학기술 서비스업',
#   '체외진단검사서비스, 의료IT솔루션',
#   '2023-11-02',
#   '12월',
#   '김진태',
#   'http://www.u2bio.com',
#   '서울특별시'),
#  ('코스닥',
#   '퀄리타스반도체',
#   '43272',
#   '반도체 제조업',
#   '초고속 통신용 반도체 IP',
#   '2023-10-27',
#   '12월',
#   '김두호',
#   'http://q-semi.com',
#   '경기도'),
#  ('코넥스',
#   '미쥬',
#   '35102',
#   '봉제의복 제조업',
#   '여성의류, 골프의류 등',
#   '2023-10-26',
#   '12월',
#   '황승주',
#   'http://lenic.co.kr',
#   '서울특별시'),
#  ('코스닥',
#   '워트',
#   '39647',
#   '특수 목적용 기계 제조업',
#   '초정밀 온습도 제어장비',
#   '2023-10-26',
#   '12월',
#   '박승배, 양귀철(각자 대표이사)',
#   'http://wot.co.kr',
#   '경기도'),
#  ('코스닥',
#   '에스엘에스바이오',
#   '24625',
#   '그외 기타 전문, 과학 및 기술 서비스업',
#   '의약품 품질관리, 신약개발지원, 체외진단기기',
#   '2023-10-20',
#   '12월',
#   '이영태',
#   'http://www.slabs.co.kr',
#   '경기도'),
#  ('코스닥',
#   '신성에스티',
#   '41618',
#   '자동차 신품 부품 제조업',
#   '전기차/2차전지 Busbar 및 배터리모듈 보호 부품 등',
#   '2023-10-19',
#   '12월',
#   '안병두, 손태도(각자 대표)',
#   'http://shinsungst.co.kr',
#   '경상남도'),
#  ('코스닥',
#   '퓨릿',
#   '44518',
#   '기초 화학물질 제조업',
#   '반도체용 케미컬, 디스플레이용 케미컬, 산업용 케미컬',
#   '2023-10-18',
#   '12월',
#   '김정수',
#   'http://purit.co.kr',
#   '경상북도'),
#  ('코넥스',
#   '바이오텐',
#   '28917',
#   '기타 식품 제조업',
#   '일반식품, 건강기능식품, 보조사료',
#   '2023-10-13',
#   '12월',
#   '김영철',
#   'http://www.bioten.co.kr',
#   '전북특별자치도'),
#  ('코스닥',
#   '에이치엠씨제6호스팩',
#   '46202',
#   '금융 지원 서비스업',
#   '합병',
#   '2023-10-13',
#   '12월',
#   '한웅',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '아이엠티',
#   '45122',
#   '특수 목적용 기계 제조업',
#   '건식세정 장비 및 EUV Mask Baking Laser',
#   '2023-10-10',
#   '12월',
#   '최재성',
#   'http://www.imt-c.co.kr/kor/',
#   '경기도'),
#  ('코스닥',
#   '레뷰코퍼레이션',
#   '44325',
#   '광고업',
#   'REVU 서비스(컨텐츠마케팅, 로컬, 에이전시)',
#   '2023-10-06',
#   '12월',
#   '송인상',
#   'http://corp.revu.net',
#   '서울특별시'),
#  ('유가증권',
#   '두산로보틱스',
#   '45491',
#   '특수 목적용 기계 제조업',
#   '협동로봇',
#   '2023-10-05',
#   '12월',
#   '박인원, 김민표, 조길성',
#   'http://www.doosanrobotics.com',
#   '경기도'),
#  ('코스닥',
#   '신한제11호스팩',
#   '45298',
#   '금융 지원 서비스업',
#   '금융서비스(기업인수목적 회사)',
#   '2023-10-04',
#   '12월',
#   '오정훈',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '한싹',
#   '43069',
#   '소프트웨어 개발 및 공급업',
#   '망간자료전송',
#   '2023-10-04',
#   '12월',
#   '이주도',
#   'http://www.hanssak.co.kr',
#   '서울특별시'),
#  ('코스닥',
#   '밀리의서재',
#   '41847',
#   '서적, 잡지 및 기타 인쇄물 출판업',
#   '전자책 정기구독 서비스',
#   '2023-09-27',
#   '12월',
#   '박현진',
#   'http://www.millie.co.kr/v3/brand/update',
#   '서울특별시'),
#  ('코스닥',
#   '인스웨이브시스템즈',
#   '45052',
#   '소프트웨어 개발 및 공급업',
#   'UI/UX 개발 솔루션, 엔터프라이즈 DX 솔루션, 금융 단말 솔루션 등',
#   '2023-09-25',
#   '12월',
#   '어세룡',
#   'http://www.inswave.com',
#   '서울특별시'),
#  ('코스닥',
#   '우듬지팜',
#   '40349',
#   '과실, 채소 가공 및 저장 처리업',
#   '스테비아 토마토, 대추방울 토마토, 완숙 토마토 등',
#   '2023-09-19',
#   '12월',
#   '심용보',
#   'http://www.wdgfarm.com',
#   '충청남도'),
#  ('코스닥',
#   '코어라인소프트',
#   '38447',
#   '소프트웨어 개발 및 공급업',
#   '의료영상 진단보조 솔루션',
#   '2023-09-18',
#   '12월',
#   '김진국',
#   'http://www.corelinesoft.com',
#   '서울특별시'),
#  ('유가증권',
#   'STX그린로지스',
#   '46577',
#   '해상 운송업',
#   '해상운송업 및 물류업',
#   '2023-09-15',
#   '12월',
#   '유재호',
#   'http://www.stxgreenlogis.co.kr/',
#   '부산광역시'),
#  ('코스닥',
#   '상상인제4호스팩',
#   '45267',
#   '금융 지원 서비스업',
#   '합병',
#   '2023-09-14',
#   '12월',
#   '양범',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '율촌',
#   '14606',
#   '1차 철강 제조업',
#   '냉간인발강관(파이프)',
#   '2023-09-08',
#   '12월',
#   '이흥해, 이인호',
#   'http://www.ycpipe.com',
#   '경기도'),
#  ('코스닥',
#   '한화플러스제4호스팩',
#   '45531',
#   '금융 지원 서비스업',
#   '-',
#   '2023-09-07',
#   '12월',
#   '김민철',
#   'http://hanwha-plus-no4spac.com',
#   '서울특별시'),
#  ('코스닥',
#   '대신밸런스제16호스팩',
#   '45763',
#   '금융 지원 서비스업',
#   '기타 금융서비스업',
#   '2023-09-04',
#   '12월',
#   '정재중',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '유안타제11호스팩',
#   '44492',
#   '금융 지원 서비스업',
#   '금융 지원 서비스업',
#   '2023-09-01',
#   '12월',
#   '임원현',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '크라우드웍스',
#   '35539',
#   '소프트웨어 개발 및 공급업',
#   '인공지능 데이터 구축 서비스',
#   '2023-08-31',
#   '12월',
#   '김우승',
#   'http://www.crowdworks.kr',
#   '서울특별시'),
#  ('코스닥',
#   '대신밸런스제15호스팩',
#   '45739',
#   '금융 지원 서비스업',
#   '금융 지원 서비스업',
#   '2023-08-30',
#   '12월',
#   '신진호',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '한국제12호스팩',
#   '45861',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2023-08-30',
#   '12월',
#   '이연경',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '시큐레터',
#   '41825',
#   '소프트웨어 개발 및 공급업',
#   'SLE(이메일 보안), SLF(파일 보안)',
#   '2023-08-24',
#   '12월',
#   '정동진',
#   'http://www.seculetter.com/',
#   '경기도'),
#  ('코스닥',
#   '스마트레이더시스템',
#   '42496',
#   '측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외',
#   '모빌리티 및 비모빌리티용 4D이미징레이다',
#   '2023-08-22',
#   '12월',
#   '김용환',
#   'http://www.smartradarsystem.com',
#   '경기도'),
#  ('유가증권',
#   '넥스틸',
#   '09279',
#   '1차 철강 제조업',
#   'OCTG Pipe, Line Pipe, Standard Pipe, 일반관',
#   '2023-08-21',
#   '12월',
#   '홍성만',
#   'http://www.nexteel.co.kr',
#   '경상북도'),
#  ('코스닥',
#   '캔버스엔',
#   '21012',
#   '영화, 비디오물, 방송프로그램 제작 및 배급업',
#   '방송영상 제작, 공급',
#   '2023-08-17',
#   '12월',
#   '오희갑',
#   'http://victents.com',
#   '서울특별시'),
#  ('코스닥',
#   'SK증권제10호스팩',
#   '45794',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2023-08-11',
#   '12월',
#   '장희정',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '코츠테크놀로지',
#   '44871',
#   '컴퓨터 및 주변장치 제조업',
#   '싱글보드컴퓨터(SBC), 군용 전시기 등',
#   '2023-08-10',
#   '12월',
#   '조지원',
#   'http://www.cotstech.com/',
#   '경기도'),
#  ('코스닥',
#   '큐리옥스바이오시스템즈',
#   '44568',
#   '의료용 기기 제조업',
#   '세포 전처리 자동화기기 등',
#   '2023-08-10',
#   '12월',
#   '김남용',
#   'http://curiox.co.kr/',
#   '서울특별시'),
#  ('코스닥',
#   '하나28호스팩',
#   '45475',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2023-08-10',
#   '12월',
#   '오동호',
#   '',
#   '서울특별시'),
#  ('유가증권',
#   'NICE평가정보',
#   '03019',
#   '기타 정보 서비스업',
#   '개인 및 기업정보, 솔루션',
#   '2023-08-08',
#   '12월',
#   '김종윤',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '파두',
#   '44011',
#   '반도체 제조업',
#   'SSD 컨트롤러',
#   '2023-08-07',
#   '12월',
#   '이지효,남이현',
#   'http://www.fadu.io/',
#   '서울특별시'),
#  ('코스닥',
#   '엠아이큐브솔루션',
#   '37317',
#   '소프트웨어 개발 및 공급업',
#   '스마트팩토리 솔루션, 제조지능화 솔루션',
#   '2023-08-04',
#   '12월',
#   '박문원, 조영택',
#   'http://www.micube.co.kr',
#   '서울특별시'),
#  ('코스닥',
#   '시지트로닉스',
#   '42927',
#   '반도체 제조업',
#   '특화반도체 소자',
#   '2023-08-03',
#   '12월',
#   '심규환 (단독 대표이사)',
#   'http://sigetronics.com',
#   '전북특별자치도'),
#  ('코넥스',
#   '에피바이오텍',
#   '44644',
#   '자연과학 및 공학 연구개발업',
#   '탈모 치료제',
#   '2023-07-31',
#   '12월',
#   '성종혁',
#   'http://epibiotech.com/',
#   '인천광역시'),
#  ('유가증권',
#   '조선내화',
#   '46252',
#   '내화, 비내화 요업제품 제조업',
#   '내화 요업제품',
#   '2023-07-28',
#   '12월',
#   '최광철',
#   '',
#   '전라남도'),
#  ('코스닥',
#   '에이엘티',
#   '17267',
#   '반도체 제조업',
#   '반도체 테스트 및 패키징(반도체 후공정)',
#   '2023-07-27',
#   '12월',
#   '천병태',
#   'http://alt-s.kr',
#   '충청북도'),
#  ('코스닥',
#   '유안타제14호스팩',
#   '45094',
#   '금융 지원 서비스업',
#   '금융 지원 서비스',
#   '2023-07-27',
#   '12월',
#   '엄수열',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '파로스아이바이오',
#   '38887',
#   '자연과학 및 공학 연구개발업',
#   'PHI-101 급성골수성백혈병 치료제 및 재발성난소암 치료제',
#   '2023-07-27',
#   '12월',
#   '윤정혁',
#   'http://www.pharosibio.com/',
#   '경기도'),
#  ('코넥스',
#   '길교이앤씨',
#   '45670',
#   '건축기술, 엔지니어링 및 관련 기술 서비스업',
#   '강합성 라멘교',
#   '2023-07-26',
#   '12월',
#   '김선동',
#   '길교.com',
#   '경상북도'),
#  ('코스닥',
#   '버넥트',
#   '43870',
#   '소프트웨어 개발 및 공급업',
#   '산업용 XR 솔루션',
#   '2023-07-26',
#   '12월',
#   '하태진',
#   'http://www.virnect.com',
#   '서울특별시'),
#  ('코스닥',
#   '뷰티스킨',
#   '40682',
#   '기타 화학제품 제조업',
#   '화장품 제조, 브랜드, 유통 사업',
#   '2023-07-24',
#   '12월',
#   '김종수, 최범석',
#   'http://beautyskincorp.co.kr/',
#   '인천광역시'),
#  ('코스닥',
#   'SK증권제9호스팩',
#   '45591',
#   '금융 지원 서비스업',
#   '기업인수목적회사',
#   '2023-07-21',
#   '12월',
#   '한현석',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '와이랩',
#   '43243',
#   '영화, 비디오물, 방송프로그램 제작 및 배급업',
#   '만화출판물의 제작 및 영상물 제작',
#   '2023-07-20',
#   '12월',
#   '심준경',
#   'http://ylabcomics.com',
#   '서울특별시'),
#  ('코스닥',
#   '센서뷰',
#   '32137',
#   '절연선 및 케이블 제조업',
#   'T&M 케이블, 초소형 전송선로',
#   '2023-07-19',
#   '12월',
#   '김병남',
#   'http://www.sensor-view.com',
#   '경기도'),
#  ('코넥스',
#   '아이엠지티',
#   '45657',
#   '의료용품 및 기타 의약 관련제품 제조업',
#   '치료용 집속초음파 기기',
#   '2023-07-19',
#   '12월',
#   '이학종, 손건호 (각자 대표이사)',
#   'http://www.imgt.co.kr/',
#   '경기도'),
#  ('코스닥',
#   '필에너지',
#   '37834',
#   '특수 목적용 기계 제조업',
#   '2차전지 제조장비',
#   '2023-07-14',
#   '12월',
#   '김광일',
#   'http://philenergy.co.kr',
#   '경기도'),
#  ('코스닥',
#   'DB금융스팩11호',
#   '45644',
#   '기타 금융업',
#   '기업인수목적',
#   '2023-07-12',
#   '12월',
#   '김동식',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '교보14호스팩',
#   '45649',
#   '금융 지원 서비스업',
#   '기업 인수 및 합병',
#   '2023-07-06',
#   '12월',
#   '박상연',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '이노시뮬레이션',
#   '27440',
#   '소프트웨어 개발 및 공급업',
#   '스마트 모빌리티 시뮬레이터, XR 가상훈련 시스템 등',
#   '2023-07-06',
#   '12월',
#   '조준희',
#   'http://www.innosim.com',
#   '서울특별시'),
#  ('코스닥',
#   '알멕',
#   '35432',
#   '1차 비철금속 제조업',
#   '알루미늄 압출 제품',
#   '2023-06-30',
#   '12월',
#   '신상호',
#   'http://www.almac.co.kr',
#   '경상남도'),
#  ('코스닥',
#   '오픈놀',
#   '44032',
#   '소프트웨어 개발 및 공급업',
#   '미니인턴플랫폼(커리어 및 채용 플랫폼)',
#   '2023-06-30',
#   '12월',
#   '권인택',
#   'http://openknowl.com',
#   '서울특별시'),
#  ('코스닥',
#   '시큐센',
#   '23283',
#   '소프트웨어 개발 및 공급업',
#   '디지털 금융 서비스 구축, 모바일 보안솔루션, 생체인증 전자서명',
#   '2023-06-29',
#   '12월',
#   '한상욱',
#   'http://www.secucen.com/',
#   '경기도'),
#  ('코스닥',
#   '하나29호스팩',
#   '45464',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2023-06-28',
#   '12월',
#   '윤경순',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   'KB제25호스팩',
#   '45525',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2023-06-23',
#   '12월',
#   '전현식',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '엔에이치스팩29호',
#   '45170',
#   '금융 지원 서비스업',
#   '금융 지원 서비스업',
#   '2023-06-23',
#   '12월',
#   '박준우',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '하이제8호스팩',
#   '45005',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2023-06-22',
#   '12월',
#   '정우주',
#   '',
#   '서울특별시'),
#  ('코넥스',
#   '가이아코퍼레이션',
#   '29652',
#   '생활용품 도매업',
#   '유아용품, 완구, 굿즈',
#   '2023-06-20',
#   '12월',
#   '나원석',
#   'http://gaiabiz.co.kr/',
#   '경기도'),
#  ('유가증권',
#   '비에이치',
#   '09046',
#   '전자부품 제조업',
#   'FPCB (연성인쇄회로기판)',
#   '2023-06-20',
#   '12월',
#   '최영식',
#   'http://www.bhe.co.kr',
#   '인천광역시'),
#  ('유가증권',
#   '동국씨엠',
#   '46085',
#   '1차 철강 제조업',
#   '냉연강판, 칼라강판',
#   '2023-06-16',
#   '12월',
#   '박상훈',
#   'http://www.dongkukcm.com',
#   '서울특별시'),
#  ('유가증권',
#   '동국제강',
#   '46086',
#   '1차 철강 제조업',
#   '봉강,형강,후판,냉연강판,칼라강판',
#   '2023-06-16',
#   '12월',
#   '최삼영',
#   'http://www.dongkuksteel.com',
#   '서울특별시'),
#  ('코스닥',
#   '프로티아',
#   '30336',
#   '의료용 기기 제조업',
#   '알레르기 진단 제품',
#   '2023-06-16',
#   '12월',
#   '임국진',
#   'http://www.protia.co.kr',
#   '서울특별시'),
#  ('코스닥',
#   '큐라티스',
#   '34808',
#   '자연과학 및 공학 연구개발업',
#   '백신 및 면역증강제 개발제조업, CMO/CDMO',
#   '2023-06-15',
#   '12월',
#   '김성준',
#   'http://quratis.com',
#   '충청북도'),
#  ('코스닥',
#   '마녀공장',
#   '43909',
#   '기타 화학제품 제조업',
#   '자연주의 기능성 화장품',
#   '2023-06-08',
#   '12월',
#   '송지혜',
#   'http://www.manyo.co.kr',
#   '서울특별시'),
#  ('코스닥',
#   '나라셀라',
#   '40592',
#   '음·식료품 및 담배 도매업',
#   '와인 도소매',
#   '2023-06-02',
#   '12월',
#   '마승철',
#   'http://www.naracellar.com/',
#   '경기도'),
#  ('코스닥',
#   '진영',
#   '28580',
#   '플라스틱제품 제조업',
#   '가구용 ASA플라스틱 시트, 엣지밴드',
#   '2023-06-01',
#   '12월',
#   '심영수',
#   'http://www.jyp21.co.kr',
#   '인천광역시'),
#  ('유가증권',
#   '이수스페셜티케미컬',
#   '45719',
#   '기초 화학물질 제조업',
#   '석유화학제품 및 정밀화학제품',
#   '2023-05-31',
#   '12월',
#   '류승호',
#   'http://www.isuspecialtychemical.com',
#   '서울특별시'),
#  ('유가증권',
#   'OCI',
#   '45604',
#   '기초 화학물질 제조업',
#   '폴리실리콘,타르제품,카본블랙,무수프탈산,농약원제,석탄화학제품,정밀화학제품,플라스틱창호재 제조,판매',
#   '2023-05-30',
#   '12월',
#   '김유신, 김원현(2인, 각자 대표이사)',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '기가비스',
#   '42077',
#   '특수 목적용 기계 제조업',
#   '반도체 기판용 광학검사 및 수리장비',
#   '2023-05-24',
#   '12월',
#   '강해철',
#   'http://www.gigavis.com',
#   '경기도'),
#  ('코스닥',
#   '팸텍',
#   '27183',
#   '특수 목적용 기계 제조업',
#   '카메라모듈 검사장비, 반도체 검사장비',
#   '2023-05-23',
#   '12월',
#   '김재웅',
#   'http://www.pamtek.com/',
#   '경기도'),
#  ('코스닥',
#   '모니터랩',
#   '43448',
#   '소프트웨어 개발 및 공급업',
#   '웹방화벽,유해사이트솔루션,가시성SSL 솔루션, SASE플랫폼기반 SECaaS',
#   '2023-05-19',
#   '12월',
#   '이광후',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '씨유박스',
#   '34081',
#   '소프트웨어 개발 및 공급업',
#   'AI얼굴인식 시스템, AI얼굴인증 솔루션, AI 객체인식 솔루션, AI데이터 플랫폼',
#   '2023-05-19',
#   '12월',
#   '남운성',
#   'http://www.cubox.ai',
#   '서울특별시'),
#  ('코넥스',
#   '큐라켐',
#   '45619',
#   '의료용품 및 기타 의약 관련제품 제조업',
#   '방사성동위원소 표지화합물 합성',
#   '2023-05-18',
#   '12월',
#   '신숙정',
#   'http://www.curachem.com',
#   '충청북도'),
#  ('코스닥',
#   '키움제8호스팩',
#   '44684',
#   '금융 지원 서비스업',
#   '기업 인수합병',
#   '2023-05-17',
#   '12월',
#   '송현길',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '트루엔',
#   '41779',
#   '영상 및 음향기기 제조업',
#   'IP 카메라, 영상스트리밍솔루션, IoT기기 및 서비스',
#   '2023-05-17',
#   '12월',
#   '안재천',
#   'http://truen.co.kr',
#   '서울특별시'),
#  ('코넥스',
#   '삼미금속',
#   '01221',
#   '기타 금속 가공제품 제조업',
#   '상용차/중장비/선박엔진 부품',
#   '2023-05-16',
#   '12월',
#   '이남영',
#   'http://www.sammiforge.co.kr',
#   '경상남도'),
#  ('코스닥',
#   '에스바이오메딕스',
#   '30436',
#   '의약품 제조업',
#   '줄기세포 치료제 연구 및 개발',
#   '2023-05-04',
#   '12월',
#   '강세일',
#   'http://www.sbiomedics.com/',
#   '서울특별시'),
#  ('코스닥',
#   '슈어소프트테크',
#   '29883',
#   '소프트웨어 개발 및 공급업',
#   '소프트웨어 자동화 검증 플랫폼',
#   '2023-04-28',
#   '12월',
#   '배현섭',
#   'http://www.suresofttech.com/',
#   '경기도'),
#  ('코스닥',
#   '토마토시스템',
#   '39321',
#   '소프트웨어 개발 및 공급업',
#   'UI/UX솔루션, 대학정보화사업 SW',
#   '2023-04-27',
#   '12월',
#   '이상돈',
#   'http://tomatosystem.co.kr/',
#   '서울특별시'),
#  ('코스닥',
#   '마이크로투나노',
#   '42498',
#   '반도체 제조업',
#   '메모리 테스트용 프로브 카드',
#   '2023-04-26',
#   '12월',
#   '황규호',
#   'http://micro2nano.com',
#   '경기도'),
#  ('코스닥',
#   '셀바이오휴먼텍',
#   '31816',
#   '기타 섬유제품 제조업',
#   '마스크팩 섬유소재(시트)',
#   '2023-04-20',
#   '12월',
#   '이권선',
#   'http://cellbiohumantech.co.kr/',
#   '경기도'),
#  ('유가증권',
#   'SK오션플랜트',
#   '10009',
#   '1차 철강 제조업',
#   '해상풍력 하부구조물',
#   '2023-04-19',
#   '12월',
#   '이승철',
#   'http://www.skoceanplant.com/',
#   '경상남도'),
#  ('코넥스',
#   '노보믹스',
#   '28310',
#   '자연과학 및 공학 연구개발업',
#   '위암 예후예측 진단키트',
#   '2023-04-19',
#   '12월',
#   '허용민',
#   'http://novomics.com/',
#   '서울특별시'),
#  ('유가증권',
#   '삼성FN리츠',
#   '44873',
#   '부동산 임대 및 공급업',
#   '대치타워 및 에스원빌딩',
#   '2023-04-10',
#   '01월',
#   '이명규',
#   'http://www.samsungfnreit.com/',
#   '서울특별시'),
#  ('유가증권',
#   '현대그린푸드',
#   '45334',
#   '종합 소매업',
#   '푸드서비스(단체급식), 식자재유통서비스, 공산품/생식품 유통서비스',
#   '2023-04-10',
#   '12월',
#   '박홍진',
#   'http://hyundaigreenfood.com',
#   '경기도'),
#  ('코스닥',
#   '미래에셋비전스팩3호',
#   '44883',
#   '금융 지원 서비스업',
#   '기업인수목적회사(기타금융서비스)',
#   '2023-04-07',
#   '12월',
#   '나경수',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   'IBKS제22호스팩',
#   '44876',
#   '금융 지원 서비스업',
#   '기업인수 및 합병',
#   '2023-04-06',
#   '12월',
#   '윤별수',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '하나27호스팩',
#   '44837',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2023-04-06',
#   '12월',
#   '김철우',
#   '',
#   '서울특별시'),
#  ('유가증권',
#   '한화갤러리아',
#   '45226',
#   '종합 소매업',
#   '백화점',
#   '2023-03-31',
#   '12월',
#   '김영훈',
#   'http://www.hanwhagalleria.co.kr',
#   '서울특별시'),
#  ('코스닥',
#   '지아이이노베이션',
#   '35857',
#   '자연과학 및 공학 연구개발업',
#   '면역항암제 및 알레르기 치료제',
#   '2023-03-30',
#   '12월',
#   '장명호, 홍준호(각자대표이사)',
#   'http://www.gi-innovation.com/kr/',
#   '서울특별시'),
#  ('코스닥',
#   'LB인베스트먼트',
#   '30996',
#   '기타 금융업',
#   '중소기업 창업투자',
#   '2023-03-29',
#   '12월',
#   '박기호',
#   'http://lbinvestment.com/',
#   '서울특별시'),
#  ('유가증권',
#   '한화리츠',
#   '45180',
#   '부동산 임대 및 공급업',
#   '부동산투자',
#   '2023-03-27',
#   '04월',
#   '한화자산운용',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '유안타제12호스팩',
#   '44615',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2023-03-17',
#   '12월',
#   '장선호',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '엑스게이트',
#   '35668',
#   '소프트웨어 개발 및 공급업',
#   '통합 네트워크 보안 솔루션',
#   '2023-03-16',
#   '12월',
#   '주갑수',
#   'http://www.axgate.com',
#   '경기도'),
#  ('코스닥',
#   '미래에셋드림스팩1호',
#   '44290',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2023-03-15',
#   '12월',
#   '박장우',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '금양그린파워',
#   '28272',
#   '전기 및 통신 공사업',
#   '플랜트, 발전소 및 신재생에너지 발전소 공사 및 용역',
#   '2023-03-13',
#   '12월',
#   '이윤철, 이기보',
#   'http://www.kygp.co.kr',
#   '울산광역시'),
#  ('코스닥',
#   '라온텍',
#   '41842',
#   '전자부품 제조업',
#   '마이크로디스플레이, 컨트롤러 IC',
#   '2023-03-09',
#   '12월',
#   '김보은',
#   'RAON.io',
#   '경기도'),
#  ('코스닥',
#   '자람테크놀로지',
#   '38902',
#   '반도체 제조업',
#   'XGSPON, 기가와이어, 광트랜시버 등',
#   '2023-03-07',
#   '12월',
#   '백준현',
#   'http://zaram.com',
#   '경기도'),
#  ('코스닥',
#   '하나26호스팩',
#   '44675',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2023-03-07',
#   '12월',
#   '김상규',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '나노팀',
#   '41701',
#   '일반 목적용 기계 제조업',
#   '전기차용 방열제품',
#   '2023-03-03',
#   '12월',
#   '최윤성',
#   'http://www.nanotim.co.kr',
#   '대전광역시'),
#  ('코스닥',
#   '바이오인프라',
#   '19973',
#   '자연과학 및 공학 연구개발업',
#   '생동성시험, 검체 분석',
#   '2023-03-02',
#   '12월',
#   '이상득',
#   'http://bioinfrakorea.co.kr',
#   '경기도'),
#  ('코스닥',
#   '삼성스팩8호',
#   '44874',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2023-03-02',
#   '12월',
#   '안신영',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '유안타제13호스팩',
#   '44902',
#   '금융 지원 서비스업',
#   '금융 지원 서비스',
#   '2023-02-28',
#   '12월',
#   '이현범',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '미래에셋비전스팩2호',
#   '44619',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '2023-02-24',
#   '12월',
#   '이효상',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '이노진',
#   '34486',
#   '기타 화학제품 제조업',
#   '탈모케어제품(볼빅), 피부케어제품(Dr.메디션)',
#   '2023-02-20',
#   '12월',
#   '이광훈',
#   'http://www.innogene.com/',
#   '서울특별시'),
#  ('코스닥',
#   '화인써키트',
#   '12798',
#   '전자부품 제조업',
#   '인쇄회로기판(PCB)',
#   '2023-02-17',
#   '12월',
#   '유수권',
#   'http://finecircuit.co.kr/',
#   '인천광역시'),
#  ('코스닥',
#   '제이오',
#   '41855',
#   '건축기술, 엔지니어링 및 관련 기술 서비스업',
#   '탄소나노튜브, 금속탱크 및 유사용기',
#   '2023-02-16',
#   '12월',
#   '강득주',
#   'http://www.jeio.co.kr/',
#   '인천광역시'),
#  ('코스닥',
#   '샌즈랩',
#   '41108',
#   '소프트웨어 개발 및 공급업',
#   '사이버 위협 인텔리전스(CTI)',
#   '2023-02-15',
#   '12월',
#   '김기홍',
#   'http://www.sandslab.io',
#   '경기도'),
#  ('코스닥',
#   '꿈비',
#   '40740',
#   '가구 제조업',
#   '놀이방매트, 유아거실가구 등',
#   '2023-02-09',
#   '12월',
#   '박영건',
#   'http://ggumbi.com/',
#   '경기도'),
#  ('코스닥',
#   '스튜디오미르',
#   '40890',
#   '영화, 비디오물, 방송프로그램 제작 및 배급업',
#   '애니메이션 제작',
#   '2023-02-07',
#   '12월',
#   '유재명',
#   'http://www.studiomir.co.kr/',
#   '서울특별시'),
#  ('코스닥',
#   '삼기이브이',
#   '41905',
#   '자동차 신품 부품 제조업',
#   '배터리(이차전지) 부품 (엔드플레이트)',
#   '2023-02-03',
#   '12월',
#   '김치환',
#   'http://ev.samkee.com',
#   '충청남도'),
#  ('유가증권',
#   '코오롱모빌리티그룹',
#   '45014',
#   '자동차 판매업',
#   '수입자동차 유통 및 정비업',
#   '2023-01-31',
#   '12월',
#   '강이구, 최현석',
#   'http://www.kolonmobilitygroup.com/',
#   '서울특별시'),
#  ('코스닥',
#   '오브젠',
#   '41786',
#   '소프트웨어 개발 및 공급업',
#   'CRM 소프트웨어',
#   '2023-01-30',
#   '12월',
#   '전배문, 유용희',
#   'http://obzen.com',
#   '서울특별시'),
#  ('코스닥',
#   '미래반도체',
#   '25449',
#   '기타 전문 도매업',
#   '반도체',
#   '2023-01-27',
#   '12월',
#   '이정',
#   'http://www.miraisemi.co.kr/',
#   '서울특별시'),
#  ('코넥스',
#   '지슨',
#   '28986',
#   '소프트웨어 개발 및 공급업',
#   '무선 도청·해킹·불법촬영 탐지시스템',
#   '2023-01-26',
#   '12월',
#   '한동진',
#   'http://www.gitsn.com',
#   '서울특별시'),
#  ('코넥스',
#   '태양3C',
#   '05296',
#   '자동차 부품 및 내장품 판매업',
#   '와이어링 하네스 커넥터, 초음파 프로브 케이블',
#   '2023-01-26',
#   '12월',
#   '황창순',
#   'http://www.tae-yang.co.kr/',
#   '강원특별자치도'),
# ...
#   '엄준형',
#   'http://www.yhtec.com',
#   '충청남도'),
#  ('코스닥',
#   '폴라리스세원',
#   '23410',
#   '자동차 신품 부품 제조업',
#   '자동차 공조장치 부품',
#   '2017-10-20',
#   '12월',
#   '김영관',
#   'http://www.polaris-sewon.com',
#   '경기도'),
#  ('코스닥',
#   '상신전자',
#   '26381',
#   '전자부품 제조업',
#   '노이즈필터(48.81%), 코일(19.33%), 리액터(10.75%)',
#   '2017-10-16',
#   '12월',
#   '김승천',
#   'http://www.sangshin-e.com',
#   '경상남도'),
#  ('코스닥',
#   '야스',
#   '25544',
#   '특수 목적용 기계 제조업',
#   'OLED 증착기, OLED 증착원',
#   '2017-09-29',
#   '12월',
#   '강경인',
#   'http://www.yasoled.com',
#   '경기도'),
#  ('코스닥',
#   '인산가',
#   '27741',
#   '기타 식품 제조업',
#   '죽염 및 죽염응용식품',
#   '2017-09-29',
#   '12월',
#   '김윤세',
#   'http://www.insanga.co.kr',
#   '경상남도'),
#  ('코스닥',
#   '휴엠앤씨',
#   '26392',
#   '그외 기타 제품 제조업',
#   '유리용기, 화장용 스펀지, 퍼프',
#   '2017-09-28',
#   '12월',
#   '김준철',
#   'http://humnc.com',
#   '인천광역시'),
#  ('코스닥',
#   '신흥에스이씨',
#   '24384',
#   '일차전지 및 이차전지 제조업',
#   '2차전지용 안전 부품(Cap Assembly, CID)',
#   '2017-09-27',
#   '12월',
#   '황만용',
#   'http://www.shsec.co.kr',
#   '경기도'),
#  ('코스닥',
#   '유티아이',
#   '17990',
#   '전자부품 제조업',
#   '카메라 윈도우',
#   '2017-09-27',
#   '12월',
#   '박덕영',
#   'http://www.utikorea.com',
#   '충청남도'),
#  ('코스닥',
#   '선익시스템',
#   '17109',
#   '특수 목적용 기계 제조업',
#   'OLED 증착장비',
#   '2017-09-20',
#   '12월',
#   '박재규, 김혜동 (각자 대표이사)',
#   'http://www.sunic.co.kr',
#   '경기도'),
#  ('코스닥',
#   '엠플러스',
#   '25963',
#   '특수 목적용 기계 제조업',
#   '이차전지 자동화 조립설비',
#   '2017-09-20',
#   '12월',
#   '김종성',
#   'http://www.mplusi.co.kr',
#   '충청북도'),
#  ('코스닥',
#   '앱클론',
#   '17490',
#   '의료용품 및 기타 의약 관련제품 제조업',
#   '항체의약품',
#   '2017-09-18',
#   '12월',
#   '이종서',
#   'http://www.abclon.com',
#   '서울특별시'),
#  ('코스닥',
#   '펄어비스',
#   '26375',
#   '소프트웨어 개발 및 공급업',
#   '온라인게임 개발 서비스(검은사막)',
#   '2017-09-14',
#   '12월',
#   '허진영',
#   'http://www.pearlabyss.com',
#   '경기도'),
#  ('코스닥',
#   '케이피에스',
#   '25694',
#   '특수 목적용 기계 제조업',
#   'OLED  마스크 인장기',
#   '2017-09-06',
#   '12월',
#   '김하용',
#   'http://www.kpscorp.co.kr',
#   '경기도'),
#  ('코넥스',
#   'SK시그넷',
#   '26087',
#   '전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업',
#   '전기차 충전기',
#   '2017-08-30',
#   '12월',
#   '김종우',
#   'http://www.sksignet.com',
#   '전라남도'),
#  ('코스닥',
#   '덕우전자',
#   '26360',
#   '전자부품 제조업',
#   '카메라 모듈 부품',
#   '2017-08-28',
#   '12월',
#   '이준용',
#   'http://www.derkwoo.com',
#   '경상북도'),
#  ('코스닥',
#   '앱트뉴로사이언스',
#   '27052',
#   '건축기술, 엔지니어링 및 관련 기술 서비스업',
#   '지열냉난방시스템',
#   '2017-08-22',
#   '12월',
#   '김재섭',
#   'http://geolitenergy.com/',
#   '경기도'),
#  ('코스닥',
#   '케일럼',
#   '25861',
#   '구조용 금속제품, 탱크 및 증기발생기 제조업',
#   '지열발전설비, 항공기MRO, 항공부품제조',
#   '2017-08-22',
#   '12월',
#   '최연지',
#   'http://www.ewkinc.co.kr',
#   '부산광역시'),
#  ('코스닥',
#   '알에스오토메이션',
#   '14067',
#   '전자부품 제조업',
#   '모션제어기, 드라이브, 에너지제어장치',
#   '2017-08-11',
#   '12월',
#   '강덕현',
#   'http://www.rsautomation.co.kr',
#   '경기도'),
#  ('코스닥',
#   '컬러레이',
#   'HKG24',
#   '기타 금융업',
#   '화장품용 진주광택안료',
#   '2017-08-10',
#   '12월',
#   '줘중비아오',
#   'http://www.coloray.co.kr',
#   '홍콩'),
#  ('코스닥',
#   '와이즈버즈',
#   '27306',
#   '광고업',
#   '광고대행',
#   '2017-08-07',
#   '12월',
#   '김종원, 최호준(각자 대표이사)',
#   'http://www.wisebirds.co',
#   '경기도'),
#  ('코스닥',
#   '모트렉스',
#   '11899',
#   '자동차 신품 부품 제조업',
#   '차량용 인포테인먼트',
#   '2017-08-04',
#   '12월',
#   '이형환',
#   'http://www.motrex.co.kr',
#   '경기도'),
#  ('코스닥',
#   '데이타솔루션',
#   '26380',
#   '기계장비 및 관련 물품 도매업',
#   'EMC스토리지, SPSS, SI',
#   '2017-08-03',
#   '12월',
#   '배복태, 정교중',
#   'http://www.datasolution.kr',
#   '서울특별시'),
#  ('코스닥',
#   '지니언스',
#   '26386',
#   '소프트웨어 개발 및 공급업',
#   '네트워크 접근 제어 솔루션(NAC), 단말기반 지능형 위협 탐지 대응 솔루션(EDR)',
#   '2017-08-02',
#   '12월',
#   '이동범',
#   'http://www.genians.co.kr/',
#   '경기도'),
#  ('코스닥',
#   '디앤씨미디어',
#   '26372',
#   '서적, 잡지 및 기타 인쇄물 출판업',
#   '웹소설 콘텐츠',
#   '2017-08-01',
#   '12월',
#   '최원영',
#   'http://www.dncmedia.co.kr',
#   '서울특별시'),
#  ('코넥스',
#   '루켄테크놀러지스',
#   '16212',
#   '기타 전기장비 제조업',
#   'Vertical Probe Card. Test Socket. Probe Station & Unit.',
#   '2017-07-25',
#   '12월',
#   '안윤태',
#   'http://www.luken.co.kr',
#   '경기도'),
#  ('코스닥',
#   '힘스',
#   '23849',
#   '특수 목적용 기계 제조업',
#   'OLED Mask 인장기, OLED Mask 검사기 등',
#   '2017-07-20',
#   '12월',
#   '김주환',
#   'http://www.hims.co.kr',
#   '인천광역시'),
#  ('유가증권',
#   '제일약품',
#   '27198',
#   '의약품 제조업',
#   '의약품',
#   '2017-07-17',
#   '12월',
#   '성석제, 한상철 (공동대표)',
#   'http://www.jeilpharm.co.kr',
#   '서울특별시'),
#  ('코스닥',
#   '브이원텍',
#   '25163',
#   '특수 목적용 기계 제조업',
#   'LCD/OLED 압흔검사기, 2차전지 검사장비',
#   '2017-07-13',
#   '12월',
#   '김선중',
#   'http://www.v-one.co.kr',
#   '경기도'),
#  ('코스닥',
#   '아우딘퓨쳐스',
#   '22761',
#   '기타 화학제품 제조업',
#   '기초화장품, 마스크팩 등',
#   '2017-07-12',
#   '12월',
#   '최영욱, 나현수(각자대표)',
#   'http://www.outinco.com',
#   '서울특별시'),
#  ('코스닥',
#   '이녹스첨단소재',
#   '27229',
#   '전자부품 제조업',
#   'FPCB소재, 반도체 및 디스플레이 소재',
#   '2017-07-10',
#   '12월',
#   '장경호, 강정태(각자 대표이사)',
#   'http://www.innoxamc.com',
#   '충청남도'),
#  ('유가증권',
#   '카카오',
#   '03572',
#   '자료처리, 호스팅, 포털 및 기타 인터넷 정보매개 서비스업',
#   '인터넷 서비스(인터넷 광고)',
#   '2017-07-10',
#   '12월',
#   '정신아',
#   'http://www.kakaocorp.com',
#   '제주특별자치도'),
#  ('유가증권',
#   '오리온',
#   '27156',
#   '기타 식품 제조업',
#   '스낵 등 과자류',
#   '2017-07-07',
#   '12월',
#   '이승준',
#   'http://www.orionworld.com',
#   '서울특별시'),
#  ('코스닥',
#   '하림지주',
#   '00338',
#   '기타 금융업',
#   '지주사업',
#   '2017-06-30',
#   '12월',
#   '김홍국',
#   'http://www.harimholdings.co.kr',
#   '전북특별자치도'),
#  ('코스닥',
#   '덴티스',
#   '26120',
#   '의료용 기기 제조업',
#   '임플란트외',
#   '2017-06-26',
#   '12월',
#   '심기봉',
#   'http://www.dentis.co.kr',
#   '대구광역시'),
#  ('코넥스',
#   '메디안디노스틱',
#   '23325',
#   '의료용품 및 기타 의약 관련제품 제조업',
#   '동물질병 체외진단키트 및 진단용 시약',
#   '2017-06-26',
#   '12월',
#   '오진식, 고민수(각자 대표이사)',
#   'http://www.mediandiagnostics.com',
#   '강원특별자치도'),
#  ('코스닥',
#   '나인테크',
#   '26732',
#   '특수 목적용 기계 제조업',
#   '이차전지 제조 장비',
#   '2017-06-22',
#   '12월',
#   '박근노',
#   'http://www.naintec.co.kr',
#   '경기도'),
#  ('코넥스',
#   '에스알바이오텍',
#   '27021',
#   '기타 화학제품 제조업',
#   '화장품 제조 및 유통',
#   '2017-06-15',
#   '12월',
#   '이소형',
#   '',
#   '경기도'),
#  ('코넥스',
#   '뿌리깊은나무들',
#   '26617',
#   '영화, 비디오물, 방송프로그램 제작 및 배급업',
#   'TV 드라마 등',
#   '2017-06-09',
#   '12월',
#   '이재원',
#   'http://www.redwoods.co.kr',
#   '서울특별시'),
#  ('코스닥',
#   '보라티알',
#   '25000',
#   '음·식료품 및 담배 도매업',
#   '유가공품, 소스류, 파스타류',
#   '2017-06-08',
#   '12월',
#   '김대영,허훈(각자대표)',
#   'http://www.boratr.co.kr',
#   '서울특별시'),
#  ('코스닥',
#   '매일유업',
#   '26798',
#   '동·식물성 유지 및 낙농제품 제조업',
#   '유제품(우유, 분유, 발효유, 치즈, 음료 등)',
#   '2017-06-05',
#   '12월',
#   '김선희, 이인기, 곽정우(각자대표)',
#   'http://www.maeil.com',
#   '서울특별시'),
#  ('코스닥',
#   'LK삼양',
#   '22519',
#   '사진장비 및 광학기기 제조업',
#   '디지털 카메라용 교환렌즈',
#   '2017-06-02',
#   '12월',
#   '구본욱, 신승열 (각자 대표이사)',
#   'http://www.syopt.co.kr',
#   '경상남도'),
#  ('코스닥',
#   '이랜시스',
#   '26485',
#   '전자부품 제조업',
#   '비데도어락부품',
#   '2017-06-01',
#   '12월',
#   '심재귀',
#   'http://www.elensys.co.kr',
#   '인천광역시'),
#  ('코스닥',
#   '필옵틱스',
#   '16158',
#   '특수 목적용 기계 제조업',
#   '디스플레이 및 반도체 제조공정용 제작',
#   '2017-06-01',
#   '12월',
#   '한기수',
#   'http://www.philoptics.com/',
#   '경기도'),
#  ('유가증권',
#   '미원에스씨',
#   '26828',
#   '기초 화학물질 제조업',
#   '에너지경화수지',
#   '2017-05-22',
#   '12월',
#   '김형웅, 배원',
#   'http://www.miramer.co.kr',
#   '전북특별자치도'),
#  ('유가증권',
#   '경동도시가스',
#   '26729',
#   '연료용 가스 제조 및 배관공급업',
#   '도시가스',
#   '2017-05-12',
#   '12월',
#   '송재호, 나윤호',
#   'http://www.kdgas.co.kr',
#   '울산광역시'),
#  ('유가증권',
#   '넷마블',
#   '25127',
#   '소프트웨어 개발 및 공급업',
#   '온라인·모바일 게임 소프트웨어 개발 및 공급',
#   '2017-05-12',
#   '12월',
#   '김병규',
#   'http://company.netmarble.com',
#   '서울특별시'),
#  ('유가증권',
#   'HD현대',
#   '26725',
#   '기타 금융업',
#   '지주회사',
#   '2017-05-10',
#   '12월',
#   '권오갑, 정기선',
#   'http://www.hd.com',
#   '경기도'),
#  ('유가증권',
#   'HD현대건설기계',
#   '26727',
#   '일반 목적용 기계 제조업',
#   '굴삭기, 지게차, 휠로더 등',
#   '2017-05-10',
#   '12월',
#   '최철곤',
#   'http://www.hd-hyundaice.com',
#   '경기도'),
#  ('유가증권',
#   'HD현대일렉트릭',
#   '26726',
#   '전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업',
#   '변압기, 고압차단기, 회전기, 배전반 등',
#   '2017-05-10',
#   '12월',
#   '김영기',
#   'http://www.hd-hyundaielectric.com',
#   '경기도'),
#  ('코스닥',
#   '포인트엔지니어링',
#   '25663',
#   '기타 금속 가공제품 제조업',
#   '디스플레이 및 반도체 장비 부품',
#   '2017-05-02',
#   '12월',
#   '안범모, 강대현',
#   'http://www.pointeng.co.kr',
#   '충청남도'),
#  ('코스닥',
#   '하나머티리얼즈',
#   '16609',
#   '반도체 제조업',
#   '실리콘부품, 세라믹부품, 특수가스',
#   '2017-04-28',
#   '12월',
#   '김현주',
#   'http://hanamts.com',
#   '충청남도'),
#  ('코스닥',
#   '소프트캠프',
#   '25879',
#   '소프트웨어 개발 및 공급업',
#   '통합보안솔루션',
#   '2017-04-27',
#   '12월',
#   '배환국',
#   'http://www.softcamp.co.kr',
#   '경기도'),
#  ('코스닥',
#   '와이엠티',
#   '25137',
#   '기초 화학물질 제조업',
#   'PCB, 반도체 및 디스플레이 제조용 화학소재 등',
#   '2017-04-27',
#   '12월',
#   '전성욱, 백성규',
#   'http://www.ymtechnology.com',
#   '인천광역시'),
#  ('코넥스',
#   '파워풀엑스',
#   '26687',
#   '기타 화학제품 제조업',
#   '플렉스파워 리커버리크림',
#   '2017-04-24',
#   '12월',
#   '박인철',
#   'http://www.flexpower.co.kr',
#   '서울특별시'),
#  ('유가증권',
#   '크라운제과',
#   '26490',
#   '떡, 빵 및 과자류 제조업',
#   '비스킷, 스낵, 당과',
#   '2017-04-11',
#   '12월',
#   '윤석빈',
#   'http://www.crown.co.kr',
#   '서울특별시'),
#  ('코스닥',
#   'AP시스템',
#   '26552',
#   '특수 목적용 기계 제조업',
#   '디스플레이 제조 장비',
#   '2017-04-07',
#   '12월',
#   'Yoo Ho Sun',
#   'http://www.apsystems.co.kr',
#   '경기도'),
#  ('코스닥',
#   '유에스티',
#   '26377',
#   '1차 철강 제조업',
#   '스테인레스강관',
#   '2017-04-06',
#   '12월',
#   '김종식',
#   'http://www.u-st.co.kr',
#   '경상북도'),
#  ('코스닥',
#   '이엘피',
#   '06376',
#   '측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외',
#   'OLED 패널검사기 등',
#   '2017-04-06',
#   '12월',
#   '이재혁',
#   'http://www.elp.co.kr',
#   '경기도'),
#  ('코스닥',
#   '유비쿼스',
#   '26445',
#   '통신 및 방송 장비 제조업',
#   '스위치, FTTH',
#   '2017-03-31',
#   '12월',
#   '이상근, 이정길(공동대표)',
#   'http://www.ubiquoss.com',
#   '경기도'),
#  ('코스닥',
#   '서진시스템',
#   '17832',
#   '기타 전기장비 제조업',
#   '통신장비부품,휴대폰부품(메탈케이스 등)',
#   '2017-03-27',
#   '12월',
#   '전동규',
#   'http://seojinsystem.net',
#   '경기도'),
#  ('코스닥',
#   '코미코',
#   '18330',
#   '특수 목적용 기계 제조업',
#   '반도체 부품 세정 및 코팅',
#   '2017-03-23',
#   '12월',
#   '최용하',
#   'http://www.komico.com',
#   '경기도'),
#  ('코스닥',
#   '아스타',
#   '24672',
#   '의료용품 및 기타 의약 관련제품 제조업',
#   'MALDI-TOF 질량분석기 기반 진단시스템',
#   '2017-03-20',
#   '12월',
#   '조응준, 김양선 (각자대표이사)',
#   'http://www.astams.com',
#   '경기도'),
#  ('유가증권',
#   '덴티움',
#   '14572',
#   '의료용 기기 제조업',
#   '치과용 기기 제조업',
#   '2017-03-15',
#   '12월',
#   '서승우, 윤병호',
#   'http://www.dentium.co.kr',
#   '경기도'),
#  ('코스닥',
#   '에스디생명공학',
#   '21748',
#   '기타 화학제품 제조업',
#   '마스크팩, 기초화장품',
#   '2017-03-02',
#   '12월',
#   '김철',
#   'http://sdbiotech.co.kr',
#   '서울특별시'),
#  ('코스닥',
#   '신신제약',
#   '00280',
#   '의약품 제조업',
#   '파스류 (신신파스 아렉스 등)',
#   '2017-02-28',
#   '12월',
#   '이병기',
#   'http://www.sinsin.com',
#   '세종특별자치시'),
#  ('코스닥',
#   '에프엔에스테크',
#   '08350',
#   '특수 목적용 기계 제조업',
#   'OLED, LCD 제조 공정 장비',
#   '2017-02-27',
#   '12월',
#   '김팔곤, 양상재(공동대표)',
#   'http://www.fnstech.com',
#   '충청남도'),
#  ('코스닥',
#   '모바일어플라이언스',
#   '08726',
#   '소프트웨어 개발 및 공급업',
#   '블랙박스, 내비게이션, HUD, ADAS',
#   '2017-02-24',
#   '12월',
#   '이재신',
#   'http://www.mobileappliance.co.kr',
#   '경기도'),
#  ('코스닥',
#   '피씨엘',
#   '24182',
#   '의료용품 및 기타 의약 관련제품 제조업',
#   '다중 체외진단 제품, 플랫폼서비스',
#   '2017-02-23',
#   '12월',
#   '김소연',
#   'http://www.pclchip.com',
#   '서울특별시'),
#  ('유가증권',
#   '호전실업',
#   '11111',
#   '봉제의복 제조업',
#   '스포츠웨어 및 아웃도어 웨어 OEM',
#   '2017-02-02',
#   '12월',
#   '박용철\n박진호',
#   'http://www.hojeon.com',
#   '서울특별시'),
#  ('코스닥',
#   '서플러스글로벌',
#   '14007',
#   '기계장비 및 관련 물품 도매업',
#   '반도체 제조용 장비, 유휴기계설비 도소매',
#   '2017-01-25',
#   '12월',
#   '김정웅',
#   'http://www.surplusglobal.com',
#   '경기도'),
#  ('코스닥',
#   '유바이오로직스',
#   '20665',
#   '의약품 제조업',
#   '경구용 콜레라 백신, 바이오의약품 수탁 연구 및 제조',
#   '2017-01-24',
#   '12월',
#   '백영옥,허태영(공동대표이사)',
#   'http://www.eubiologics.com',
#   '서울특별시'),
#  ('코넥스',
#   '도부',
#   '22742',
#   '기타 전문 도매업',
#   ' 1) 마스크 도소매업 2) MB필터 생산 및 도소매업',
#   '2016-12-28',
#   '12월',
#   '김일순',
#   'http://www.dobumask.asia',
#   '경기도'),
#  ('코스닥',
#   '한국비엔씨',
#   '25684',
#   '기초 의약물질 제조업',
#   '필러 등 생체재료의료물질 개발',
#   '2016-12-28',
#   '12월',
#   '최완규',
#   'http://www.bnckorea.co.kr',
#   '대구광역시'),
#  ('코스닥',
#   'DSC인베스트먼트',
#   '24152',
#   '신탁업 및 집합투자업',
#   '투자조합 결성 및 투자',
#   '2016-12-19',
#   '12월',
#   '윤건수',
#   'http://www.dscinvestment.com',
#   '서울특별시'),
#  ('코스닥',
#   'TS인베스트먼트',
#   '24669',
#   '신탁업 및 집합투자업',
#   '투자조합 결성 및 투자',
#   '2016-12-15',
#   '12월',
#   '김웅, 변기수(각자 대표)',
#   'http://www.tsinvestment.co.kr',
#   '서울특별시'),
#  ('코스닥',
#   '피엠티',
#   '14776',
#   '측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외',
#   '반도체 검사용 프로브카드',
#   '2016-12-12',
#   '12월',
#   '조용호',
#   'http://pmt23.com',
#   '충청남도'),
#  ('코넥스',
#   '바이오프로테크',
#   '19929',
#   '의료용 기기 제조업',
#   '심전도 측정용 전극 등 ',
#   '2016-12-08',
#   '12월',
#   '박익로,김병전 (공동대표이사)',
#   'http://www.protechsite.com',
#   '강원특별자치도'),
#  ('코스닥',
#   '애니젠',
#   '19630',
#   '기초 의약물질 제조업',
#   '펩타이드 바이오소재 및 아미노산 펩타이드 신약',
#   '2016-12-07',
#   '12월',
#   '김재일, 심경재 (각자 대표)',
#   'http://www.anygen.com',
#   '광주광역시'),
#  ('코스닥',
#   '유니온커뮤니티',
#   '20345',
#   '통신 및 방송 장비 제조업',
#   '지문인식출입통제기',
#   '2016-12-07',
#   '12월',
#   '신요식',
#   'http://www.unioncomm.co.kr',
#   '서울특별시'),
#  ('코스닥',
#   '신라젠',
#   '21560',
#   '자연과학 및 공학 연구개발업',
#   '펙사벡(바이러스 항암면역치료제)',
#   '2016-12-06',
#   '12월',
#   '김재경',
#   'http://www.sillajen.com',
#   '서울특별시'),
#  ('코스닥',
#   '자비스',
#   '25412',
#   '특수 목적용 기계 제조업',
#   '자동엑스레이검사장비',
#   '2016-12-02',
#   '12월',
#   '김형철',
#   'http://www.xavis.co.kr',
#   '경기도'),
#  ('유가증권',
#   '핸즈코퍼레이션',
#   '14321',
#   '자동차 신품 부품 제조업',
#   '자동차 알루미늄 휠',
#   '2016-12-02',
#   '12월',
#   '승현창',
#   'http://www.handscorp.co.kr',
#   '인천광역시'),
#  ('코스닥',
#   '티이엠씨씨엔에스',
#   '24179',
#   '특수 목적용 기계 제조업',
#   '반도체 케미칼 및 특수가스, 반도체 장비',
#   '2016-12-01',
#   '12월',
#   '이동준',
#   'http://\thttp://www.oceanbridge.co.kr',
#   '경기도'),
#  ('코스닥',
#   '퓨쳐켐',
#   '22010',
#   '의약품 제조업',
#   'PET 방사성의약품, 자동합성장치, 합성시약 및 전구체',
#   '2016-12-01',
#   '12월',
#   '지대윤',
#   '',
#   '서울특별시'),
#  ('코스닥',
#   '뉴파워프라즈마',
#   '14496',
#   '특수 목적용 기계 제조업',
#   '플라즈마 세정기(Remote Plasma Cleaning Generator)',
#   '2016-11-30',
#   '12월',
#   '양재영',
#   'http://newpower.co.kr',
#   '경기도'),
#  ('코스닥',
#   '엘앤케이바이오',
#   '15610',
#   '의료용 기기 제조업',
#   '척추 임플란트',
#   '2016-11-30',
#   '12월',
#   '강국진(단독대표)',
#   'http://www.lnkbiomed.com',
#   '경기도'),
#  ('코넥스',
#   '에스엘테라퓨틱스',
#   '25854',
#   '자연과학 및 공학 연구개발업',
#   '줄기세포치료제, 화장품, 전자의료기기 등',
#   '2016-11-29',
#   '12월',
#   '최종성',
#   'http://www.stemlab.co.kr',
#   '서울특별시'),
#  ('코스닥',
#   '핸디소프트',
#   '22018',
#   '소프트웨어 개발 및 공급업',
#   'EKP, BPM, 네트워크장비',
#   '2016-11-24',
#   '12월',
#   '이준희',
#   'http://www.handysoft.co.kr',
#   '경기도'),
#  ('유가증권',
#   '두산밥캣',
#   '24156',
#   '특수 목적용 기계 제조업',
#   'Compact Equipment, Heavy Equipment, Portable Power',
#   '2016-11-18',
#   '12월',
#   '스캇성철박, 조덕제',
#   'http://www.doosanbobcat.com',
#   '경기도'),
#  ('유가증권',
#   '삼성바이오로직스',
#   '20794',
#   '기초 의약물질 제조업',
#   '바이오의약품',
#   '2016-11-10',
#   '12월',
#   '임존종보 (Rim John Chongbo)',
#   'http://www.samsungbiologics.com',
#   '인천광역시'),
#  ('코스닥',
#   '클리오',
#   '23788',
#   '기타 화학제품 제조업',
#   '색조화장품, 기초화장품',
#   '2016-11-09',
#   '12월',
#   '한현옥',
#   'http://www.clio.co.kr',
#   '서울특별시'),
#  ('코스닥',
#   '오가닉티코스메틱',
#   'HKG20',
#   '기타 금융업',
#   '유아용 화장품(클렌징, 여름용, 피부케어, 기능성 화장품)',
#   '2016-11-04',
#   '12월',
#   '채정망',
#   '',
#   '홍콩'),
#  ('코스닥',
#   '얼라인드',
#   '23812',
#   '사진장비 및 광학기기 제조업',
#   '자동세포카운팅시스템, 생체조직투명화시스템, 디지털세포이미징시스템',
#   '2016-11-03',
#   '12월',
#   '정연철',
#   'http://www.alignedgenetics.co.kr',
#   '경기도'),
#  ('코스닥',
#   '세화피앤씨',
#   '25250',
#   '기타 화학제품 제조업',
#   '염모제  등',
#   '2016-11-02',
#   '12월',
#   '이훈구',
#   'http://www.sewha.co.kr',
#   '충청북도'),
#  ('코넥스',
#   '아이티센코어',
#   '24387',
#   '컴퓨터 프로그래밍, 시스템 통합 및 관리업',
#   '건설ERP, 내부통제솔루션, 공간관리솔루션, 소프트웨어 개발 및 공급 자문/ IT 컨설팅 外',
#   '2016-10-31',
#   '12월',
#   '김우성',
#   'http://www.goodcen.com',
#   '경기도'),
#  ('코스닥',
#   '인크로스',
#   '21605',
#   '광고업',
#   '미디어렙서비스',
#   '2016-10-31',
#   '12월',
#   '손윤정',
#   'http://www.incross.com',
#   '서울특별시'),
#  ('코스닥',
#   '에이치엘사이언스',
#   '23961',
#   '기타 식품 제조업',
#   '건강기능식품 등',
#   '2016-10-28',
#   '12월',
#   '이해연',
#   'http://www.hlscience.com',
#   '경기도'),
#  ('코스닥',
#   '코스메카코리아',
#   '24171',
#   '기타 화학제품 제조업',
#   '화장품 OEM, ODM',
#   '2016-10-28',
#   '12월',
#   '조임래, 박은희(각자대표)',
#   'http://www.cosmecca.com',
#   '충청북도'),
#  ('유가증권',
#   'JW생명과학',
#   '23408',
#   '의약품 제조업',
#   '기초수액, TPN, 특수수액, HEMO, 영양수액 등',
#   '2016-10-27',
#   '12월',
#   '노정열',
#   'http://www.jw-lifescience.co.kr',
#   '충청남도'),
#  ('코스닥',
#   'GRT',
#   'HKG21',
#   '기타 금융업',
#   '광학필름, 포장필름',
#   '2016-10-25',
#   '06월',
#   '주영남',
#   '',
#   '홍콩'),
#  ('코넥스',
#   '안지오랩',
#   '25128',
#   '자연과학 및 공학 연구개발업',
#   '신약개발 및 체지방 감소 건강기능식품',
#   '2016-10-25',
#   '12월',
#   '김민영',
#   'http://www.angiolab.co.kr',
#   '대전광역시'),
#  ('코스닥',
#   '인텔리안테크',
#   '18930',
#   '통신 및 방송 장비 제조업',
#   '위성통신 안테나, 해상용 위성방송 수신안테나',
#   '2016-10-18',
#   '12월',
#   '성상엽',
#   'http://www.intelliantech.com',
#   '경기도'),
#  ('코스닥',
#   '에이치시티',
#   '07299',
#   '기타 과학기술 서비스업',
#   '기술검사서비스',
#   '2016-10-17',
#   '12월',
#   '허 봉 재',
#   'http://www.hct.co.kr',
#   '경기도'),
#  ('코스닥',
#   '잉글우드랩',
#   'USA11',
#   '기타 화학제품 제조업',
#   '화장품OEM·ODM',
#   '2016-10-14',
#   '12월',
#   '조현철',
#   'http://www.englewoodlab.com',
#   '미국'),
#  ('코스닥',
#   '앤디포스',
#   '23809',
#   '플라스틱제품 제조업',
#   'TSP용 양면 테이프, 윈도우 필름',
#   '2016-10-12',
#   '12월',
#   '권오빈, 김성진(각자 대표이사)',
#   'http://www.ndfos.com',
#   '충청북도'),
#  ('코스닥',
#   '수산아이앤티',
#   '05096',
#   '소프트웨어 개발 및 공급업',
#   '공유단말접속관리서비스, 보안솔루션 등',
#   '2016-10-11',
#   '12월',
#   '정은아',
#   'http://www.soosanint.co.kr',
#   '서울특별시'),
#  ('코스닥',
#   '미투온',
#   '20149',
#   '소프트웨어 개발 및 공급업',
#   '소셜 카지노 게임',
#   '2016-10-10',
#   '12월',
#   '손창욱',
#   'http://www.me2on.com',
#   '서울특별시'),
#  ...]

# %%
columns = soup.select_one('table')['summary'].split(", ")
columns.insert(0,'주식종목')
columns.insert(2,'종목코드')
#print(columns)
df=pd.DataFrame(company_infos,columns=columns)
df
# Out:
#       주식종목       회사명   종목코드                        업종  \
# 0      코스닥    한국피아이엠  44890             자동차 신품 부품 제조업
# 1      코스닥    에이유브랜즈  48107     섬유, 의복, 신발 및 가죽제품 소매업
# 2      코스닥    우양에이치씨  10197  구조용 금속제품, 탱크 및 증기발생기 제조업
# 3      코스닥        더즌  46286                    전기 통신업
# 4      코스닥      심플랫폼  44453            소프트웨어 개발 및 공급업
# ...    ...       ...    ...                       ...
# 2756  유가증권      유한양행  00010                   의약품 제조업
# 2757  유가증권    CJ대한통운  00012                 도로 화물 운송업
# 2758  유가증권        경방  00005                    종합 소매업
# 2759  유가증권     유수홀딩스  00070       회사 본부 및 경영 컨설팅 서비스업
# 2760  유가증권  한진중공업홀딩스  00348         연료용 가스 제조 및 배관공급업
#
#                                                    주요제품         상장일  결산월  \
# 0     내연기관 부품(터보차저, DCT변속기), IT 부품(스마트워치/스마트링), 자율주행...  2025-04-04  12월
# 1                               레인부츠, 스니커즈, 겨울화, 패션잡화 등  2025-04-03  12월
# 2                                       화공 플랜트, 에너지 플랜트  2025-03-28  12월
# 3                                 디지털뱅킹 솔루션(B2B 금융 서비스)  2025-03-24  12월
# 4                NUBISON AIoT(산업용 데이터 수집과 산업용 AI서비스 운영)  2025-03-21  12월
# ...                                                 ...         ...  ...
# 2756  의약품(삐콤씨, 안티푸라민, 렉라자, 로수바미브, 코푸시럽 등), 생활용품(유한락스...  1962-11-01  12월
# 2757  Contract Logistics, 포워딩, 항만하역, 해운, 택배국제특송, SCM...  1956-07-02  12월
# 2758          섬유류(면사,면혼방사,면직물,면혼방직물,화섬사,화섬직물) 제조,도매,수출입  1956-03-03  12월
# 2759                                               지주사업  1956-03-03  12월
# 2760                                               지주회사  1956-03-03  12월
#
#                   대표자명                          홈페이지     지역
# 0                  송준호       http://www.pimkorea.com  대구광역시
# 1                  김지훈  http://aubrandz.irpage.co.kr  서울특별시
# 2                  김진태      http://www.wooyang.co.kr    경기도
# 3                  조철한        http://www.dozn.co.kr/  서울특별시
# 4             임대근, 강태신       http://simplatform.com/  서울특별시
# ...                ...                           ...    ...
# 2756          대표이사 조욱제        http://www.yuhan.co.kr  서울특별시
# 2757  신영수, 민영학 (각자 대표)    http://www.cjlogistics.com  서울특별시
# 2758            김준, 김담    http://www.kyungbang.co.kr  서울특별시
# 2759               송영규  http://www.eusu-holdings.com  서울특별시
# 2760               조원국  http://www.hhic-holdings.com    경기도
#
# [2761 rows x 10 columns]

# %% [markdown]
# # 데이터를 수집한 날짜를 포함해서 파일명을 만들고 저장하기

# %%
from datetime import datetime
today=datetime.now()
print(f"{today.year}{today.month:02d}{today.day:02d}")
today=f"{today.year}{today.month:02d}{today.day:02d}"
# Out:
# 20250404

# %%
df.to_csv(f"./scraping_results/상장기업정보({today}).csv",encoding="utf-8",index=False)

# %% [markdown]
# # 수집한 자료를 데이터베이스에 저장하기

# %%
from sqlalchemy import create_engine, text
import pymysql
pymysql.install_as_MySQLdb()

# %% [markdown]
# * sqlalchemy의 create_engine을 이용해서 mysql 서버에 접속
#     * engine 생성
#     * engine : 파이썬과 DB 연결 시 접속하게 되는 경로, id, password 등 입력해주는 것
#
# engine = create_engine("mysql+pymysql://user id:password@ip주소:port번호/데이터베이스 이름")
#
# * localhost=127.0.0.1

# %%
engine = create_engine("mysql+pymysql://root:1234@localhost:3306/stock_info")

# %%
# engine.connect 하면 create_engine에 있는 정보로 DB접속
conn = engine.connect()

# %%
#데이터프레임을 DB에 저장하기
# 데이터프레임명.to_sql("테이블명", con=오픈한 db)
df.to_sql(f"stock_company_info_{today}",con=conn, if_exists='replace', index=False)
conn.close()

# %% [markdown]
# # 판다스의 read_html을 이용해서 table 자료 한번에 가져오기

# %%
from io import StringIO

# %%
soup.select_one('table')
# Out:
# <table class="list type-00 tmt30" summary="회사명, 업종, 주요제품, 상장일, 결산월, 대표자명, 홈페이지, 지역">
# <caption>목록</caption>
# <colgroup>
# <col width="*"/>
# <col width="15%"/>
# <col width="20%"/>
# <col width="11%"/>
# <col width="8%"/>
# <col width="10%"/>
# <col width="8%"/>
# <col width="12%"/>
# </colgroup>
# <thead>
# <tr class="first" id="title-contents">
# </tr>
# </thead>
# <tbody>
# <tr class="first">
# <td class="first" title="(주)디에이치오토넥스"><img alt="유가증권" class="vmiddle legend" src="/images/common/icn_t_yu.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('
td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.eusu-holdings.com" target="_blank" title="http://www.eusu-holdings.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="(주)한진중공업홀딩스"><img alt="유가증권" class="vmiddle legend" src="/images/common/icn_t_yu.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('00348'); return false;" title="한진중공업홀딩스"> 한진중공업홀딩스</a> </td>
# <td class="textOverflow" title="연료용 가스 제조 및 배관공급업">연료용 가스 제조 및 배관공급업</td>
# <td class="textOverflow" title="지주회사">지주회사</td>
# <td class="txc">1956-03-03</td>
# <td class="txc">12월</td>
# <td class="txc" title="조원국">조원국</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.hhic-holdings.com" target="_blank" title="http://www.hhic-holdings.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">경기도</td>
# </tr>
# </tbody>
# </table>

# %%
pd.read_html(r.text)[0]
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6348\1880019241.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_html(r.text)[0]
#    Unnamed: 0           Unnamed: 1  \
# 0      DH오토넥스       통신 및 방송 장비 제조업
# 1         BYC             봉제의복 제조업
# 2      KG모빌리티    자동차용 엔진 및 자동차 제조업
# 3       SPC삼립            기타 식품 제조업
# 4        흥국화재                  보험업
# ..        ...                  ...
# 56       유한양행              의약품 제조업
# 57     CJ대한통운            도로 화물 운송업
# 58         경방               종합 소매업
# 59      유수홀딩스  회사 본부 및 경영 컨설팅 서비스업
# 60   한진중공업홀딩스    연료용 가스 제조 및 배관공급업
#
#                                            Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# 0                                           유,무선 통신장비  1975-06-09        12월
# 1                    메리야스,란제리 제조,도매/건축공사/부동산 임대,분양,공급  1975-06-02        12월
# 2                              자동차,자동차부품,차륜,정비 제조/도소매  1975-05-29        12월
# 3         빵,아이스크림,과자,케익,유산균음료,인스턴트식품,병조림,면류,식용유 제조,판매  1975-05-02        12월
# 4                                                손해보험  1974-12-05        12월
# ..                                                ...         ...        ...
# 56  의약품(삐콤씨, 안티푸라민, 렉라자, 로수바미브, 코푸시럽 등), 생활용품(유한락스...  1962-11-01        12월
# 57  Contract Logistics, 포워딩, 항만하역, 해운, 택배국제특송, SCM...  1956-07-02        12월
# 58          섬유류(면사,면혼방사,면직물,면혼방직물,화섬사,화섬직물) 제조,도매,수출입  1956-03-03        12월
# 59                                               지주사업  1956-03-03        12월
# 60                                               지주회사  1956-03-03        12월
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0         최준용    홈페이지 보기    전북특별자치도
# 1       김 대..    홈페이지 보기      서울특별시
# 2       곽재선..    홈페이지 보기        경기도
# 3       황종현..    홈페이지 보기        경기도
# 4         송윤상    홈페이지 보기      서울특별시
# ..        ...        ...        ...
# 56      대표이..    홈페이지 보기      서울특별시
# 57      신영수..    홈페이지 보기      서울특별시
# 58      김준,..    홈페이지 보기      서울특별시
# 59        송영규    홈페이지 보기      서울특별시
# 60        조원국    홈페이지 보기        경기도
#
# [61 rows x 8 columns]
