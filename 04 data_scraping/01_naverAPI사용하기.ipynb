# %% [markdown]
# # 웹에서 자료를 수집하는 방법
# 1. API를 이용해서 자료 수집
# * naver, google, kakao, 공공데이터 에서 제공하는 API를 이용해서 자료수집
# 2. Web 페이지를 직접 스크래이핑 해서 자료 수집
# * 정적페이지 수집: javascrip 없이 수집 가능한 사이트
# * 동적페이지 수집: javascrip에 의해서 콘텐츠가 제어. 웹브라우저 제어를 통해 수집

# %% [markdown]
# ### HTTP 상태 코드
# * 1xx 정보 제공
# * 2xx 성공
# * 3xx 리다이렉션
# * 4xx 클라이언트 에러
# * 5xx 서버 에러

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "c58ExzdJxITcuHEtCf4k"
client_secret = "zOxRmpOStb"
encText = urllib.parse.quote("핀테크") #utf-8 인코딩 작업
url = "https://openapi.naver.com/v1/search/blog?query=" + encText + "&start=101&display=100" # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request) # 실제 요청 전송
rescode = response.getcode()
# HTTP 응답 상태 코드 
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Tue, 01 Apr 2025 00:01:15 +0900",
# 	"total":456134,
# 	"start":101,
# 	"display":100,
# 	"items":[
# 		{
# 			"title":"[기자단 뉴스] 우리가 쓰는 앱 속에 숨어 있는 <b>핀테크<\/b>, 얼마나... ",
# 			"link":"https:\/\/blog.naver.com\/koreafintech\/223703070792",
# 			"description":"우리가 쓰는 앱 속에 숨어 있는 <b>핀테크<\/b>, 얼마나 알고 계신가요?배달의 민족 제12기 대학생 기자단 이서현... 배달의 민족 배달의민족은 단순한 음식 배달 서비스를 넘어, <b>핀테크<\/b> 기술로 사용자와 배달 파트너에게... ",
# 			"bloggername":"한국핀테크지원센터",
# 			"bloggerlink":"blog.naver.com\/koreafintech",
# 			"postdate":"20241223"
# 		},
# 		{
# 			"title":"[정책현장] <b>핀테크<\/b> 생태계의 지속적인 교류 기회를 마련합니다",
# 			"link":"https:\/\/blog.naver.com\/blogfsc\/223667100074",
# 			"description":"금융위원회는 제2회 '<b>핀테크<\/b> 오픈 네트워킹 데이'를 개최하여 <b>핀테크<\/b> 생태계를 위한 교류의 장을 펼쳤습니다. 김병환 위원장은 <b>핀테크<\/b> 산업의 앞선 간담회에서 지속적인 성장과 금융회사의 디지털전환을... ",
# 			"bloggername":"금융위원회 공식 블로그",
# 			"bloggerlink":"blog.naver.com\/blogfsc",
# 			"postdate":"20241120"
# 		},
# 		{
# 			"title":"<b>핀테크<\/b> 기술이 이끄는 간편한 세상",
# ...

# %%
"https://openapi.naver.com/v1/search/blog?query="+encText
# Out:
# 'https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC'

# %% [markdown]
# # url : http://로 시작한느 웹페이지 접속주소
# * url : 실제 서비스 서버에 접속하는 주소
# * parameter: 서비스에 요청하는 값
# https://search.shopping.naver.com/book/search?bookTabType=BEST_SELLER&catId=50005542&pageIndex=1&pageSize=40&query=%EB%84%A4%EC%9D%B4%EB%B2%84%20%EC%B1%85&sort=REL
# * url: https://search.shopping.naver.com/book/search?
# * parameter: bookTabType=BEST_SELLER&catId=50005542&pageIndex=1&pageSize=40&query=%EB%84%A4%EC%9D%B4%EB%B2%84%20%EC%B1%85&sort=REL
# (한계값이 존재하는 파라미터도 있음)

# %% [markdown]
# ## HTTP 프로토콜
# ### GET 방식
# url & 파라미터="기본값" & 파라미터 = "기본값" ...
# ex. https://openapi.naver.com/v1/search/blog?query="파이썬"&display=10&start=1&sort=sim

# %%
import json

# %%
data = response_body.decode('utf-8')
data
# Out:
# '{\n\t"lastBuildDate":"Tue, 01 Apr 2025 00:01:15 +0900",\n\t"total":456134,\n\t"start":101,\n\t"display":100,\n\t"items":[\n\t\t{\n\t\t\t"title":"[기자단 뉴스] 우리가 쓰는 앱 속에 숨어 있는 <b>핀테크<\\/b>, 얼마나... ",\n\t\t\t"link":"https:\\/\\/blog.naver.com\\/koreafintech\\/223703070792",\n\t\t\t"description":"우리가 쓰는 앱 속에 숨어 있는 <b>핀테크<\\/b>, 얼마나 알고 계신가요?배달의 민족 제12기 대학생 기자단 이서현... 배달의 민족 배달의민족은 단순한 음식 배달 서비스를 넘어, <b>핀테크<\\/b> 기술로 사용자와 배달 파트너에게... ",\n\t\t\t"bloggername":"한국핀테크지원센터",\n\t\t\t"bloggerlink":"blog.naver.com\\/koreafintech",\n\t\t\t"postdate":"20241223"\n\t\t},\n\t\t{\n\t\t\t"title":"[정책현장] <b>핀테크<\\/b> 생태계의 지속적인 교류 기회를 마련합니다",\n\t\t\t"link":"https:\\/\\/blog.naver.com\\/blogfsc\\/223667100074",\n\t\t\t"description":"금융위원회는 제2회 \'<b>핀테크<\\/b> 오픈 네트워킹 데이\'를 개최하여 <b>핀테크<\\/b> 생태계를 위한 교류의 장을 펼쳤습니다. 김병환 위원장은 <b>핀테크<\\/b> 산업의 앞선 간담회에서 지속적인 성장과 금융회사의 디지털전환을... ",\n\t\t\t"bloggername":"금융위원회 공식 블로그",\n\t\t\t"bloggerlink":"blog.naver.com\\/blogfsc",\n\t\t\t"postdate":"20241120"\n\t\t},\n\t\t{\n\t\t\t
# ...

# %%
data = json.loads(data)
data
# Out:
# {'lastBuildDate': 'Tue, 01 Apr 2025 00:01:15 +0900',
#  'total': 456134,
#  'start': 101,
#  'display': 100,
#  'items': [{'title': '[기자단 뉴스] 우리가 쓰는 앱 속에 숨어 있는 <b>핀테크</b>, 얼마나... ',
#    'link': 'https://blog.naver.com/koreafintech/223703070792',
#    'description': '우리가 쓰는 앱 속에 숨어 있는 <b>핀테크</b>, 얼마나 알고 계신가요?배달의 민족 제12기 대학생 기자단 이서현... 배달의 민족 배달의민족은 단순한 음식 배달 서비스를 넘어, <b>핀테크</b> 기술로 사용자와 배달 파트너에게... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20241223'},
#   {'title': '[정책현장] <b>핀테크</b> 생태계의 지속적인 교류 기회를 마련합니다',
#    'link': 'https://blog.naver.com/blogfsc/223667100074',
#    'description': "금융위원회는 제2회 '<b>핀테크</b> 오픈 네트워킹 데이'를 개최하여 <b>핀테크</b> 생태계를 위한 교류의 장을 펼쳤습니다. 김병환 위원장은 <b>핀테크</b> 산업의 앞선 간담회에서 지속적인 성장과 금융회사의 디지털전환을... ",
#    'bloggername': '금융위원회 공식 블로그',
#    'bloggerlink': 'blog.naver.com/blogfsc',
#    'postdate': '20241120'},
#   {'title': '<b>핀테크</b> 기술이 이끄는 간편한 세상',
# ...

# %%
len(data['items'])
# Out:
# 100

# %%
data.keys()
# Out:
# dict_keys(['lastBuildDate', 'total', 'start', 'display', 'items'])

# %%
def text_clean(x):
    result=x.replace("<b>","").replace("</b>","")
    return result

# %%
result={}
for item in data['items']:
    for key, value in item.items():
        value=text_clean(value)
        result.setdefault(key,[]).append(value)
result
# Out:
# {'title': ['[기자단 뉴스] 우리가 쓰는 앱 속에 숨어 있는 핀테크, 얼마나... ',
#   '[정책현장] 핀테크 생태계의 지속적인 교류 기회를 마련합니다',
#   '핀테크 기술이 이끄는 간편한 세상',
#   'EBS 입트영 해외여행을 편리하게 해 주는 핀테크 기술',
#   "녹색 금융과 기술의 만남 '그린 핀테크', 제대로 정착하려면?",
#   '센트비, 2024 싱가포르 핀테크 페스티벌에서 혁신을 선보이다!',
#   'BNK금융그룹, 핀테크 랩 ‘Storage B’ 2기 참여기업 모집',
#   '핀테크 거인들의 숨은 이야기: 금융 혁명의 현재와 미래',
#   "[News] 이롬넷 '페이버스' 코리아 핀테크 위크 2024 참가 현장",
#   '잡아야 할 AI 기술주 2선 XYZ DDOG 주가(feat.핀테크, 클라우드)',
#   "[ 페이업뉴스] 페이업이 '제 9회 한경 핀테크대상' 테크 분야... ",
#   '[슬기로운 핀테크 생활] # 8편... 포인트도 적립하는 핀테크!',
#   '핀테크 뜻 기업 종류 산업 사례 장단점 알아보자',
#   '개인 신용대출 갈아타기 중개수수료 저렴한 핀테크 기업과 뜻은?',
#   '[기자단 뉴스] 핀테크큐브 입주기업을 소개합니다!',
#   '2024 APEC 중소기업 디지털 금융 및 핀테크 혁신 포럼 개최!',
#   '지급결제 시스템 혁신과 미래 변화 핀테크의 역할과 과제',
#   '20대 29%는 ‘인터넷은행 주거래’… 핀테크 침투 주목',
#   '한국에서 미국으로 달러 송금시, 주요 은행 및 핀테크 수수료 비교',
#   '특허등록절차, 어플 시스템 핀테크 등 확실한 보호 TIP',
#   '서울핀테크위크2024 - 스마트라이프를 실천하는 금융중심지... ',
#   '[기자단 뉴스] 이런 핀테크는 어떤가요?',
#   '[핀테크] 프랑스 핀테크 리디아, 새로운 디지털 뱅킹 앱... ',
#   '[코리아 핀테크위크 2024] DDP에서 열린 핀테크 박람회 탐방기!',
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(result)
df
# Out:
#                                       title  \
# 0   [기자단 뉴스] 우리가 쓰는 앱 속에 숨어 있는 핀테크, 얼마나...
# 1         [정책현장] 핀테크 생태계의 지속적인 교류 기회를 마련합니다
# 2                        핀테크 기술이 이끄는 간편한 세상
# 3            EBS 입트영 해외여행을 편리하게 해 주는 핀테크 기술
# 4        녹색 금융과 기술의 만남 '그린 핀테크', 제대로 정착하려면?
# ..                                      ...
# 95                       핀테크의 글로벌 협력 기회와 도전
# 96                       핀테크의 발전과 소비자 보호 방안
# 97   금융혁신을 주도할 핀테크 우수기업 K-Fintech 30 선정(2차)
# 98                          핀테크와 금융사기 방지 전략
# 99        한국핀테크지원센터 제13기 대학생 기자단 '핀플루언서' 모집
#
#                                                  link  \
# 0    https://blog.naver.com/koreafintech/223703070792
# 1         https://blog.naver.com/blogfsc/223667100074
# 2         https://blog.naver.com/jjsbmh2/223795518211
# 3         https://blog.naver.com/jjang03/223680514029
# 4   https://blog.naver.com/wisdot_official/2238037...
# ..                                                ...
# ...
