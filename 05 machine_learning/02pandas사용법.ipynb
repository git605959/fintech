# %% [markdown]
# # pandas
# * https://pandas.pydata.org/
# * spark 자료형
# * pip install pandas
# * conda install pandas

# %% [markdown]
# * numpy를 내부적으로 활용함
# * 데이터분석에 특화된 데이터 구조 제공 (테이블, dataframe)
# * 다양한 데이터분석 함수 제공
# * 데이터베이스에 쉽게 연결 가능
# * json 데이터 html의 table 요소를 dataframe으로 손쉽게 변형 가능

# %% [markdown]
# # Pandas에서 다루는 데이터 타입 2가지
# ## 1) DataFrame: 2차원 표형식 데이터
# * python의 dict와 비슷하나 key에 list 형태의 value가 매칭된 형태
# * {key:[value1, value2, value3], key2: [value1, value2, value3]}
# ## 2) Series: 1차원 벡터 형식 데이터
# * python의 list, tuple, ndarray의 1차원 상태와 비슷
# * 열벡터에 이름이 붙어있는 상태

# %%
import pandas as pd

# %% [markdown]
# # 데이터프레임 만들기
# * pd.DataFrame({key1:[value1, value2], key2: [value1, value2]})

# %%
df = pd.DataFrame(
    {'이름' : ['홍길동','둘리','또치','도우너'],
    '주소': ['서울','의정부','고양','성남'],
    '취미' : ['음악감상','놀기','달리기','바이올린']}
)

# %%
print(type(df['이름'][:2]))
# series = list와 똑같은
# Out:
# <class 'pandas.core.series.Series'>

# %%
df.shape
# Out:
# (4, 3)

# %%
df.ndim
# Out:
# 2

# %%
df['이름'].dtype
# Out:
# dtype('O')

# %% [markdown]
# # Series 만들기
# * pd.Series([리스트 자료/튜플], name = "컬럼명")
# * 이름을 가지고 있는 list /벡터
# * dataframe에서 컬럼 1개를 잘라온 형태

# %%
ages = pd.Series([22,53,35], name="나이")
print(ages)
print(ages.dtype)
# Out:
# 0    22
# 1    53
# 2    35
# Name: 나이, dtype: int64
# int64

# %%
ages[0] # 내부적으로 numpy로 바뀜
# Out:
# np.int64(22)

# %%
ages[::-1]
# Out:
# 2    35
# 1    53
# 0    22
# Name: 나이, dtype: int64

# %%
ages.max()
# Out:
# np.int64(53)

# %%
ages.sum()
# Out:
# np.int64(110)

# %%
ages.cumsum() #누적합
# Out:
# 0     22
# 1     75
# 2    110
# Name: 나이, dtype: int64

# %%
ages.mean()
# Out:
# np.float64(36.666666666666664)

# %%
ages.median()
# Out:
# np.float64(35.0)

# %% [markdown]
# # 판다스에서 자료 불러오기, 저장하기
# * csv, tsv, excel, json, html, sql (+spark 타입)
# * pd.read_확장자명(파일경로, 옵션)

# %% [markdown]
# ### excel 파일 불러오기

# %%
df_excel=pd.read_excel("./data/Online Retail.xlsx")
df_excel
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
#df_excel2=pd.read_excel("./data/아파트(매매)_실거래가_20240806113828.xlsx")
# 데이터 이전에 정보들이 있는 경우
# 시트 이름(번호) or header 지정해서 원하는 위치의 데이터 불러오기 가능
df_excel2=pd.read_excel("./data/아파트(매매)_실거래가_20240806113828.xlsx",header=12, index_col=None)
df_excel2
# Out:
#           NO                  시군구      번지    본번  부번                단지명  \
# 0          1     서울특별시 영등포구 당산동5가      42    42   0          당산삼성래미안4차
# 1          2  강원특별자치도 원주시 지정면 가곡리    1512  1512   0  원주롯데캐슬골드파크1차(5단지)
# 2          3    대구광역시 달성군 화원읍 구라리    1650  1650   0             대곡역래미안
# 3          4         광주광역시 남구 진월동   312-7   312   7                 광명
# 4          5         광주광역시 남구 진월동  331-93   331  93                 중흥
# ...      ...                  ...     ...   ...  ..                ...
# 37575  37576        서울특별시 송파구 장지동     849   849   0          송파파인타운3단지
# 37576  37577        부산광역시 사상구 모라동     552   552   0               백양그린
# 37577  37578        광주광역시 광산구 비아동   152-5   152   5                 호반
# 37578  37579        부산광역시 사상구 모라동     552   552   0               백양그린
# 37579  37580         대구광역시 북구 읍내동  1366-2  1366   2               칠곡보성
#
#         전용면적(㎡)    계약년월  계약일 거래금액(만원)  ...   층  매수자 매도자  건축년도            도로명  \
# ...

# %%
df_csv=pd.read_csv("./data/아파트(매매)_실거래가_20240806113828.csv", header=12)
df_csv
# Out:
#           NO                  시군구      번지    본번  부번                단지명  \
# 0          1     서울특별시 영등포구 당산동5가      42    42   0          당산삼성래미안4차
# 1          2  강원특별자치도 원주시 지정면 가곡리    1512  1512   0  원주롯데캐슬골드파크1차(5단지)
# 2          3    대구광역시 달성군 화원읍 구라리    1650  1650   0             대곡역래미안
# 3          4         광주광역시 남구 진월동   312-7   312   7                 광명
# 4          5         광주광역시 남구 진월동  331-93   331  93                 중흥
# ...      ...                  ...     ...   ...  ..                ...
# 37575  37576        서울특별시 송파구 장지동     849   849   0          송파파인타운3단지
# 37576  37577        부산광역시 사상구 모라동     552   552   0               백양그린
# 37577  37578        광주광역시 광산구 비아동   152-5   152   5                 호반
# 37578  37579        부산광역시 사상구 모라동     552   552   0               백양그린
# 37579  37580         대구광역시 북구 읍내동  1366-2  1366   2               칠곡보성
#
#         전용면적(㎡)    계약년월  계약일 거래금액(만원)  ...   층  매수자 매도자  건축년도            도로명  \
# ...

# %%
df_json=pd.read_json("./data/서울특별시_관광지입장정보_2011_2016.json")
df_json
# Out:
#     ForNum  NatNum  addrCd gungu      resNm  rnum   sido  yyyymm
# 0    44722   75991    1111   종로구        창덕궁     1  서울특별시  201112
# 1        0   11017    1111   종로구        운현궁     2  서울특별시  201112
# 2   132399  237330    1111   종로구        경복궁     3  서울특별시  201112
# 3     3133   21267    1111   종로구        창경궁     4  서울특별시  201112
# 4    18226   24223    1111   종로구         종묘     5  서울특별시  201112
# ..     ...     ...     ...   ...        ...   ...    ...     ...
# 62    5588   44232    1141  서대문구  서대문형무소역사관     8  서울특별시  201512
# 63       0   22587    1141  서대문구  서대문자연사박물관     9  서울특별시  201512
# 64   29520    8822    1144   마포구    트릭아이미술관    10  서울특별시  201512
# 65       3    1647    1165   서초구      헌릉ㆍ인릉    11  서울특별시  201512
# 66     492   14454    1168   강남구      선릉·정릉    12  서울특별시  201512
#
# [67 rows x 8 columns]

# %%
df_html = pd.read_html("./data/corpList.htm")
df_html[0]
# Out:
#     Unnamed: 0                             Unnamed: 1  \
# 0     한국제15호스팩                             금융 지원 서비스업
# 1       에스오에스랩  측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
# 2   미래에셋비전스팩6호                             금융 지원 서비스업
# 3   에이치엠씨제7호스팩                             금융 지원 서비스업
# 4        파라다이스                     유원지 및 기타 오락관련 서비스업
# 5       한중엔시에스      전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업
# 6     KB제29호스팩                             금융 지원 서비스업
# 7   미래에셋비전스팩5호                             금융 지원 서비스업
# 8     씨어스테크놀로지                             의료용 기기 제조업
# 9     한국제14호스팩                             금융 지원 서비스업
# 10   디비금융스팩12호                                 기타 금융업
# 11        라메디텍                             의료용 기기 제조업
# 12       그리드위즈                 그외 기타 전문, 과학 및 기술 서비스업
# 13       다원넥스뷰                        사진장비 및 광학기기 제조업
# 14  미래에셋비전스팩4호                             금융 지원 서비스업
#
#                                            Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# ...

# %% [markdown]
# ## DB에서 자료 읽어오기

# %%
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

# %%
# 외부 db 접속 > kict04
engine=create_engine("mysql+pymysql://root:1234@localhost:3306/exchange_rate")
conn=engine.connect()
data=pd.read_sql('exchange_rate',con=conn)
conn.close()
data
# Out:
#              date            통화  현찰_사실_때_환율  현찰_사실_때_Spread  현찰_파실_때_환율  \
# 0      1995-01-03        미국 USD      800.53             1.5      776.87
# 1      1995-01-03  일본 JPY (100)      798.89             1.5      775.29
# 2      1995-01-03        유로 EUR        0.00             0.0        0.00
# 3      1995-01-03        중국 CNY        0.00             0.0        0.00
# 4      1995-01-03        홍콩 HKD      103.45             3.0      100.41
# ...           ...           ...         ...             ...         ...
# 311134 2025-04-15       리비아 LYD        0.00             0.0        0.00
# 311135 2025-04-15      루마니아 RON        0.00             0.0        0.00
# 311136 2025-04-15       미얀마 MMK        0.00             0.0        0.00
# 311137 2025-04-15     에티오피아 ETB        0.00             0.0        0.00
# 311138 2025-04-15    우즈베키스탄 UZS        0.00             0.0        0.00
#
#         현찰_파실_때_Spread  송금_보낼_때_보낼_때  송금_받을_때_받을_때  외화_수표_파실때  매매_기준율  환가_료율  \
# ...

# %% [markdown]
# # 타이타닉 데이터셋으로 pandas 기능 익히기

# %%
df = pd.read_csv("./data/Taitanic_train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# * 데이터의 일부만 보기
#     * 앞쪽만 head(조회할 행의 갯수), 뒷쪽 tail()
#     * 기본 값 = 5

# %%
df.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# 데이터 프레임 각 컬럼의 데이터타입
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# # .info
# * 컬럼명, null이 아닌 데이터 개수, 데이터타입 동시에 출력

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # .describe()
# * 데이터 프레임의 숫자 데이터 기초통계를 보여주는 함수
# * count, mean, std, min, 25%, 50%, 75%, max

# %%
df.describe(include="all") # include=all을 하면 문자 값, 빈도수까지 모두 보여줌.
# Out:
#         PassengerId    Survived      Pclass                 Name   Sex  \
# count    891.000000  891.000000  891.000000                  891   891
# unique          NaN         NaN         NaN                  891     2
# top             NaN         NaN         NaN  Dooley, Mr. Patrick  male
# freq            NaN         NaN         NaN                    1   577
# mean     446.000000    0.383838    2.308642                  NaN   NaN
# std      257.353842    0.486592    0.836071                  NaN   NaN
# min        1.000000    0.000000    1.000000                  NaN   NaN
# 25%      223.500000    0.000000    2.000000                  NaN   NaN
# 50%      446.000000    0.000000    3.000000                  NaN   NaN
# 75%      668.500000    1.000000    3.000000                  NaN   NaN
# max      891.000000    1.000000    3.000000                  NaN   NaN
#
#                Age       SibSp       Parch  Ticket        Fare Cabin Embarked
# ...

# %%
# 이상치 계측 시 4분위 수 계산 -> 정상 범위 안에 있는지 계산

# %% [markdown]
# ### 판다스 데이터 프레임에서 일부 자료만 추출하기

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
df['Name'] # series로 잘라오기
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
print(type(df['Name']))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# * 2개 이상 컬럼 가져오기

# %%
df[['Name','Age']] # 컬럼 순서, 갯수 조정 가능
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %% [markdown]
# * 데이터 프레임의 컬럼 순서 바꾸기

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df2=df[['Survived', 'Pclass', 'Name', 'Sex', 'Age',  'Embarked', 'SibSp',
       'Parch', 'Ticket', 'Fare', 'Cabin','PassengerId']]
df2
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age Embarked  SibSp  Parch            Ticket     Fare Cabin  \
# ...

# %% [markdown]
# # 데이터프레임에서 일부 컬럼만 가져오기2
# * loc: 인덱스 이름과 컬럼명으로 데이터 일부를 추출해 가져옴
#     * df.loc[시작 row 인덱스: 끝 row 인덱스, ['컬럼명1','컬럼명2']]
# * iloc: 인덱스를 이용해 슬라이싱으로 데이터 일부 추출
#     * df.iloc[시작row인덱스 : 끝row인덱스, 시작_column_index:끝_column_index]

# %% [markdown]
# ### loc[시작 row 인덱스: 끝 row 인덱스, ['컬럼명1','컬럼명2']]

# %%
df.loc[100:130,['Name','Age']]
# Out:
#                                   Name   Age
# 100            Petranec, Miss. Matilda  28.0
# 101   Petroff, Mr. Pastcho ("Pentcho")   NaN
# 102          White, Mr. Richard Frasar  21.0
# 103         Johansson, Mr. Gustaf Joel  33.0
# 104     Gustafsson, Mr. Anders Vilhelm  37.0
# 105              Mionoff, Mr. Stoytcho  28.0
# 106   Salkjelsvik, Miss. Anna Kristine  21.0
# 107             Moss, Mr. Albert Johan   NaN
# 108                    Rekic, Mr. Tido  38.0
# 109                Moran, Miss. Bertha   NaN
# 110     Porter, Mr. Walter Chamberlain  47.0
# 111               Zabour, Miss. Hileni  14.5
# 112             Barton, Mr. David John  22.0
# 113            Jussila, Miss. Katriina  20.0
# 114              Attalah, Miss. Malake  17.0
# 115              Pekoniemi, Mr. Edvard  21.0
# 116               Connors, Mr. Patrick  70.5
# 117    Turpin, Mr. William John Robert  29.0
# 118           Baxter, Mr. Quigg Edmond  24.0
# 119  Andersson, Miss. Ellis Anna Maria   2.0
# ...

# %%
df.loc[101,['Age']] #1차원 데이터라 series로 조회됨 => 하나씩 조회해서 값 변경 가능
# Out:
# Age    NaN
# Name: 101, dtype: object

# %%
df.loc[101,['Age']]=29
df.loc[101,['Age']]
# Out:
# Age    29.0
# Name: 101, dtype: object

# %% [markdown]
# ### df.iloc[시작row인덱스 : 끝row인덱스, 시작_column_index:끝_column_index]

# %%
df.iloc[:10,-5:]
# Out:
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
df.iloc[4,4]='female'

# %%
df.iloc[:5,:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry  female

# %%
df.iloc[:10:2,::2]
# Out:
#    PassengerId  Pclass     Sex  SibSp            Ticket Cabin
# 0            1       3    male      1         A/5 21171   NaN
# 2            3       3  female      0  STON/O2. 3101282   NaN
# 4            5       3  female      0            373450   NaN
# 6            7       1    male      0             17463   E46
# 8            9       3  female      0            347742   NaN

# %% [markdown]
# * 특정 컬럼에서 유일값(중복되지 않은 고유한 값) 출력하기
# * .unique()

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %% [markdown]
# * .nunique()
# * 유일값의 개수를 출력
# * nan값 무시

# %%
df['Embarked'].nunique()
# Out:
# 3

# %% [markdown]
# * 카테고리 컬럼에서 유일값 별 개수를 세는 함수
# * value_counts()

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts(ascending=True)
# 정렬하기 옵션 가능.
# Out:
# Pclass
# 2    184
# 1    216
# 3    491
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts(sort=True)
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %% [markdown]
# * 데이터를 정렬하는 함수
# * sort_values(by="컬럼명")
# * sql - order by와 같은 기능

# %%
# 기준 컬럼 2개로 정렬
df.sort_values(by=['Age','Pclass'], ascending=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 630          631         1       1
# 851          852         0       3
# 96            97         0       1
# 493          494         0       1
# 116          117         0       3
# ..           ...       ...     ...
# 766          767         0       1
# 793          794         0       1
# 815          816         0       1
# 839          840         1       1
# 849          850         1       1
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 630          Barkworth, Mr. Algernon Henry Wilson    male  80.0      0      0
# 851                           Svensson, Mr. Johan    male  74.0      0      0
# 96                      Goldschmidt, Mr. George B    male  71.0      0      0
# 493                       Artagaveytia, Mr. Ramon    male  71.0      0      0
# 116                          Connors, Mr. Patrick    male  70.5      0      0
# ...

# %%
df = df.set_index("PassengerId")
# 재할당 안하면 원본 바뀌지 않음
# inplace 옵션을 사용해 원본 변경 가능.

# %% [markdown]
# * 인덱스를 숫자로 초기화
# * reset_index(drop=True)

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df.reset_index(drop=True)
df=df.reset_index()
df
# Out:
#      PassengerId  Surv  Pclass  \
# 0              1     0       3
# 1              2     1       1
# 2              3     1       3
# 3              4     1       1
# 4              5     0       3
# ..           ...   ...     ...
# 886          887     0       2
# 887          888     1       1
# 888          889     0       3
# 889          890     1       1
# 890          891     0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# * 컬럼 이름 출력하기, 바꾸기
# * df.colums

# %%
df.columns
# Out:
# Index(['index', 'PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# * 컬럼 이름 변경하기
# * rename(columns={'원래 이름':'새이름','원래 이름2':'새이름2'}):

# %%
df.rename(columns={'PassengerId':'Pid','Survived':'Surv'}, inplace=True)
df
# Out:
#      Pid  Surv  Pclass                                               Name  \
# 0      1     0       3                            Braund, Mr. Owen Harris
# 1      2     1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      3     1       3                             Heikkinen, Miss. Laina
# 3      4     1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4      5     0       3                           Allen, Mr. William Henry
# ..   ...   ...     ...                                                ...
# 886  887     0       2                              Montvila, Rev. Juozas
# 887  888     1       1                       Graham, Miss. Margaret Edith
# 888  889     0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889  890     1       1                              Behr, Mr. Karl Howell
# 890  891     0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# * df.columns 로 출력되는 리스트길이와 같은 새로운 이름의 리스트로 덮어쓰기

# %%
df. columns
# Out:
# Index(['Surv', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
newName=['승객번호', '생존여부', '선실등급', '이름', '성별', '나이', '형제자매수',
       '부모자식수', '티켓번호', '티켓가격', '선실번호', '목적지']

# %%
df.columns=newName
df
# Out:
#      승객번호  생존여부  선실등급                                                 이름  \
# 0       1     0     3                            Braund, Mr. Owen Harris
# 1       2     1     1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       3     1     3                             Heikkinen, Miss. Laina
# 3       4     1     1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       5     0     3                           Allen, Mr. William Henry
# ..    ...   ...   ...                                                ...
# 886   887     0     2                              Montvila, Rev. Juozas
# 887   888     1     1                       Graham, Miss. Margaret Edith
# 888   889     0     3           Johnston, Miss. Catherine Helen "Carrie"
# 889   890     1     1                              Behr, Mr. Karl Howell
# 890   891     0     3                                Dooley, Mr. Patrick
#
#          성별    나이  형제자매수  부모자식수              티켓번호     티켓가격  선실번호 목적지
# ...

# %% [markdown]
# * 컬럼 추가하기/삭제하기
# * 변수명['컬럼명']=value

# %%
df['가족수']=""
#df
# 행렬계산 가능 => 컬럼 값 연산을 통해서 새로운 컬럼 값 생성 가능
df['가족수']=df['형제자매수']+df['부모자식수']
df
# Out:
#      승객번호  생존여부  선실등급                                                 이름  \
# 0       1     0     3                            Braund, Mr. Owen Harris
# 1       2     1     1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       3     1     3                             Heikkinen, Miss. Laina
# 3       4     1     1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       5     0     3                           Allen, Mr. William Henry
# ..    ...   ...   ...                                                ...
# 886   887     0     2                              Montvila, Rev. Juozas
# 887   888     1     1                       Graham, Miss. Margaret Edith
# 888   889     0     3           Johnston, Miss. Catherine Helen "Carrie"
# 889   890     1     1                              Behr, Mr. Karl Howell
# 890   891     0     3                                Dooley, Mr. Patrick
#
#          성별    나이  형제자매수  부모자식수              티켓번호     티켓가격  선실번호 목적지  가족수
# ...

# %% [markdown]
# * 컬럼 삭제하기
# * del df['컬럼명']
# * df.drop('컬럼명',axis=1, inplace=True)
#     * #drop은 행 삭제가 기본이기 때문에 axis 변경 필요

# %%
del df['형제자매수']
df
# Out:
#      승객번호  생존여부  선실등급                                                 이름  \
# 0       1     0     3                            Braund, Mr. Owen Harris
# 1       2     1     1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       3     1     3                             Heikkinen, Miss. Laina
# 3       4     1     1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       5     0     3                           Allen, Mr. William Henry
# ..    ...   ...   ...                                                ...
# 886   887     0     2                              Montvila, Rev. Juozas
# 887   888     1     1                       Graham, Miss. Margaret Edith
# 888   889     0     3           Johnston, Miss. Catherine Helen "Carrie"
# 889   890     1     1                              Behr, Mr. Karl Howell
# 890   891     0     3                                Dooley, Mr. Patrick
#
#          성별    나이  부모자식수              티켓번호     티켓가격  선실번호 목적지  가족수
# ...

# %%
df.drop('부모자식수',axis=1,inplace=True)

# %%
df
# Out:
#      승객번호  생존여부  선실등급                                                 이름  \
# 0       1     0     3                            Braund, Mr. Owen Harris
# 1       2     1     1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       3     1     3                             Heikkinen, Miss. Laina
# 3       4     1     1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       5     0     3                           Allen, Mr. William Henry
# ..    ...   ...   ...                                                ...
# 886   887     0     2                              Montvila, Rev. Juozas
# 887   888     1     1                       Graham, Miss. Margaret Edith
# 888   889     0     3           Johnston, Miss. Catherine Helen "Carrie"
# 889   890     1     1                              Behr, Mr. Karl Howell
# 890   891     0     3                                Dooley, Mr. Patrick
#
#          성별    나이              티켓번호     티켓가격  선실번호 목적지  가족수
# ...

# %%
df.drop(['이름','승객번호'],axis=1)
# Out:
#      생존여부  선실등급      성별    나이              티켓번호     티켓가격  선실번호 목적지  가족수
# 0       0     3    male  22.0         A/5 21171   7.2500   NaN   S    1
# 1       1     1  female  38.0          PC 17599  71.2833   C85   C    1
# 2       1     3  female  26.0  STON/O2. 3101282   7.9250   NaN   S    0
# 3       1     1  female  35.0            113803  53.1000  C123   S    1
# 4       0     3    male  35.0            373450   8.0500   NaN   S    0
# ..    ...   ...     ...   ...               ...      ...   ...  ..  ...
# 886     0     2    male  27.0            211536  13.0000   NaN   S    0
# 887     1     1  female  19.0            112053  30.0000   B42   S    0
# 888     0     3  female   NaN        W./C. 6607  23.4500   NaN   S    3
# 889     1     1    male  26.0            111369  30.0000  C148   C    0
# 890     0     3    male  32.0            370376   7.7500   NaN   Q    0
#
# [891 rows x 9 columns]

# %% [markdown]
# # 데이터 타입 바꾸기
# * astype(자료형)
# * apply(형변환함수)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   승객번호    891 non-null    int64
#  1   생존여부    891 non-null    int64
#  2   선실등급    891 non-null    int64
#  3   이름      891 non-null    object
#  4   성별      891 non-null    object
#  5   나이      714 non-null    float64
#  6   티켓번호    891 non-null    object
#  7   티켓가격    891 non-null    float64
#  8   선실번호    204 non-null    object
#  9   목적지     889 non-null    object
#  10  가족수     891 non-null    int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.7+ KB

# %%
df['승객번호']=df['승객번호'].astype('int')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   승객번호    891 non-null    int64
#  1   생존여부    891 non-null    int64
#  2   선실등급    891 non-null    int64
#  3   이름      891 non-null    object
#  4   성별      891 non-null    object
#  5   나이      714 non-null    float64
#  6   티켓번호    891 non-null    object
#  7   티켓가격    891 non-null    float64
#  8   선실번호    204 non-null    object
#  9   목적지     889 non-null    object
#  10  가족수     891 non-null    int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.7+ KB

# %%
df['승객번호']=df['승객번호'].apply(str)
#apply(lambda x: )사용하여 index 0번부터 함수 돌릴 수 있음
df['승객번호'].apply(lambda x:'짝수' if int(x)%2==0 else '홀수')
# Out:
# 0      홀수
# 1      짝수
# 2      홀수
# 3      짝수
# 4      홀수
#        ..
# 886    홀수
# 887    짝수
# 888    홀수
# 889    짝수
# 890    홀수
# Name: 승객번호, Length: 891, dtype: object

# %% [markdown]
# # 판다스 데이터프레임에서 조건에 맞는 행만 가져오기 (데이터 필터링)
# * df[df['컬럼명'] 조건식]
# * 조건식 연산자 <.<=,>,>=,==,!=,&,|

# %%
df[df['승객번호']%2==0]
# Out:
#      승객번호  생존여부  선실등급                                                 이름  \
# 1       2     1     1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3       4     1     1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5       6     0     3                                   Moran, Mr. James
# 7       8     0     3                     Palsson, Master. Gosta Leonard
# 9      10     1     2                Nasser, Mrs. Nicholas (Adele Achem)
# ..    ...   ...   ...                                                ...
# 881   882     0     3                                 Markun, Mr. Johann
# 883   884     0     2                      Banfield, Mr. Frederick James
# 885   886     0     3               Rice, Mrs. William (Margaret Norton)
# 887   888     1     1                       Graham, Miss. Margaret Edith
# 889   890     1     1                              Behr, Mr. Karl Howell
#
#          성별    나이              티켓번호     티켓가격  선실번호 목적지  가족수
# ...

# %%
df[df['나이']>35]
# Out:
#      승객번호  생존여부  선실등급                                                 이름  \
# 1       2     1     1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 6       7     0     1                            McCarthy, Mr. Timothy J
# 11     12     1     1                           Bonnell, Miss. Elizabeth
# 13     14     0     3                        Andersson, Mr. Anders Johan
# 15     16     1     2                   Hewlett, Mrs. (Mary D Kingcome)
# ..    ...   ...   ...                                                ...
# 865   866     1     2                           Bystrom, Mrs. (Karolina)
# 871   872     1     1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 873   874     0     3                        Vander Cruyssen, Mr. Victor
# 879   880     1     1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 885   886     0     3               Rice, Mrs. William (Margaret Norton)
#
#          성별    나이      티켓번호     티켓가격  선실번호 목적지  가족수
# ...

# %%
# 조건 2개 => 각각의 조건을 () 묶어줘야 함.
# 여성이면서 나이가 35세 초과
len(df[(df['성별']=='female')&(df['나이']>35)])
# Out:
# 73

# %% [markdown]
# * 선실 등급별 승차권 금액의 최소, 최대, 평균 등 4분위 수를 보고싶음

# %%
# 선실등급이 1등급인 사람들의 승차권 금액 통계량
df[df['선실등급']==1]['티켓가격'].describe()
# Out:
# count    216.000000
# mean      84.154687
# std       78.380373
# min        0.000000
# 25%       30.923950
# 50%       60.287500
# 75%       93.500000
# max      512.329200
# Name: 티켓가격, dtype: float64

# %%
df['티켓가격'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: 티켓가격, dtype: float64

# %%
df[df['티켓가격']>512]
# Out:
#      승객번호  생존여부  선실등급                                  이름      성별    나이  \
# 258   259     1     1                    Ward, Miss. Anna  female  35.0
# 679   680     1     1  Cardeza, Mr. Thomas Drake Martinez    male  36.0
# 737   738     1     1              Lesurer, Mr. Gustave J    male  35.0
#
#          티켓번호      티켓가격         선실번호 목적지  가족수
# 258  PC 17755  512.3292          NaN   C    0
# 679  PC 17755  512.3292  B51 B53 B55   C    1
# 737  PC 17755  512.3292         B101   C    0

# %%
df[df['티켓가격']==0]
# Out:
#      승객번호  생존여부  선실등급                                이름    성별    나이    티켓번호  \
# 179   180     0     3               Leonard, Mr. Lionel  male  36.0    LINE
# 263   264     0     1             Harrison, Mr. William  male  40.0  112059
# 271   272     1     3      Tornquist, Mr. William Henry  male  25.0    LINE
# 277   278     0     2       Parkes, Mr. Francis "Frank"  male   NaN  239853
# 302   303     0     3   Johnson, Mr. William Cahoone Jr  male  19.0    LINE
# 413   414     0     2    Cunningham, Mr. Alfred Fleming  male   NaN  239853
# 466   467     0     2             Campbell, Mr. William  male   NaN  239853
# 481   482     0     2  Frost, Mr. Anthony Wood "Archie"  male   NaN  239854
# 597   598     0     3               Johnson, Mr. Alfred  male  49.0    LINE
# 633   634     0     1     Parr, Mr. William Henry Marsh  male   NaN  112052
# 674   675     0     2        Watson, Mr. Ennis Hastings  male   NaN  239856
# ...

# %% [markdown]
# ### 조건에 맞는 행을 찾은 후 특정 컬럼만 조회하기

# %% [markdown]
# * 선실등급이 1 or 2 이면서 생존한 여성 중 이름 컬럼만 조회하기

# %%
df.loc[((df['선실등급']==1) | (df['선실등급']==2))& (df['성별']=='female') & (df['생존여부']==1), '이름']
# Out:
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 9                    Nasser, Mrs. Nicholas (Adele Achem)
# 11                              Bonnell, Miss. Elizabeth
# 15                      Hewlett, Mrs. (Mary D Kingcome)
#                              ...
# 871     Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 874                Abelson, Mrs. Samuel (Hannah Wizosky)
# 879        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 880         Shelley, Mrs. William (Imanita Parrish Hall)
# 887                         Graham, Miss. Margaret Edith
# Name: 이름, Length: 161, dtype: object

# %%
df[(df.나이<25)&(df.생존여부==1)][['이름','나이']]
# Out:
#                                            이름    나이
# 9         Nasser, Mrs. Nicholas (Adele Achem)  14.0
# 10            Sandstrom, Miss. Marguerite Rut   4.0
# 22                McGowan, Miss. Anna "Annie"  15.0
# 39                Nicola-Yarred, Miss. Jamila  14.0
# 43   Laroche, Miss. Simonne Marie Anne Andree   3.0
# ..                                        ...   ...
# 855                Aks, Mrs. Sam (Leah Rosen)  18.0
# 858     Baclini, Mrs. Solomon (Latifa Qurban)  24.0
# 869           Johnson, Master. Harold Theodor   4.0
# 875          Najib, Miss. Adele Kiamie "Jane"  15.0
# 887              Graham, Miss. Margaret Edith  19.0
#
# [118 rows x 2 columns]

# %%
df[df['선실등급'].isin([1,2])]
# Out:
#      승객번호  생존여부  선실등급                                                 이름  \
# 1       2     1     1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3       4     1     1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 6       7     0     1                            McCarthy, Mr. Timothy J
# 9      10     1     2                Nasser, Mrs. Nicholas (Adele Achem)
# 11     12     1     1                           Bonnell, Miss. Elizabeth
# ..    ...   ...   ...                                                ...
# 880   881     1     2       Shelley, Mrs. William (Imanita Parrish Hall)
# 883   884     0     2                      Banfield, Mr. Frederick James
# 886   887     0     2                              Montvila, Rev. Juozas
# 887   888     1     1                       Graham, Miss. Margaret Edith
# 889   890     1     1                              Behr, Mr. Karl Howell
#
#          성별    나이              티켓번호     티켓가격  선실번호 목적지  가족수
# ...

# %% [markdown]
# # 특정 단어 포함한 행 찾기
# * 이름에 Joseph가 들어간 사람 찾기
# * like %단어% - SQL
# * .str.contains('찾을 단어')

# %%
df[df['이름'].str.contains("Joseph")]
# Out:
#      승객번호  생존여부  선실등급                                                 이름  \
# 20     21     0     2                               Fynney, Mr. Joseph J
# 34     35     0     1                            Meyer, Mr. Edgar Joseph
# 95     96     0     3                        Shorney, Mr. Charles Joseph
# 140   141     0     3                      Boulos, Mrs. Joseph (Sultana)
# 145   146     0     2                       Nicholls, Mr. Joseph Charles
# 194   195     1     1          Brown, Mrs. James Joseph (Margaret Tobin)
# 375   376     1     1              Meyer, Mrs. Edgar Joseph (Leila Saks)
# 454   455     0     3                                Peduzzi, Mr. Joseph
# 532   533     0     3                               Elias, Mr. Joseph Jr
# 559   560     1     3       de Messemaeker, Mrs. Guillaume Joseph (Emma)
# 578   579     0     3                   Caram, Mrs. Joseph (Maria Elias)
# 589   590     0     3                                Murdlin, Mr. Joseph
# ...

# %%
df[df['티켓번호'].str.contains("PC")]
# Out:
#      승객번호  생존여부  선실등급                                                 이름  \
# 1       2     1     1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 30     31     0     1                           Uruchurtu, Don. Manuel E
# 31     32     1     1     Spencer, Mrs. William Augustus (Marie Eugenie)
# 34     35     0     1                            Meyer, Mr. Edgar Joseph
# 52     53     1     1           Harper, Mrs. Henry Sleeper (Myna Haxtun)
# 64     65     0     1                              Stewart, Mr. Albert A
# 96     97     0     1                          Goldschmidt, Mr. George B
# 97     98     1     1                    Greenfield, Mr. William Bertram
# 118   119     0     1                           Baxter, Mr. Quigg Edmond
# 139   140     0     1                                 Giglio, Mr. Victor
# 155   156     0     1                        Williams, Mr. Charles Duane
# 168   169     0     1                                Baumann, Mr. John D
# ...

# %% [markdown]
# * 승객 이름에 ()를 없애는 경우

# %%
result=[]
for name in df['이름']:
    result.append(name.replace("(","").replace(")",""))
result
df['이름']=result

# %%
df
# Out:
#      승객번호  생존여부  선실등급                                                 이름  \
# 0       1     0     3                            Braund, Mr. Owen Harris
# 1       2     1     1  Cumings, Mrs. John Bradley Florence Briggs Thayer
# 2       3     1     3                             Heikkinen, Miss. Laina
# 3       4     1     1         Futrelle, Mrs. Jacques Heath Lily May Peel
# 4       5     0     3                           Allen, Mr. William Henry
# ..    ...   ...   ...                                                ...
# 886   887     0     2                              Montvila, Rev. Juozas
# 887   888     1     1                       Graham, Miss. Margaret Edith
# 888   889     0     3           Johnston, Miss. Catherine Helen "Carrie"
# 889   890     1     1                              Behr, Mr. Karl Howell
# 890   891     0     3                                Dooley, Mr. Patrick
#
#          성별    나이              티켓번호     티켓가격  선실번호 목적지  가족수
# ...

# %%
df = pd.read_csv("./data/Taitanic_train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# apply와 lambda 함수 이용해 작업하기
df['Name'].apply(lambda name:name.replace("(","").replace(")",""))
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley Florence Briggs Thayer
# 2                                 Heikkinen, Miss. Laina
# 3             Futrelle, Mrs. Jacques Heath Lily May Peel
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name']=df['Name'].apply(lambda x:x.split(','))
df['first_name']=df['Name'].apply(lambda x:x[0])
df['second_name']=df['Name'].apply(lambda x:x[1])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           [Braund,  Mr. Owen Harris]    male  22.0      1
# 1    [Cumings,  Mrs. John Bradley (Florence Briggs ...  female  38.0      1
# 2                            [Heikkinen,  Miss. Laina]  female  26.0      0
# 3      [Futrelle,  Mrs. Jacques Heath (Lily May Peel)]  female  35.0      1
# 4                          [Allen,  Mr. William Henry]    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # groupby
# * 특정 기준 컬럼 지정해서 다른 컬럼 통계량(평균, 최소, 최대)
# * df[['보고싶은 컬럼1','보고싶은 컬럼2']].groupby('기준컬럼').집합함수(mean,max,min,median,count)

# %% [markdown]
# * 성별별 생존자 수

# %%
survbysex=df[['Sex','Survived']].groupby('Sex').value_counts(sort=False)
survbysex
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: count, dtype: int64

# %%
print(type(survbysex))
# Out:
# <class 'pandas.core.series.Series'>

# %%
survbysex.index
# Out:
# MultiIndex([('female', 0),
#             ('female', 1),
#             (  'male', 0),
#             (  'male', 1)],
#            names=['Sex', 'Survived'])

# %%
df3 = pd.DataFrame(survbysex)
df3
# Out:
#                  count
# Sex    Survived
# female 0            81
#        1           233
# male   0           468
#        1           109

# %%
#여성 생존자 생존율
233/(81+233) * 100
# Out:
# 74.20382165605095

# %% [markdown]
# * 선실 등급별 생존자 수

# %%
df[['Pclass','Survived']].groupby('Pclass').value_counts(sort=False)
# Out:
# Pclass  Survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: count, dtype: int64

# %% [markdown]
# * 성별별, 선실등급별 생존자 수

# %%
df[['Sex','Pclass','Survived']].groupby(['Pclass','Sex']).value_counts(sort=False)
# Out:
# Pclass  Sex     Survived
# 1       female  0             3
#                 1            91
#         male    0            77
#                 1            45
# 2       female  0             6
#                 1            70
#         male    0            91
#                 1            17
# 3       female  0            72
#                 1            72
#         male    0           300
#                 1            47
# Name: count, dtype: int64

# %% [markdown]
# 은행 고객 등급
# - 급여 통장 입금여부, 액수
# - 적금, 예금

# %% [markdown]
# * 성별에 따른 나이의 평균, 최소, 최대값

# %%
df[['Sex','Age']].groupby('Sex').mean()
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %%
df[['Sex','Age']].groupby('Sex').describe()
# Out:
#           Age
#         count       mean        std   min   25%   50%   75%   max
# Sex
# female  261.0  27.915709  14.110146  0.75  18.0  27.0  37.0  63.0
# male    453.0  30.726645  14.678201  0.42  21.0  29.0  39.0  80.0

# %%
df[['Sex','Age']].groupby('Sex').agg(['min','max','mean'])
# Out:
#          Age
#          min   max       mean
# Sex
# female  0.75  63.0  27.915709
# male    0.42  80.0  30.726645

# %% [markdown]
# ### 피벗테이블 pivot

# %%
df.pivot_table(values="Survived",index='Sex',columns='Pclass')
# Out:
# Pclass         1         2         3
# Sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
#결측값 퍼센티지 구하기
# 결측치가 40% 이상이면 측정 제외하는 것이 좋음
df.isna().sum()/len(df)*100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# first_name      0.000000
# second_name     0.000000
# dtype: float64

# %% [markdown]
# * dropna() 결측값이 있는 행 삭제

# %%
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    [Cumings,  Mrs. John Bradley (Florence Briggs ...  female  38.0      1
# 3      [Futrelle,  Mrs. Jacques Heath (Lily May Peel)]  female  35.0      1
# 6                           [McCarthy,  Mr. Timothy J]    male  54.0      0
# 10                  [Sandstrom,  Miss. Marguerite Rut]  female   4.0      1
# 11                         [Bonnell,  Miss. Elizabeth]  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# * fillna() 결측 값을 다른 값으로 채워주는 함수

# %%
df['Age']=df['Age'].fillna(round(df['Age'].mean()))

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# first_name       0
# second_name      0
# dtype: int64

# %% [markdown]
# # 여러 개의 데이터프레임 합치기
# * concat
# * merge : sql join과 같은 역할. 공통된 기준 컬럼 매칭해서 합침
# * join : sql join과 같은 역할 index가 같은 것 끼리 합침

# %%
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

# %%
engine = create_engine("mysql+pymysql://kict04:kict04@221.155.18.165:3306/titanic")
conn=engine.connect()

# %%
passenger = pd.read_sql("p_info", con=conn)
ticket = pd.read_sql("t_info", con=conn)
survived = pd.read_sql("survived", con=conn)
conn.close()

# %%
survived.head(1)
# Out:
#    PassengerId  Survived
# 0            1         0

# %% [markdown]
# # concat axis=0 행추가, axis =1 열 추가

# %%
df1 = pd.concat([passenger, ticket, survived],axis=1)
df1
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
# ...

# %%
print('passenger',passenger.shape)
print('ticket',ticket.shape)
print('survived',survived.shape)
# Out:
# passenger (891, 6)
# ticket (891, 6)
# survived (891, 2)

# %%
passenger.head(1)
# Out:
#    PassengerId                     Name   Sex   Age  SibSp  Parch
# 0            1  Braund, Mr. Owen Harris  male  22.0      1      0

# %%
# select * from passenger left join ticket on passenger.PassengerId = ticket.PassengerId
joined_df=pd.merge(passenger,ticket, how="inner", on="PassengerId")
joined_df
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
# ...

# %%
joined_df=pd.merge(joined_df, survived, how='inner', on="PassengerId")

# %%
joined_df
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
# ...

# %% [markdown]
# # join : sql의 join과 동일. 기준 컬럼명 기준으로 합침

# %%
passenger=passenger.set_index("PassengerId")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 passenger=passenger.set_index("PassengerId")
#       2 ticket=ticket.set_index("PassengerId")
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\frame.py:6122, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6119                 missing.append(col)
#    6121 if missing:
# -> 6122     raise KeyError(f"None of {missing} are in the columns")
#    6124 if inplace:
#    6125     frame = self
#
# KeyError: "None of ['PassengerId'] are in the columns"

# %%
ticket=ticket.set_index("PassengerId")

# %%
joined_df2=passenger.join(ticket)
joined_df2
# Out:
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
# ...

# %%
survived = survived.set_index("PassengerId")

# %%
joined_df2.join(survived)
# Out:
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
# ...

# %%
joined_df2=joined_df2.reset_index()
joined_df2
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
# ...

# %% [markdown]
# # 중복여부 확인 및 제거하기

# %%
toss=pd.read_csv("./data/viva_republica_toss.csv", index_col=0)
toss.head(1)
# Out:
#         사용자  별점                                                 리뷰  \
# 0  Won Choi   2  토스 많이 이용하는데 나쁘지 않음. 하지만 연말정산 잘 알지 않으면 돌려받기는 사용...
#
#               날짜                                             개발자 응답
# 0  2024년 11월 19일  안녕하세요. Won Choi 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 ...

# %%
toss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52565 entries, 0 to 52564
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   사용자     52531 non-null  object
#  1   별점      52565 non-null  int64
#  2   리뷰      52565 non-null  object
#  3   날짜      52565 non-null  object
#  4   개발자 응답  49611 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 2.4+ MB

# %%
toss.duplicated().sum()
# Out:
# np.int64(52052)

# %% [markdown]
# * 중복 컬럼 삭제하기 drop_duplicates()

# %%
toss= toss.drop_duplicates()

# %%
toss = toss.reset_index(drop=True)
toss
# Out:
#           사용자  별점                                                 리뷰  \
# 0    Won Choi   2  토스 많이 이용하는데 나쁘지 않음. 하지만 연말정산 잘 알지 않으면 돌려받기는 사용...
# 1         최유연   1  증권부분이 너무 빈약해요. 이평선, 분봉, 틱봉 자유롭게 수치를 설정할 수 있었음 ...
# 2     EXPRESS   1  주식 UI에서 홈과 관심 종목을 나눈 것도 불편한데 이번 자주 사용하는 계좌 업데이...
# 3        JS P   1  언제 한 번 대대적으로 앱 퍼포먼스 최적화를 했으면 좋겠습니다. 예전엔 이러지 않았...
# 4    AndPeter   1  앱 최적화 좀 해주세요! 무슨 메모리를 1GB나 잡아먹고 패킷전송이 하루에 80만건...
# ..        ...  ..                                                ...
# 508       나명자   5  사용은 편해요. 계좌개설 확인증이나 송금확인증 의 글씨가 좀 더 컸으면 좋겠습니다....
# 509       김주영   4  소비 관리하는 데 아주 유용하게 쓰고 있습니다. ktx 예매 때문에 코레일을 이용했...
# 510     bk im   1  편리함은 사라지고 불편함만 가중되고있음. 1. 동영상 광고 도입으로 토스 켤 때 마...
# 511       임혜란   2  토스 편해서 사용했는데..최근에 토스에서 하는 꽃돼지이벤트 하다가 짜증났어요. 완전...
# 512      60 2   3  왜 알람이 안 울릴까요? 입출금 알람 설정해뒀는데 어느 순간부터 안 울리네요 그렇다...
#
#                 날짜                                             개발자 응답
# ...
