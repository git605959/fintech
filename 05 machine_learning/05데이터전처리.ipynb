# %% [markdown]
# # 데이터분석 순서 (KDD 분석 방법론)
# * 데이터 세트 선택 : CSV, Excel, DB에서 데이터 읽어옴
# * 데이터 전처리 : 데이터타입, 결측값, 이상치탐지, 데이터분포분석, 상관관계
# * 데이터 변환(특성 추출) : 원본 데이터에서 새로운 데이터 생성, 삭제, 스케일링, 구간화
# * 데이터 마이닝(모델만들기, 분석) : 분석에 적합한 알고리즘 선택, 모델 생성, 성능 튜닝
# * 결과 평가 : 테스트 데이터를 이용해서 데이터 마이닝으로 만든 모델 성능 평가

# %% [markdown]
# # 데이터 전처리
# * 데이터 타입 변환
# * 결측치 탐지 및 보강
# * 이상치 탐지 및 처리
# * 데이터 특성 파악( 치우침, 분포 특성)
# * 변수들 간의 상관관계 분석

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1.데이터 세트 선택 및 로딩
# * 데이터 로드 후 head(), tail()로 컬럼과 데이터 파악하기

# %%
data=pd.read_csv("./data/Taitanic_train.csv")
data.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# # 2. .info()로 컬럼명, 결측치, 데이터타입 파악

# %%
# 데이터가 너무 커서 Non-Null이 표지되지 않을 때 : show_counts=True
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # 3. describe()로 기초통계량 파악

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # 4. 결측값 찾고, 비율 보고, 대치/삭제하기
# * 결측값 비율 계산: isna().sum() / len(df) * 100
# * 결측값 비율 5% 미만: 행, 열 제거, 분석에 크게 영향을 미치지 않음
# * 결측값 비율 5~30% : 결측값을 대체(imputation)
#     * 수치형 데이터(숫자형, 나이, 가격) : 평균(mean), 중앙값(median), 최빈값(mode)로 대체
#     * 범주형 데이터(문자형/(숫자형), 선실등급, 탑승지: 최빈값(mode)로 대체
# * 결측값 비율 30%~50%: 컬럼의 중요도에 따라서 결측값을 대체 혹은 삭제
#     * KNN(K-Nearest Neighbor, 최근접이웃) imputer, 회귀분석을 통해 결측치 대체
# * 결측값 비율이 50% 이상: 해당 컬럼 삭제

# %%
round(data.isna().sum()/len(data)*100,2)
# Out:
# PassengerId     0.00
# Survived        0.00
# Pclass          0.00
# Name            0.00
# Sex             0.00
# Age            19.87
# SibSp           0.00
# Parch           0.00
# Ticket          0.00
# Fare            0.00
# Cabin          77.10
# Embarked        0.22
# dtype: float64

# %% [markdown]
# ## 결측 데이터 종류
# * MCAR(완전 무작위 결측): 다른 변수와 무관하게 생긴 결측(랜덤, 이유 없음)
#     * 설문조사 중 일부 응답자가 무작위로 답변 건너뜀
# * MAR(무작위 결측) : 다른 변수와는 관련있지만, 본인과 무관
#     * 나이가 많은 사람들이 소득란에 응답을 하지 않는 경우 (현재 소득이 없거나 밝히고 싶지 않아서 응답 X - 나이와 관련 O)
#     * 직업에 따라서 학력란에 응답하지 않는 경우 (가정환경, 소득)
# * NMAR(비무작위 결측): 변수 자기 자신과 직접 관련이 있는 경우
#     * 소득이 낮은 사람이 자신의 소득을 숨기는 경우
#     * 체중이 많이 나가는 사람이 자신의 체중을 숨기는 경우
#     * 만족도가 낮은 사람이 설문에 응하지 않는 경우

# %% [markdown]
# ## 결측치 처리 방법
# * 1) 단순대치법(simple imputation)
#     * (1) 완전분석 : 결측값이 있는 모든 행을 삭제하고 완전한 자료만으로 분석(잘 안씀)
#         * 결측값을 삭제해도 모델을 만들기에 충분히 많은 데이터가 있는 경우
#         * 결측값을 삭제한 후에 데이터에 편향이 없다는 전제가 있을 때
#         * dropna() : 결측값이 있는 모든 행 삭제

# %%
data.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
183/len(data)*100
# Out:
# 20.53872053872054

# %% [markdown]
# ### (2) 평균 대치법: 결측치가 있는 컬럼에서 데이터의 평균을 구한 후 결측값을 대치
#         * 평균을 이용하기 때문에 간편
#         * 데이터에 이상치가 있을 경우 평균을 이용할 수 없다.
#         * 데이터에 이상치가 있는 경우 중앙값이나 최빈값을 고려해야 함.

# %%
a=pd.Series([24,5,10,34,20,18,28,20])
b=pd.Series([24,5,10,34,20,18,28,2000])

# %%
a.mean()
# Out:
# np.float64(19.875)

# %%
b.mean()
# Out:
# np.float64(267.375)

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
age_na_idx=data[data['Age'].isna()].index

# %%
# 깊은 복사, 얕은 복사

data2=data.copy()
data3=data.copy()

# %%
data['Age']=data['Age'].fillna(data['Age'].mean())

# %%
data.loc[age_na_idx]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %% [markdown]
# 중앙값으로 대치

# %%
age_na_index2=data2[data2['Age'].isna()].index

# %%
data2['Age']=data2['Age'].fillna(data2['Age'].median())

# %%
data2.loc[age_na_index2]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %% [markdown]
# * 최빈값 대치 .mode()

# %%
data3['Age'].mode()
# Out:
# 0    24.0
# Name: Age, dtype: float64

# %%
age_na_idx3=data3[data3['Age'].isna()].index

# %%
data3['Age']=data3['Age'].fillna(data3['Age'].mode()[0])

# %%
data3.loc[age_na_idx3]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %% [markdown]
# # scikit-learn의 simple imputer를 이용한 대치

# %%
from sklearn.impute import SimpleImputer

# %%
data4=data.copy()

# %%
imp_mean=SimpleImputer(strategy="mean")
data4['Age']=imp_mean.fit_transform(data4[['Age']])[:,0]

# %%
data4['Age'].isna().sum()
# Out:
# np.int64(0)

# %%
na_idx=data4[data4['Age'].isna()].index
# Out:
# Index([], dtype='int64')

# %%
imp_median=SimpleImputer(strategy='median')
data4['Age']=imp_median.fit_transform(data4[['Age']])[:,0]

# %%
data4.loc[na_idx]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# # 깊은 복사, 얕은 복사

# %%
# data를 copy()를 이용해서 복사
data_copyed=data.copy()

# data를 다른 변수에 재할당
data_reassigned = data

# %%
data['Age'].isna().sum()
# Out:
# np.int64(177)

# %%
data_reassigned['Age']=data_reassigned['Age'].fillna(28)

# %%
data_reassigned['Age'].isna().sum()
# Out:
# np.int64(0)

# %%
data['Age'].isna().sum() # 재할당한 데이터셋에서 작업한 내용도 변경됨.
# Out:
# np.int64(0)

# %% [markdown]
# # 실제 메모리상의 주소를 출력 id()

# %%
print("data의 메모리 주소:",id(data))
print("data_reassigned 의 메모리 주소:",id(data_reassigned))
print("data_copyed 의 메모리 주소:",id(data_copyed))
# Out:
# data의 메모리 주소: 2345622481984
# data_reassigned 의 메모리 주소: 2345622481984
# data_copyed 의 메모리 주소: 2345622450768

# %% [markdown]
# * 얕은 복사 쓰는 이유 : 깊은 복사는 메모리를 많이 소요함.
