# %% [markdown]
# # 마크다운 모드
#
# # 셀복사
# ## html과 비슷한 필기 모드
# ### 이렇게 표시 가능
# * 목록
# * 목록2
#   * 세부목록1
#     * 세부목록의 목록1
#
# 내용적기
# **굵게 만들기**
#
# ### 링크걸기
# [네이버링크](https://www.naver.com/)
#
# ### 이미지 넣기
# ![고양이](이미지링크 주소, 이미지 삽입)
#
# ### 수식넣기
#  - TeX 문법
# $$ A \over B $$
#
# ###  표 만들기
# | 값 | 의미 | 기본값 |
# |-|-|-|
# |`static`| 유형(기준)없음/배치불가능 | `static` |

# %%
# 코딩모드
